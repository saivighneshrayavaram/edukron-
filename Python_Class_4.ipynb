# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000],  ["C102", "Anita", "Current", 150000],  ["C103", "Kiran", "Loan", 500000] ],
           [ ["C104", "Sneha", "Savings", 95000], ["C105", "Vikram", "Current", 275000], ["C106", "Meena", "Loan", 750000] ] ],
[[["C201", "Arjun", "Savings", 120000],["C202", "Pooja", "Current", 325000],["C203", "Ramesh", "Loan", 900000]],[["C204", "Priya", "Savings", 45000],["C205", "Amit", "Current", 185000],
["C206", "Divya", "Loan", 650000]]],

[[["C301", "Nikhil", "Savings", 78000],["C302", "Kavya", "Current", 240000],["C303", "Suresh", "Loan", 1000000]],[["C304", "Neha", "Savings", 135000],
 ["C305", "Rohan", "Current", 410000],["C306", "Asha", "Loan", 550000]]]
]

# %% [markdown]
# 30.Print the loan amount of the last customer in Bank 3, Branch 2.

# %%
bank[2][1][2][3]
# Out:
# 550000

# %% [markdown]
# 29.Print the second customer from every bank's second branch.

# %%
b1=bank[0][1][1]
b2=bank[1][1][1]
b3=bank[2][1][1]
print(b1,b2,b3)
# Out:
# ['C105', 'Vikram', 'Current', 275000] ['C205', 'Amit', 'Current', 185000] ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# 28.Print the first customer from every bank's first branch.

# %%
a1=bank[0][0][0]
a2=bank[1][0][0]
a3=bank[2][0][0]
print(a1,a2,a3)
# Out:
# ['C101', 'Rahul', 'Savings', 85000] ['C201', 'Arjun', 'Savings', 120000] ['C301', 'Nikhil', 'Savings', 78000]

# %% [markdown]
# 27.Print all branches of Bank 3.

# %%
bank[2]
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000],
#   ['C302', 'Kavya', 'Current', 240000],
#   ['C303', 'Suresh', 'Loan', 1000000]],
#  [['C304', 'Neha', 'Savings', 135000],
#   ['C305', 'Rohan', 'Current', 410000],
#   ['C306', 'Asha', 'Loan', 550000]]]

# %% [markdown]
# 26.Print all branches of Bank 2.

# %%
bank[1]
# Out:
# [[['C201', 'Arjun', 'Savings', 120000],
#   ['C202', 'Pooja', 'Current', 325000],
#   ['C203', 'Ramesh', 'Loan', 900000]],
#  [['C204', 'Priya', 'Savings', 45000],
#   ['C205', 'Amit', 'Current', 185000],
#   ['C206', 'Divya', 'Loan', 650000]]]

# %% [markdown]
# 25.Print all branches of Bank 1.

# %%
bank[0]
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %% [markdown]
# 24.Print all customers in Bank 3, Branch 2.

# %%
j=bank[2][1][0][1]
k=bank[2][1][1][1]
l=bank[2][1][2][1]
print(j,k,l)
# Out:
# Neha Rohan Asha

# %% [markdown]
# 23.Print all customers in Bank 3, Branch 1.

# %%
m=bank[2][0][0][1]
n=bank[2][0][1][1]
o=bank[2][0][2][1]
print(m,n,o)
# Out:
# Nikhil Kavya Suresh

# %% [markdown]
# 22.Print all customers in Bank 2, Branch 2.

# %%
d=bank[1][1][0][1]
e=bank[1][1][1][1]
f=bank[1][1][2][1]
print(d,e,f)
# Out:
# Priya Amit Divya

# %% [markdown]
# 21.Print all customers in Bank 2, Branch 1.

# %%
g=bank[1][0][0][1]
h=bank[1][0][1][1]
i=bank[1][0][2][1]
print(g,h,i)
# Out:
# Arjun Pooja Ramesh

# %% [markdown]
# 20.Print all customers in Bank 1, Branch 2.

# %%
a=bank[0][1][0][1]
b=bank[0][1][1][1]
c=bank[0][1][2][1]
print(a,b,c)
# Out:
# Sneha Vikram Meena

# %% [markdown]
# 19.Print all customers in Bank 1, Branch 1.

# %%
x=bank[0][0][0][1]
y=bank[0][0][1][1]
z=bank[0][0][2][1]
print(x,y,z)
# Out:
# Rahul Anita Kiran

# %% [markdown]
# 18.Print Asha's account type.

# %%
bank[2][1][2][2]
# Out:
# 'Loan'

# %% [markdown]
# 17.Print Rohan's complete record.

# %%
bank[2][1][1]
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# 16.Print Neha's name

# %%
bank[2][1][0][1]
# Out:
# 'Neha'

# %% [markdown]
# 15.Print Suresh's loan amount.

# %%
bank[2][0][2][3]
# Out:
# 1000000

# %% [markdown]
# 14.Print Kavya's balance

# %%
bank[2][0][1][3]
# Out:
# 240000

# %% [markdown]
# 13.Print Nikhil's account type.

# %%
bank[2][0][0][2]
# Out:
# 'Savings'

# %% [markdown]
# 12.Print Divya's customer ID.

# %%
bank[1][1][2][0]
# Out:
# 'C206'

# %% [markdown]
# 11.Print Amit's account type.

# %%
bank[1][1][1][2]
# Out:
# 'Current'

# %% [markdown]
# 10.Print Priya's balance.

# %%
bank[1][1][0][3]
# Out:
# 45000

# %% [markdown]
# 9.Print Ramesh's account type

# %%
bank[1][0][2][2]
# Out:
# 'Loan'

# %% [markdown]
# 8.Print Pooja's name.

# %%
bank[1][0][1][1]
# Out:
# 'Pooja'

# %% [markdown]
# 7.Print Arjun's customer ID.

# %%
bank[1][0][0][0]
# Out:
# 'C201'

# %% [markdown]
# 6.Print Meena's complete record.

# %%
bank[0][1][2]
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %% [markdown]
# 5.Print Vikram's balance.

# %%
bank[0][1][1][3]
# Out:
# 275000

# %% [markdown]
# 1.Print Rahul's complete record.

# %%
bank[0][0][0]
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %% [markdown]
# 2.Print Anita's account type.

# %%
bank[0][0][1][2]
# Out:
# 'Current'

# %% [markdown]
# 3.Print Kiran's loan amount.

# %%
bank[0][0][2][3]
# Out:
# 500000

# %% [markdown]
# 4.Print Sneha's customer ID.

# %%
bank[0][1][0][0]
# Out:
# 'C104'

# %% [markdown]
# 1.Create a list of 5 employee names and add a new employee using append().

# %%
x=[]

# %%
x.append("Kartheek")
x.append("sai")
x.append("kushal")
x.append("bhairav")
x.append("vijay")
print(x)
# Out:
# ['Kartheek', 'sai', 'kushal', 'bhairav', 'vijay']

# %% [markdown]
# 2.Create a list of account numbers and add three new account numbers using extend().

# %%
y=[11111111111,222222222222]
y.extend([333333333333,444444444444,555555555555])
print(y)
# Out:
# [11111111111, 222222222222, 333333333333, 444444444444, 555555555555]

# %% [markdown]
# 3.Insert a new customer at the beginning of a customer list using insert().

# %%
x.insert(0,"Ganesh")
print(x)
# Out:
# ['Ganesh', 'Kartheek', 'sai', 'kushal', 'bhairav', 'vijay']

# %% [markdown]
# 4.Insert a transaction amount at index 3 in a list.

# %%
x.insert(3,52000)
print(x)
# Out:
# ['Ganesh', 'Kartheek', 'sai', 52000, 'kushal', 'bhairav', 'vijay']

# %% [markdown]
# 5.Remove the last item from a list using pop().

# %%
x.pop()
print(x)
# Out:
# ['Ganesh', 'Kartheek', 'sai', 52000, 'kushal', 'bhairav']

# %% [markdown]
# 6.Remove the customer "Rahul" from a customer list using `remove()`.

# %%
x.remove("bhairav")
print(x)
# Out:
# ['Ganesh', 'Kartheek', 'sai', 52000, 'kushal']

# %%
Customer_IDs=['C101', 'C102', 'C103', 'C104', 'C105', 'C106',
'C201', 'C202', 'C203', 'C204', 'C205', 'C206',
'C301', 'C302', 'C303', 'C304', 'C305', 'C306']

# %%
Names=[
'Rahul', 'Anita', 'Kiran', 'Sneha', 'Vikram', 'Meena',
'Arjun', 'Pooja', 'Ramesh', 'Priya', 'Amit', 'Divya',
'Nikhil', 'Kavya', 'Suresh', 'Neha', 'Rohan', 'Asha']

Account_Types=[
'Savings', 'Current', 'Loan', 'Savings', 'Current', 'Loan',
'Savings', 'Current', 'Loan', 'Savings', 'Current', 'Loan',
'Savings', 'Current', 'Loan', 'Savings', 'Current', 'Loan']

Amounts=[
85000, 150000, 500000, 50000,95000, 275000, 750000,
120000, 325000, 900000, 45000, 185000, 650000,
78000, 240000, 1000000, 135000, 410000, 550000]

cities=["Banglore","Hyderabad","Chennai","Hyderabad","Kadapa","Kurnool",
        "Pulivendula","Kadiri","Chennai","Banglore"]

banknames=["APGB","State Of India","Union Bank","Indian Bank","Canara Bank","HDFC Bank","Kadapa Bank"]

# %% [markdown]
# 20.Create a list of loan amounts and sort it in descending order.

# %%
Amounts.sort(reverse=True)
print(Amounts)
# Out:
# [1000000, 900000, 750000, 650000, 550000, 500000, 410000, 325000, 275000, 240000, 185000, 150000, 135000, 120000, 95000, 85000, 78000, 50000, 45000]

# %% [markdown]
# 19.Reverse a list of bank names and print the result.

# %%
banknames.reverse()
print(banknames)
# Out:
# ['Kadapa Bank', 'HDFC Bank', 'Canara Bank', 'Indian Bank', 'Union Bank', 'State Of India', 'APGB']

# %% [markdown]
# 18.Count how many times the city "Bangalore" appears in a list.

# %%
cities.count("Banglore")
# Out:
# 2

# %% [markdown]
# 17.Pop the element at index 2 from a list and print the removed value.

# %%
print(Amounts.pop(2))
# Out:
# 500000

# %% [markdown]
# 16.Remove the first occurrence of the balance 50000 from a list using remove().

# %%
Amounts.remove(50000)
print(Amounts)
# Out:
# [85000, 150000, 500000, 95000, 275000, 750000, 120000, 325000, 900000, 45000, 185000, 650000, 78000, 240000, 1000000, 135000, 410000, 550000]

# %% [markdown]
# 15.Extend a list of branch names with another list of new branches.

# %%
Branches=["Vempalli","Kadapa","Pulivendula","ATP","Kurnool"];
Branches.extend(["Hyd","Chennai","Banglore"])
print(Branches)
# Out:
# ['Vempalli', 'Kadapa', 'Pulivendula', 'ATP', 'Kurnool', 'Hyd', 'Chennai', 'Banglore']

# %% [markdown]
# 14.Append a nested list containing a new customer's details to an existing customer list.

# %%
Amounts.append([25001,45869,65897])
print(Amounts)
# Out:
# [45000, 78000, 85000, 95000, 120000, 135000, 150000, 185000, 240000, 275000, 325000, 410000, 500000, 550000, 650000, 750000, 900000, 1000000, [25001, 45869, 65897]]

# %% [markdown]
# 13.Clear all elements from a list using clear().

# %%
Customer_IDs.clear();
print(Customer_IDs);
# Out:
# []

# %% [markdown]
# 12.Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list.

# %%
Amounts1=Amounts.copy();
Amounts1[3]=51000;
print(Amounts);
print(Amounts1);
# Out:
# [45000, 78000, 85000, 95000, 120000, 135000, 150000, 185000, 240000, 275000, 325000, 410000, 500000, 550000, 650000, 750000, 900000, 1000000]
# [45000, 78000, 85000, 51000, 120000, 135000, 150000, 185000, 240000, 275000, 325000, 410000, 500000, 550000, 650000, 750000, 900000, 1000000]

# %% [markdown]
# 11.Sort a list of customer names in descending order using sort().

# %%
Names.sort(reverse=True)
print(Names)
# Out:
# ['Vikram', 'Suresh', 'Sneha', 'Rohan', 'Ramesh', 'Rahul', 'Priya', 'Pooja', 'Nikhil', 'Neha', 'Meena', 'Kiran', 'Kavya', 'Divya', 'Asha', 'Arjun', 'Anita', 'Amit']

# %% [markdown]
# 10.Sort a list of account balances in ascending order using sort().

# %%
Amounts.sort();
print(Amounts)
# Out:
# [45000, 78000, 85000, 95000, 120000, 135000, 150000, 185000, 240000, 275000, 325000, 410000, 500000, 550000, 650000, 750000, 900000, 1000000]

# %% [markdown]
# 9.Reverse a list of transaction IDs using reverse()

# %%
transaction_id=[12345,25463,14523,78459,24587,98573,57843,63985,34589]

# %%
transaction_id.reverse()
print(transaction_id)
# Out:
# [34589, 63985, 57843, 98573, 24587, 78459, 14523, 25463, 12345]

# %% [markdown]
# 8.Find the index of "Current" in a list of account types using index().

# %%
print(Account_Types.index("Current"));
# Out:
# 1

# %% [markdown]
# 7.Count how many times the account type "Savings" appears in a list using count()

# %%
print(Account_Types.count("Savings"));
# Out:
# 6

# %%
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}

loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}

transaction_ids = {101, 102, 103, 104, 105}

balances = {85000, 120000, 45000, 95000, 275000}

cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}

new_cities = {"Mumbai", "Bangalore", "Delhi"}

account_types = {"Savings", "Current", "Loan"}

# %% [markdown]
# 40Clear the transaction_ids set and verify that it is empty.

# %%
transaction_ids.clear()
print(transaction_ids)
# Out:
# set()

# %% [markdown]
# 39.Print every element of the loan_customers set using a loop

# %%
for loan in loan_customers:
  print(loan)
# Out:
# Kiran
# Asha
# Ramesh
# Rahul

# %% [markdown]
# 38.Find the length of the account_types set.

# %%
print(len(account_types))
# Out:
# 3

# %% [markdown]
# 37.Add five employee names to the empty set.

# %%
se1.add("Sai");
se1.add("Kartheek");
se1.add("Ravi");
se1.add("bhairav");
se1.add("Vijay");
print(se1)
# Out:
# {'Kartheek', 'Sai', 'Vijay', 'Ravi', 'bhairav'}

# %% [markdown]
# 36.Create an empty set.

# %%
se1=set()

# %% [markdown]
# 35.Remove duplicates from the list: ["Rahul", "Rahul", "Anita", "Sneha", "Sneha"] by converting it into a set.

# %%
li=["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
se=set(li)
print(se)
# Out:
# {'Anita', 'Sneha', 'Rahul'}

# %% [markdown]
# 34.Convert the cities set into a tuple.

# %%
tup=tuple(cities)
print(tup)
# Out:
# ('Hyderabad', 'Chennai', 'Pune', 'Bangalore')

# %% [markdown]
# 33.Convert the customers set into a list.

# %%
listcust=list(customers)
print(listcust)
# Out:
# ['Kiran', 'Rahul', 'Anita', 'Sneha', 'Vikram']

# %% [markdown]
# 32.Sort the balances set in ascending order.

# %%
sorted(balances)
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %% [markdown]
# 31.Find the total of all balances.

# %%
print(sum(balances))
# Out:
# 620000

# %% [markdown]
# 30.Find the minimum balance in the balances set.

# %%
print(min(balances))
# Out:
# 45000

# %% [markdown]
# 29.Find the maximum balance in the balances set.

# %%
print(max(balances))
# Out:
# 275000

# %% [markdown]
# 28.Check whether loan_customers and new_cities are disjoint.

# %%
print(loan_customers.isdisjoint(new_cities))
# Out:
# True

# %% [markdown]
# 27.Check whether customers is a superset of {"Rahul", "Anita"}

# %%
print(customers.issuperset({"Rahul", "Anita"}))
# Out:
# False

# %% [markdown]
# 26.Check whether {"Rahul", "Kiran"} is a subset of loan_customers

# %%
print({"Rahul","Kiran"}.issubset(loan_customers))
# Out:
# True

# %% [markdown]
# 25.Find customers that are present in either customers or new_customers but not both.

# %%
print(customers.symmetric_difference(new_customers))
# Out:
# {'Kiran', 'Rahul', 'Meena', 'Sneha', 'Vikram'}

# %% [markdown]
# 24.Find customers who have only Savings accounts.

# %%
print(savings_customers.difference(customers))
# Out:
# {'Nikhil', 'Rahul'}

# %% [markdown]
# 23.Find customers present only in customers but not in new_customers.

# %%
print(customers.difference(new_customers))
# Out:
# {'Kiran', 'Meena', 'Sneha', 'Vikram'}

# %% [markdown]
# 22.Find customers who have both Savings and Loan accounts.

# %%
print(savings_customers.intersection(loan_customers))
# Out:
# {'Rahul'}

# %% [markdown]
# 21.Find the common customers between customers and new_customers.

# %%
print(customers.intersection(new_customers))
# Out:
# {'Divya', 'Amit', 'Priya'}

# %% [markdown]
# 20.Find the union of customers and new_customers.

# %%
print(customers.union(new_customers))
# Out:
# {'Kiran', 'Divya', 'Amit', 'Vikram', 'Rahul', 'Priya', 'Sneha', 'Meena'}

# %% [markdown]
# 19.Modify the copied set and verify that the original set remains unchanged.

# %%
customers1.add("Sai")
print(customers)
print(customers1)
# Out:
# {'Kiran', 'Divya', 'Amit', 'Vikram', 'Priya', 'Sneha', 'Meena'}
# {'Kiran', 'Sai', 'Divya', 'Amit', 'Meena', 'Sneha', 'Vikram', 'Priya'}

# %% [markdown]
# 18.Create a copy of the customers set.

# %%
customers1=customers.copy();
print(customers1)
# Out:
# {'Kiran', 'Divya', 'Amit', 'Meena', 'Sneha', 'Vikram', 'Priya'}

# %% [markdown]
# 17.Remove all elements from the balances set.

# %%
balances.clear()
balances
# Out:
# set()

# %% [markdown]
# 16.Remove another random element from the account_types set.

# %%
account_types.pop();
account_types
# Out:
# {'Current', 'Loan'}

# %% [markdown]
# 15.Remove a random element from the transaction_ids set using pop().

# %%
transaction_ids.pop()
transaction_ids
# Out:
# {102, 103, 104, 105}

# %% [markdown]
# 14.Discard "Kolkata" from the cities set.

# %%
cities.discard("Kolkata")
cities
# Out:
# {'Bangalore', 'Chennai', 'Hyderabad', 'Mumbai', 'Mysore'}

# %% [markdown]
# 13.Discard "Delhi" from the cities set.

# %%
cities.discard("Delhi")
cities
# Out:
# {'Bangalore', 'Chennai', 'Hyderabad', 'Mumbai', 'Mysore'}

# %% [markdown]
# 12.Discard "Anita" from the customers set.

# %%
customers.discard("Anita")
customers
# Out:
# {'Amit', 'Divya', 'Kiran', 'Meena', 'Priya', 'Sneha', 'Vikram'}

# %% [markdown]
# 11.Remove "Pune" from the cities set.

# %%
cities.remove("Pune")
cities
# Out:
# {'Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Mumbai', 'Mysore'}

# %% [markdown]
# 10.Remove "Rahul" from the customers set.

# %%
customers.remove("Rahul")
customers
# Out:
# {'Amit', 'Anita', 'Divya', 'Kiran', 'Meena', 'Priya', 'Sneha', 'Vikram'}

# %% [markdown]
# 9.Update the cities set with new_cities.

# %%
cities.update(new_cities)
cities
# Out:
# {'Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Mumbai', 'Mysore', 'Pune'}

# %% [markdown]
# 8.Update the customers set with new_customers.

# %%
customers.update(new_customers)
print(customers)
# Out:
# {'Kiran', 'Divya', 'Amit', 'Rahul', 'Vikram', 'Priya', 'Anita', 'Sneha', 'Meena'}

# %% [markdown]
# 7.Add "Mysore" to the cities set.

# %%
cities.add("Mysore")
cities
# Out:
# {'Bangalore', 'Chennai', 'Hyderabad', 'Mysore', 'Pune'}

# %% [markdown]
# 6.Add "Meena" to the customers set.

# %%
customers.add("Meena")
customers
# Out:
# {'Anita', 'Kiran', 'Meena', 'Rahul', 'Sneha', 'Vikram'}

# %% [markdown]
# 5.Iterate through all elements in the bank_branches set.

# %%
print(bank_branches)
# Out:
# {'Electronic City', 'MG Road', 'Whitefield', 'Indiranagar'}

# %% [markdown]
# 4.Check whether "Meena" exists in the customers set.

# %%
print("Meena" in customers)
# Out:
# False

# %% [markdown]
# 3.Check whether "Rahul" exists in the customers set.

# %%
print("Rahul" in customers)
# Out:
# True

# %% [markdown]
# 2.Find the number of elements in the customers set.

# %%
print(len(customers))
# Out:
# 5

# %% [markdown]
# 1.Print the customers set.

# %%
print(customers)
# Out:
# {'Kiran', 'Rahul', 'Anita', 'Sneha', 'Vikram'}
