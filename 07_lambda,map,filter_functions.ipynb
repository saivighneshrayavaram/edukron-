# %% [markdown]
# 1.Write a lambda expression to calculate the square of number.(Number=8)

# %%
square=lambda x:x**2
print(square(8))
# Out:
# 64

# %% [markdown]
# 2.Write a lambda expression to calculate the cube of number.

# %%
cube=lambda x:x**3
print(cube(5))
# Out:
# 125

# %% [markdown]
# 3.Write a lambda expression to add a and b.(a=25,b=17)

# %%
add=lambda a,b:a+b
print(add(25,17))
# Out:
# 42

# %% [markdown]
# 4.Write a lambda expression to subtract b from a.(a=50,b=18)

# %%
subtract=lambda a,b:a-b
print(subtract(50,18))
# Out:
# 32

# %% [markdown]
# 5.Write a lambda expression to multiply a and b.(a=12,b=9)

# %%
multiply=lambda a,b:a*b
print(multiply(12,9))
# Out:
# 108

# %% [markdown]
# 6.Write a lambda expression to divide a by b.(a=100,b=4)

# %%
div=lambda a,b:a/b
print(div(100,4))
# Out:
# 25.0

# %% [markdown]
# 7.Write a lambda expression to return the larger number.(a=72,b=91)

# %%
more=lambda a,b:a if(a>b) else b
print(more(72,91))
# Out:
# 91

# %% [markdown]
# 8.Write a lambda expression to return the smaller number.(a=46,b=28)

# %%
less=lambda a,b: a if(a<b) else b
print(less(46,28))
# Out:
# 28

# %% [markdown]
# 9.Write a lambda expression that returns True when the number is even and False otherwise.(number=34)

# %%
num=lambda x: True if x%2==0 else False
print(num(34))
# Out:
# True

# %% [markdown]
# 10.Write a lambda expression that returns True when the number is odd and False otherwise.(number=27)

# %%
num=lambda x:True if(x%2!=0) else False
print(num(27))
# Out:
# True

# %% [markdown]
# 11.Write a lambda expression to calculate the area of a rectangle.(length=12,width=8)

# %%
area=lambda a,b:a*b
print(area(12,8))
# Out:
# 96

# %% [markdown]
# 12.Write a lambda expression to calculate the area of a circle using 3.14.(Radius=7)

# %%
area=lambda pi,r:pi*r**2
print(area(3.14,7))
# Out:
# 153.86

# %% [markdown]
# 13.Write a lambda expression to calculate the perimeter of a rectangle.(length=15,width=10)

# %%
perimeter=lambda l,w:2*(l+w)
print(perimeter(15,10))
# Out:
# 50

# %% [markdown]
# 14.Write a lambda expression to convert Celsius into Fahrenheit.(celsius=35)

# %%
fahrenheit=lambda x: x*(9/5)+32
print(fahrenheit(35))
# Out:
# 95.0

# %% [markdown]
# 15.Write a lambda expression to convert Fahrenheit into Celsius.(fahrenheit=104)

# %%
celsius=lambda x:(x-32)*(5/9)
print(celsius(104))
# Out:
# 40.0

# %% [markdown]
# 16.Write a lambda expression to return the length of the string.(word="Python)

# %%
length=lambda x:len(x)
print(length("Python"))
# Out:
# 6

# %% [markdown]
# 17.Write a lambda expression to return the first character of the string.(word="Azure")

# %%
ch=lambda x:x[0]
print(ch("Azure"))
# Out:
# A

# %% [markdown]
# 18.Write a lambda expression to return the last character of the string.(word=Databricks)

# %%
ch=lambda x:x[-1]
print(ch("Databricks"))
# Out:
# s

# %% [markdown]
# 19.Write a lambda expression to return the absolute value of the number without using abs().

# %%
ab=lambda x:abs(x)
print(ab(-45))
# Out:
# 45

# %% [markdown]
# 20.Write a lambda expression that returns:
# "Distinction" when marks are 75 or above
# "Pass" when marks are 40 to 74
# "Fail" when marks are below 40

# %%
a=lambda x:"Distinction" if(x>=75)  else("Pass" if(x>=40 and x<=74) else "Fail")
print(a(72))
# Out:
# Pass

# %% [markdown]
# Map()

# %% [markdown]
# 1.Using map() and a lambda expression, calculate the square of every number.

# %%
numbers=[1,2,3,4,5]
a=list(map(lambda x:x**2,numbers))
print(a)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# 2.Using map() and a lambda expression, calculate the cube of every number.

# %%
numbers=[2,3,4,5,6]
a=list(map(lambda x:x**3,numbers))
print(a)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# 3.Using map(), add 5 to every number.

# %%
numbers=[10,20,30,40,50]
c=list(map(lambda x:x+5,numbers))
print(c)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# 4.Using map(), subtract 10 from every number

# %%
numbers=[15,25,35,45,55]
c=list(map(lambda x:x-10,numbers))
print(c)
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# 5.Using map(), multiply every number by 100.

# %%
numbers=[1,5,10,15,20]
c=list(map(lambda x:x*100,numbers))
print(c)
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# 6.Using map(), convert every name to uppercase.

# %%
names=["ravi", "anil", "meena", "kiran", "sneha"]
c=list(map(lambda x:x.upper(),names))
print(c)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# 7.Using map(), convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
c=list(map(lambda x:x.lower(),names))
print(c)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# 8.Using map(), convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
c=list(map(lambda x:x.title(),names))
print(c)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# 9.Using map(), calculate the length of every word.

# %%
words=["Python","Azure","Databricks","cloud","AI"]
c=list(map(lambda x:len(x),words))
print(c)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# 10.Using map(), extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
c=list(map(lambda x:x[0],words))
print(c)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# 11.Using map(), extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
c=list(map(lambda x:x[-1],words))
print(c)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# 12.Using map(), convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [0, 10, 20, 30, 40]
c=list(map(lambda x:x*(9/5)+32,temperatures))
print(c)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# 13.Using map(), calculate 18% GST for every price.

# %%
prices=[100,250,500,1000,2500]
c=list(map(lambda x:x*0.18,prices))
print(c)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# 14.Using map(), calculate the final price after adding 18% GST.

# %%
prices=[100,250,500,1000,2500]
c=list(map(lambda x:x+x*0.18,prices))
print(c)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# 15.Using map(), round every number to two decimal places.

# %%
decimal_numbers=[12.4567,45.8976,78.1234,99.9999]
c=list(map(lambda x:round(x,2),decimal_numbers))
print(c)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# 16.Using map(), convert every number into its absolute value.

# %%
values=[-10,20,-35,40,-55,60]
c=list(map(lambda x:abs(x),values))
print(c)
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# 17.Using map(), convert every integer into a string.

# %%
numbers=[10,20,30,40,50]
c=list(map(lambda x:str(x),numbers))
print(c)
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# 18.Using map(), remove leading and trailing spaces from every name.

# %%
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
c=list(map(lambda x:x.strip(),names))
print(c)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# 19.Using map(), extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
c=list(map(lambda x:x["name"],employees))
print(c)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# 20.Using map(), create a new list of dictionaries containing:

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
a=[]
c=list(map(lambda x:{"name":x["name"],"salary":x["salary"],"Salary after a 10% increment":x["salary"]+x["salary"]*0.10},employees))
print(c)
# Out:
# [{'name': 'Rahul', 'salary': 45000, 'Salary after a 10% increment': 49500.0}, {'name': 'Anil', 'salary': 65000, 'Salary after a 10% increment': 71500.0}, {'name': 'Sneha', 'salary': 72000, 'Salary after a 10% increment': 79200.0}, {'name': 'Kiran', 'salary': 82000, 'Salary after a 10% increment': 90200.0}]

# %% [markdown]
# 3.filter()

# %% [markdown]
# 1.Using filter(), extract all even numbers.

# %%
numbers=[12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
c=list(filter(lambda x:x%2==0,numbers))
print(c)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# 2.Using filter(), extract all odd numbers.

# %%
numbers=[12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
c=list(filter(lambda x:x%2 !=0,numbers))
print(c)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# 3.Using filter(), extract all numbers greater than 50.

# %%
numbers=[12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
c=list(filter(lambda x:x > 50,numbers))
print(c)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# 4.Using filter(), extract all numbers less than 100.

# %%
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
c=list(filter(lambda x:x<100,numbers))
print(c)
# Out:
# [45, 89, 56, 91, 34]

# %% [markdown]
# 5.Using filter(), extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
c=list(filter(lambda x:x > 0,numbers))
print(c)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# 6.Using filter(), extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
c=list(filter(lambda x:x<0,numbers))
print(c)
# Out:
# [-15, -8, -25]

# %% [markdown]
# 7.Using filter(), remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
c=list(filter(lambda x:x!=0,numbers))
print(c)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# 8.Using filter(), extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
c=list(filter(lambda x:len(x) > 5,words))
print(c)
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# 9.Using filter(), extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
c=list(filter(lambda x:x.startswith("A"),names))
print(c)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# 10.Using filter(), extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
c=list(filter(lambda x:x.endswith("n"),names))
print(c)
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# 11.Using filter(), extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
c=list(filter(lambda x:x%5==0,numbers))
print(c)
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# 12.Using filter(), extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
c=list(filter(lambda x:x%3==0 and x%5==0,numbers))
print(c)
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# 13.Using filter(), extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
c=list(filter(lambda x:x==x[::-1],words))
print(c)
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# 14.Using filter(), extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]
c=list(filter(lambda x:x.endswith(".com"),emails))
print(c)
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# 15.Using filter(), extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]
c=list(filter(lambda x:x.endswith(".csv"),files))
print(c)
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# 16.Using filter(), extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
c=list(filter(lambda x:x["salary"]>60000,employees))
print(c)
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# 17.Using filter(), extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
c=list(filter(lambda x:x["marks"]>80,students))
print(c)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# 18.Using filter(), extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
c=list(filter(lambda x:x["stock"] != 0,products))
print(c)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# 19.Using filter(), extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
c=list(filter(lambda x:x["age"]>= 18,people))
print(c)
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}, {'name': 'Meena', 'age': 18}]

# %% [markdown]
# 20.Using filter(), extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
c=list(filter(lambda x:(x["department"]=="IT") and (x["active"]==True),employees))
print(c)
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True}, {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# Reduce()

# %% [markdown]
# 1.Using reduce(), calculate the sum of all numbers.

# %%
from functools import reduce

# %%
numbers = [10, 20, 30, 40, 50]
result=reduce(lambda x,y:x+y,numbers)
print(result)
# Out:
# 150

# %% [markdown]
# 2.Using reduce(), calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]
result=reduce(lambda x,y:x*y,numbers)
print(result)
# Out:
# 120

# %% [markdown]
# 3.Using reduce(), find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
result=reduce(lambda x,y:x if(x>y) else y,numbers)
print(result)
# Out:
# 91

# %% [markdown]
# 4.Using reduce(), find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
result=reduce(lambda x,y:x if(x<y) else y,numbers)
print(result)
# Out:
# 12

# %% [markdown]
# 5.Using reduce(), combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]
result=reduce(lambda x,y:x+y,words)
print(result)
# Out:
# Python is powerful

# %% [markdown]
# 6.Using reduce(), calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]
result=reduce(lambda x,y:x+y,words)
c=len(result)
print(c)
# Out:
# 18

# %% [markdown]
# 7.Using reduce(), calculate the factorial of number.

# %%
number=6
numbers=list(range(1,number+1))
result=reduce(lambda x,y:x*y,numbers)
print(result)
# Out:
# 720

# %% [markdown]
# 8.Using reduce(), calculate the sum of only the even numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result=reduce(lambda total,x:total+x if(x%2==0) else total,numbers,0)
print(result)
# Out:
# 280

# %% [markdown]
# 9.Using reduce(), calculate the sum of only the odd numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result=reduce(lambda total,x:total+x if(x%2 !=0) else total,numbers,0)
print(result)
# Out:
# 315

# %% [markdown]
# 10.Using reduce(), find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
result1=reduce(lambda x1,y1:x1 if(len(x1)>len(y1)) else y1,words)
print(result1)
# Out:
# Kubernetes

# %% [markdown]
# 11.Using reduce(), find the shortest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
result=reduce(lambda x,y:x if(len(x)<len(y)) else y,words)
print(result)
# Out:
# AI

# %% [markdown]
# 12.Using reduce(), calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]
result=reduce(lambda x,y:x+y,salaries)
print(result)
# Out:
# 319000

# %% [markdown]
# 13.Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
result=reduce(lambda x,y:x+y["salary"],employees,0)
print(result)
# Out:
# 319000

# %% [markdown]
# 14.Using reduce(), find the employee with the highest salary.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
result=reduce(lambda x,y:x if(x["salary"]>y["salary"]) else y,employees)
print(result)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# 15.Using reduce(), find the student with the highest marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
result=reduce(lambda x,y:x if(x["marks"]>y["marks"]) else y,students)
print(result)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# 16.Using reduce(), calculate the total stock quantity.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
result=reduce(lambda x,y:x+y["stock"],products,0)
print(result)
# Out:
# 53

# %% [markdown]
# 17.Using reduce(), calculate the total inventory value using price × stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
result=reduce(lambda x,y:x+y["price"]*y["stock"],products,0)
print(result)
# Out:
# 456500

# %% [markdown]
# 18.Using reduce(), calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]
result=reduce(lambda x,y:x+y,sales)
print(result)
# Out:
# 182000

# %% [markdown]
# 19.Using reduce(), merge all dictionaries into one dictionary.

# %%
di={}
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
result=reduce(lambda x,y:dict(x,**y),dictionaries,di)
print(result)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# 20.Using reduce(), calculate the sum of unique numbers only. Do not directly use sum(set(numbers)).

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
distinct=[]
result=reduce(lambda total,y:total+y if y not in distinct and not distinct.append(y) else total,numbers,0)
print(result)
# Out:
# 336

# %% [markdown]
# section:5 Combined Lambda, map(), filter(), and reduce()

# %% [markdown]
# 1.Using filter() and map():
#  Extract all even numbers.
#  Calculate the square of every even number.
#  Return the squared values as a list.

# %%
numbers=[12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result=list(filter(lambda x:x%2==0,numbers))
result1=list(map(lambda x:x**2,result))
print(result1)
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# 2.Using filter() and reduce():
# Extract all odd numbers.
# Calculate their total sum.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result=list(filter(lambda x:x%2 !=0,numbers))
result1=reduce(lambda x,y:x+y,result)
print(result1)
# Out:
# 315

# %% [markdown]
# 3.Using filter() and map():
# Extract numbers greater than 50.
# Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
result=list(filter(lambda x:x>50,numbers))
result1=list(map(lambda x:x*2,result))
print(result1)
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# 4.Using filter(), map(), and reduce():
#
# Extract positive numbers.
# Calculate the square of every positive number.
# Calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]
result=list(filter(lambda x:x > 0,numbers))
result1=list(map(lambda x:x**2,result))
result2=reduce(lambda x,y:x+y,result1)
print(result2)
# Out:
# 8100

# %% [markdown]
# 5.Using filter() and map():
# Extract words containing more than five characters.
# Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
result=list(filter(lambda x:len(x)>5,words))
result1=list(map(lambda x:x.upper(),result))
print(result1)
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# 6.Using filter() and map():
# Extract names beginning with "A".
# Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
result=list(filter(lambda x:x.startswith("A"),names))
result1=list(map(lambda x:x.lower(),result))
print(result1)
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# 7.Using filter() and reduce():
# Extract numbers divisible by both 3 and 5.
# Calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
result=list(filter(lambda x:x%3==0 and x%5==0,numbers))
result1=reduce(lambda x,y:x+y,result)
print(result1)
# Out:
# 225

# %% [markdown]
# 8.Using filter() and reduce():
# Extract palindrome words.
# Join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
result=list(filter(lambda x:x==x[::-1],words))
result1=reduce(lambda x,y:x+y,"|".join(result),"")
print(result1)
# Out:
# madam|level|radar|civic

# %% [markdown]
# 9.Using filter(), map(), and reduce():
# Extract temperatures greater than 30°C.
# Convert the selected values into Fahrenheit.
# Calculate the average Fahrenheit temperature.

# %%
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
result=list(filter(lambda x:x>30,temperatures))
result1=list(map(lambda x:x*(9/5)+32,result))
result2=reduce(lambda x,y:((x+y)/len(result1)),result1)
print(result2)
# Out:
# 35.721875000000004

# %% [markdown]
# 10.Using filter(), map(), and reduce():
# Extract prices greater than 1000.
# Apply a 10% discount to every selected price.
# Calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
result=list(filter(lambda x:x>1000,prices))
result1=list(map(lambda x:x*0.10,result))
result2=reduce(lambda x,y:(x+y),result1)
print(result2)
# Out:
# 1770.0

# %% [markdown]
# 11.Using filter() and map():
# Extract employees earning more than 60000.
# Increase their salary by 10%.
# Return their names and updated salaries.

# %%
import math
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
result=list(filter(lambda x:x["salary"]>60000,employees))
result1=list(map(lambda x:{"name":x["name"],"salary":x["salary"]+x["salary"]*0.10},result))
print(result1)
# Out:
# [{'name': 'Anil', 'salary': 71500.0}, {'name': 'Sneha', 'salary': 79200.0}, {'name': 'Kiran', 'salary': 90200.0}]

# %% [markdown]
# 12.Using filter() and reduce():
# Extract employees from the IT department.
# Calculate the total salary of IT employees.

# %%
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
result=list(filter(lambda x:x["department"]=="IT",employees))
result1=reduce(lambda x,y:x+y["salary"],result,0)
print(result1)
# Out:
# 199000

# %% [markdown]
# 13.Using filter(), map(), and reduce():
# Extract active employees.
# Increase every active employee's salary by 15%.
# Calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
result=list(filter(lambda x:x["active"]==True,employees))
result1=list(map(lambda x:x["salary"]+x["salary"]*0.15,result))
result2=reduce(lambda x,y:x+y,result1)
print(result2)
# Out:
# 284050.0

# %% [markdown]
# 14.Using filter() and reduce():
# Extract students who passed.
# Find the topper among the passed students.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
result=list(filter(lambda x:x["passed"]==True,students))
print(result)
result1=reduce(lambda x,y:x if(x["marks"]>y["marks"]) else y,result)
print(result1)
# Out:
# [{'name': 'Ravi', 'marks': 92, 'passed': True}, {'name': 'Kiran', 'marks': 68, 'passed': True}, {'name': 'Meena', 'marks': 85, 'passed': True}, {'name': 'Ajay', 'marks': 48, 'passed': True}, {'name': 'Rahul', 'marks': 95, 'passed': True}]
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# 15.Using filter(), map(), and reduce():
# Extract students scoring more than 70.
# Extract only their marks.
# Calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
result=list(filter(lambda x:x["marks"]>70,students))
result1=list(map(lambda x:x["marks"],result))
result2=reduce(lambda x,y:((x+y)/len(result1)),result1)
print(result2)
# Out:
# 31.453125

# %% [markdown]
# 16.Using filter(), map(), and reduce():
# Extract products currently in stock.
# Calculate each product's inventory value using price × stock.
# Calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
result=list(filter(lambda x:x["stock"]>0,products))
result1=list(map(lambda x:x["price"]*x["stock"],result))
result2=reduce(lambda x,y:x+y,result1)
print(result2)
# Out:
# 512000

# %% [markdown]
# 17.Using filter(), map(), and reduce():
# Extract products belonging to the Electronics category.
# Apply a 20% discount.
# Calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
result=list(filter(lambda x:x["category"]=="Electronics",products))
result1=list(map(lambda x:x["price"]+x["price"]*0.20,result))
result2=reduce(lambda x,y:x+y,result1)
print(result2)
# Out:
# 95400.0

# %% [markdown]
# 18.Using filter() and reduce():
# Extract delivered orders.
# Calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
result=list(filter(lambda x:x["status"]=="Delivered",orders))
result1=reduce(lambda x,y:x+y["amount"],result,0)
print(result1)
# Out:
# 17300

# %% [markdown]
# 19.Using filter(), map(), and reduce():
# Extract transactions whose amount is greater than 5000.
# Add 18% GST to every selected transaction.
# Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
result=list(filter(lambda x:x["amount"]>5000,transactions))
result1=list(map(lambda x:x["amount"]+x["amount"]*0.18,result))
result2=reduce(lambda x,y:x+y,result1)
print(result2)
# Out:
# 47200.0

# %% [markdown]
# 20.Using filter(), map(), and reduce():
# Extract active salespeople from the South region.
# Calculate a 5% incentive for each selected salesperson.
# Create a list containing salesperson name, sales amount, and incentive.
# Calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
result=list(filter(lambda x:x["active"]==True and x["region"]=="South",sales_records))
result1=list(map(lambda x:{"name":x["salesperson"],"sales amount":x["sales"],"incentive":x["sales"]*(5/100)},result))
result2=reduce(lambda x,y:x+y["incentive"],result1,0)
print(result2)
# Out:
# 11250.0
