# %% [markdown]
# 1.Find a account code for banking case 1; use sample reference `ACC-1001` and explain the result.

# %%
import re
Account_Number='ACC-1001'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
pattern=r"^\d{11}$"
if(re.findall(pattern,Account_Number)):
    print("Valid Account Number")
else:
    print("Invalid account Number")
# Out:
# Account Number: ACC-1001
# Valid Account Number

# %% [markdown]
# 2.Validate a six-digit pin for banking case 1; use sample reference `ACC-1002` and explain the result.

# %%
Account_Number='ACC-1002'
print("Account Number:",Account_Number)
pattern=r"^\d{6}$"
pin=input("Enter pin:")
if(re.findall(pattern,pin)):
    print("Valid pin")
else:
    print("Invalid pin")
# Out:
# Account Number: ACC-1002
# Valid pin

# %% [markdown]
# 3. Extract all amounts for banking case 1; use sample reference `ACC-1003` and explain the result.

# %%
Account_Number='ACC-1003'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"₹\d+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1003
# ['₹10000', '₹2500', '₹50']

# %% [markdown]
# 4.Match a receipt date for banking case 1; use sample reference `ACC-1004` and explain the result

# %%
Account_Number='ACC-1004'
print("Account Number:",Account_Number)
Date=input("Enter Receipt Date:")
pattern=r"[0-30]{2}-[0-12]{2}-\d{4}"
re.findall(pattern,Date)
# Out:
# Account Number: ACC-1004
# ['12-12-2004']

# %% [markdown]
# 5.Find uppercase account references for banking case 1; use sample reference `ACC-1005` and explain the result

# %%
Account_Number="ACC-1005"
pattern=r"^[A-Z]+-\d+$"
re.findall(pattern,Account_Number)
# Out:
# ['ACC-1005']

# %% [markdown]
# 6.Remove extra spaces for banking case 1; use sample reference `ACC-1006` and explain the result

# %%
Account_Number='ACC-1006'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
re.sub(" ","",Account_Number)
# Out:
# Account Number: ACC-1006
# '123456789'

# %% [markdown]
# 7.Split a comma-separated tag list for banking case 1; use sample reference `ACC-1007` and explain the result.

# %%
Account_Number='ACC-1007'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(",",text)
# Out:
# Account Number: ACC-1007
# ['Savings', 'Premium', 'Active', 'Online']

# %% [markdown]
# 8.Check a phone number for banking case 1; use sample reference `ACC-1008` and explain the result.

# %%
Account_Number='ACC-1008'
print("Account Number:",Account_Number)
Mobile_Number=input("Enter Mobile Number:")
pattern=r"^\d{10}$"
if(re.findall(pattern,Mobile_Number)):
    print("Phone Number is valid")
else:
    print("Invalid Phone Number")
# Out:
# Account Number: ACC-1008
# Phone Number is valid

# %% [markdown]
# 9.Find fee waiver codes for banking case 1; use sample reference `ACC-1009` and explain the result.

# %%
Account_Number='ACC-1009'
print("Account Number:",Account_Number)
code=input("Enter code:")
pattern="[A-Z]+[0-9]+"
re.findall(pattern,code)
# Out:
# Account Number: ACC-1009
# ['ACC1005']

# %% [markdown]
# 10.Replace masked card digits for banking case 1; use sample reference `ACC-1010` and explain the result.

# %%
Account_Number='ACC-1010'
print("Account Number:",Account_Number)
Credit_Number=input("Enter credit number:")
re.sub("x","#",Credit_Number)
# Out:
# Account Number: ACC-1010
# '####-####-1025'

# %% [markdown]
# 11.Extract quantities for banking case 1; use sample reference `ACC-1011` and explain the result.

# %%
Account_Number='ACC-1011'
print("Account Number",Account_Number)
text=input("Enter text:")
pattern=r"\d+"
re.findall(pattern,text)
# Out:
# Account Number ACC-1011
# ['5', '10000', '2']

# %% [markdown]
# 12.Match branch ids for banking case 1; use sample reference `ACC-1012` and explain the result.

# %%
Account_Number='ACC-1012'
print("Account Number:",Account_Number)
Branch_id=input("Enter Branch Id:")
pattern="[A-Z]+-[0-9]+"
re.findall(pattern,Branch_id)
# Out:
# Account Number: ACC-1012
# ['SB-1025']

# %% [markdown]
# 13.Find email addresses for banking case 1; use sample reference `ACC-1013` and explain the result

# %%
Account_Number='ACC-1013'
print("Account Number:",Account_Number)
email=input("Enter email:")
pattern=r"^[a-z]+@[a-z]+\.[a-z]+$"
re.findall(pattern,email)
# Out:
# Account Number: ACC-1013
# ['saivignesh@gmail.com']

# %% [markdown]
# 14.Validate a postcode for banking case 1; use sample reference `ACC-1014` and explain the result.

# %%
Account_Number='ACC-1014'
print("Account Number:",Account_Number)
postal_code=input("Enter Postal code:")
pattern=r"^\d{6}$"
if(re.findall(pattern,postal_code)):
    print("Postal Code is valid")
else:
    print("Invalid Postal Code")
# Out:
# Account Number: ACC-1014
# Postal Code is valid

# %% [markdown]
# 15.Detect the word sale for banking case 1; use sample reference `ACC-1015` and explain the result.

# %%
Account_Number='ACC-1015'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern="sale" 
re.findall(pattern,text)
# Out:
# Account Number: ACC-1015
# ['sale']

# %% [markdown]
# 16.Find a account code for banking case 2; use sample reference `ACC-1016` and explain the result.

# %%
Account_Number='ACC-1016'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
pattern=r"^\d{11}$"
if(re.findall(pattern,Account_Number)):
    print("Valid Account Number")
else:
    print("Invalid account Number")
# Out:
# Account Number: ACC-1016
# Valid Account Number

# %% [markdown]
# 17.Validate a six-digit pin for banking case 2; use sample reference `ACC-1017` and explain the result.

# %%
Account_Number='ACC-1017'
print("Account Number:",Account_Number)
pattern=r"^\d{6}$"
pin=input("Enter pin:")
if(re.findall(pattern,pin)):
    print("Valid pin")
else:
    print("Invalid pin")
# Out:
# Account Number: ACC-1017
# Valid pin

# %% [markdown]
# 18.Extract all amounts for banking case 2; use sample reference `ACC-1018` and explain the result.

# %%
Account_Number='ACC-1018'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"₹\d+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1018
# ['₹10', '₹2', '₹50']

# %% [markdown]
# 19.Match a receipt date for banking case 2; use sample reference `ACC-1019` and explain the result.

# %%
Account_Number='ACC-1019'
print("Account Number:",Account_Number)
Date=input("Enter Receipt Date:")
pattern=r"[0-30]{2}-[0-12]{2}-\d{4}"
re.findall(pattern,Date)
# Out:
# Account Number: ACC-1019
# ['02-12-2005']

# %% [markdown]
# 20.Find uppercase account references for banking case 2; use sample reference `ACC-1020` and explain the result.

# %%
Account_Number="ACC-1020"
pattern=r"^[A-Z]+-\d+$"
re.findall(pattern,Account_Number)
# Out:
# ['ACC-1020']

# %% [markdown]
# 21.Remove extra spaces for banking case 2; use sample reference `ACC-1021` and explain the result.

# %%
Account_Number='ACC-1021'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
re.sub(" ","",Account_Number)
# Out:
# Account Number: ACC-1021
# '123546897'

# %% [markdown]
# 22. Split a comma-separated tag list for banking case 2; use sample reference `ACC-1022` and explain the result.

# %%
import re
Account_Number='ACC-1022'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(",",text)
# Out:
# Account Number: ACC-1022
# ['Savings', 'Premium', 'Active', 'Online']

# %% [markdown]
# 23.Check a phone number for banking case 2; use sample reference `ACC-1023` and explain the result.

# %%
Account_Number='ACC-1023'
print("Account Number:",Account_Number)
Mobile_Number=input("Enter Mobile Number:")
pattern=r"^\d{10}$"
if(re.findall(pattern,Mobile_Number)):
    print("Phone Number is valid")
else:
    print("Invalid Phone Number")
# Out:
# Account Number: ACC-1023
# Phone Number is valid

# %% [markdown]
# 24.Find fee waiver codes for banking case 2; use sample reference `ACC-1024` and explain the result.

# %%
Account_Number='ACC-1024'
print("Account Number:",Account_Number)
code=input("Enter code:")
pattern="[A-Z]+[0-9]+"
re.findall(pattern,code)
# Out:
# Account Number: ACC-1024
# ['SBI1256']

# %% [markdown]
# 25.Replace masked card digits for banking case 2; use sample reference `ACC-1025` and explain the result.

# %%
Account_Number='ACC-1025'
print("Account Number:",Account_Number)
Credit_Number=input("Enter credit number:")
re.sub("x","#",Credit_Number)
# Out:
# Account Number: ACC-1025
# '####-####-####-1256'

# %% [markdown]
# 26.Extract quantities for banking case 2; use sample reference `ACC-1026` and explain the result.

# %%
Account_Number='ACC-1026'
print("Account Number",Account_Number)
text=input("Enter text:")
pattern=r"\d+"
re.findall(pattern,text)
# Out:
# Account Number ACC-1026
# ['5', '10000', '2']

# %% [markdown]
# 27. Match branch ids for banking case 2; use sample reference `ACC-1027` and explain the result.

# %%
Account_Number='ACC-1027'
print("Account Number:",Account_Number)
Branch_id=input("Enter Branch Id:")
pattern="[A-Z]+-[0-9]+"
re.findall(pattern,Branch_id)
# Out:
# Account Number: ACC-1027
# ['APGB-1025']

# %% [markdown]
# 28.Find email addresses for banking case 2; use sample reference `ACC-1028` and explain the result.

# %%
Account_Number='ACC-1028'
print("Account Number:",Account_Number)
email=input("Enter email:")
pattern=r"^[a-z]+@[a-z]+\.[a-z]+$"
re.findall(pattern,email)
# Out:
# Account Number: ACC-1028
# ['abcfd@gmail.com']

# %% [markdown]
# 29.Validate a postcode for banking case 2; use sample reference `ACC-1029` and explain the result.

# %%
Account_Number='ACC-1029'
print("Account Number:",Account_Number)
postal_code=input("Enter Postal code:")
pattern=r"^\d{6}$"
if(re.findall(pattern,postal_code)):
    print("Postal Code is valid")
else:
    print("Invalid Postal Code")
# Out:
# Account Number: ACC-1029
# Postal Code is valid

# %% [markdown]
# 30.Detect the word sale for banking case 2; use sample reference `ACC-1030` and explain the result.

# %%
Account_Number='ACC-1030'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern="sale" 
re.findall(pattern,text)
# Out:
# Account Number: ACC-1030
# ['sale']

# %% [markdown]
# 31.Parse a receipt line into named groups for banking case 1; use sample reference `ACC-1031` and explain the result.

# %%
import re
Account_Number='ACC-1031'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-\d+|\d{2}-\d{2}-\d{4}| ₹\d+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1031
# ['TXN-1025', '17-09-2026', ' ₹5000']

# %% [markdown]
# 32.Validate an account reference with optional category prefix for banking case 1; use sample reference `ACC-1032` and explain the result.

# %%
Account_Number='ACC-1032'
print("Account Number:",Account_Number)
text=input("Enter Input:")
pattern1=r"[A-Z]+-\d+"
pattern2=r"[A-Z]+-[A-Z]+-\d+"
if(re.findall(r"[A-Z]{3}-[A-Z]{3}-\d{4}",text)):
    print("Category Prefix is present")
elif(re.findall(r"[A-Z]{3}-\d{4}",text)):
    print("Category prefix is not present")
# Out:
# Account Number: ACC-1032
# Category prefix is not present

# %% [markdown]
# 33.Extract currency and amount for banking case 1; use sample reference `ACC-1033` and explain the result.

# %%
Account_Number='ACC-1033'
print("Account Number:",Account_Number)
money=input("Enter Money:")
print("currency:",re.findall(r"[₹|$|€|£|INR]",money))
print("Money:",re.findall(r"\d+",money))
# Out:
# Account Number: ACC-1033
# currency: ['₹']
# Money: ['25614']

# %% [markdown]
# 34. Normalize account holder phone numbers for banking case 1; use sample reference `ACC-1034` and explain the result.

# %%
Account_Number="ACC-1034"
print("Account Number:",Account_Number)
Mobile_Number=input("Enter Mobile Number:")
re.sub("-","",Mobile_Number)
# Out:
# Account Number: ACC-1034
# '7993923714'

# %% [markdown]
# 35. Find repeated account words for banking case 1; use sample reference `ACC-1035` and explain the result.

# %%
Account_Number='ACC-1035'
print("Account Number:",Account_Number)
text=input("Enter Text:").lower()
b=re.findall(r"[a-z]+",text)
print(b)
c=len(b)
for i in range(len(b)):
    count=0
    for j in range(i+1,len(b)):
        if(b[i]==b[j]):
            count=count+1
            b[j]=""
    if(count > 0):
        print(b[i])
# Out:
# Account Number: ACC-1035
# ['transaction', 'transaction', 'failed', 'due', 'to', 'insufficient', 'balance', 'transaction', 'failed']
# transaction
#
# failed

# %% [markdown]
# 36.Validate fee waiver start and end anchors for banking case 1; use sample reference `ACC-1036` and explain the result.

# %%
Account_Number = 'ACC-1036'
print("Account Number:", Account_Number)
text = input("Enter Input: ")
if re.findall(r"^FEE-WAIVER.*FEE-WAIVER$", text):
    print("Valid")
else:
    print("Invalid")
# Out:
# Account Number: ACC-1036
# Valid

# %% [markdown]
# 37.Redact emails from support text for banking case 1; use sample reference `ACC-1037` and explain the result.

# %%
Account_Number='ACC-1037'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.sub(r"[a-z]+[0-9]*@[a-z]+\.[a-z]+","customer",text)
# Out:
# Account Number: ACC-1037
# 'Please contact customer regarding account ACC-1037'

# %% [markdown]
# 38.Extract transfer ids without partial matches for banking case 1; use sample reference `ACC-1038` and explain the result.

# %%
Account_Number='ACC-1038'
print("Account Number:",Account_Number)
text=input("Enter Transfer_id:")
pattern=r"[A-Z]+-[0-9]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1038
# ['TRF-1025']

# %% [markdown]
# 39.Parse inventory key-value pairs for banking case 1; use sample reference `ACC-1039` and explain the result.

# %%
Account_Number='ACC-1039'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(",",text)
# Out:
# Account Number: ACC-1039
# ['Account=ACC-1035', ' Balance=50000', ' Type=Savings']

# %% [markdown]
# 40.Use lookahead for strong fee waiver tokens for banking case 1; use sample reference `ACC-1040` and explain the result.

# %%
Account_Number='ACC-1040'
print("Account Number:",Account_Number)
text=input("Enter text:")
pattern1=r"WAIVER-\d+"
if(re.findall(pattern1,text)):
    print("Valid Token")
else:
    print("Invalid Token")
# Out:
# Account Number: ACC-1040
# Invalid Token

# %% [markdown]
# 41.Use negative lookahead to reject test account references for banking case 1; use sample reference `ACC-1041` and explain the result.

# %%
Account_Number='ACC-1041'
print("Account Number:",Account_Number)
text=input("Enter Text:")
if(re.findall(r"TEST",text)):
    print("Your Bank Account is rejected")
else:
    print("Your Bank Account is Accepted")
# Out:
# Account Number: ACC-1041
# Your Bank Account is rejected

# %% [markdown]
# 42. Extract account names between delimiters for banking case 1; use sample reference `ACC-1042` and explain the result.

# %%
Account_Number='ACC-1042'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.findall(r"[[a-z]+\s*[a-z]+]",text)
# Out:
# Account Number: ACC-1042
# ['[sai vignesh]', '[rahul kumar]']

# %% [markdown]
# 43.Replace dates with iso format for banking case 1; use sample reference `ACC-1043` and explain the result.

# %%
Account_Number="ACC-1043"
print("Account Number:",Account_Number)
text=input("Enter Date:")
c=re.split("-",text)
c.reverse()
d="-".join(c)
print(d)
# Out:
# Account Number: ACC-1043
# 2005-12-12

# %% [markdown]
# 44.Compile a reusable account pattern for banking case 1; use sample reference `ACC-1044` and explain the result.

# %%
Account_Number='ACC-1044'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-[0-9]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1044
# ['ACC-2050']

# %% [markdown]
# 45.Use case-insensitive matching for brand search for banking case 1; use sample reference `ACC-1045` and explain the result.

# %%
Account_Number='ACC-1045'
print("Account Number:",Account_Number)
text=input("Enter Text:").upper()
pattern=r"HDFC|SBI|APGB|UNION|CANARA|ICIC"
print(re.search(pattern,text))
# Out:
# Account Number: ACC-1045
# <re.Match object; span=(30, 34), match='HDFC'>

# %% [markdown]
# 46.Parse a receipt line into named groups for banking case 2; use sample reference `ACC-1046` and explain the result.

# %%
Account_Number='ACC-1046'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-\d+|\d{2}-\d{2}-\d{4}| ₹\d+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1046
# ['TXN-1025', '17-09-2026', ' ₹5000']

# %% [markdown]
# 47. Validate an account reference with optional category prefix for banking case 2; use sample reference `ACC-1047` and explain the result.

# %%
Account_Number='ACC-1047'
print("Account Number:",Account_Number)
text=input("Enter Input:")
pattern1=r"[A-Z]+-\d+"
pattern2=r"[A-Z]+-[A-Z]+-\d+"
if(re.findall(r"[A-Z]{3}-[A-Z]{3}-\d{4}",text)):
    print("Category Prefix is present")
elif(re.findall(r"[A-Z]{3}-\d{4}",text)):
    print("Category prefix is not present")
# Out:
# Account Number: ACC-1047
# Category Prefix is present

# %% [markdown]
# 48.Extract currency and amount for banking case 2; use sample reference `ACC-1048` and explain the result.

# %%
Account_Number='ACC-1048'
print("Account Number:",Account_Number)
money=input("Enter Money:")
print("currency:",re.findall(r"[₹|$|€|£|INR]",money))
print("Money:",re.findall(r"\d+",money))
# Out:
# Account Number: ACC-1048
# currency: ['$']
# Money: ['56000']

# %% [markdown]
# 49.Normalize account holder phone numbers for banking case 2; use sample reference `ACC-1049` and explain the result.

# %%
Account_Number="ACC-1049"
print("Account Number:",Account_Number)
Mobile_Number=input("Enter Mobile Number:")
re.sub("-","",Mobile_Number)
# Out:
# Account Number: ACC-1049
# '7999821717'

# %% [markdown]
# 50.Find repeated account words for banking case 2; use sample reference `ACC-1050` and explain the result.

# %%
Account_Number='ACC-1050'
print("Account Number:",Account_Number)
text=input("Enter Text:").lower()
b=re.findall(r"[a-z]+",text)
print(b)
c=len(b)
for i in range(len(b)):
    count=0
    for j in range(i+1,len(b)):
        if(b[i]==b[j]):
            count=count+1
            b[j]=""
    if(count > 0):
        print(b[i])
# Out:
# Account Number: ACC-1050
# ['account', 'account', 'holder', 'requested', 'an', 'account', 'statement']
# account

# %% [markdown]
# 51.Validate fee waiver start and end anchors for banking case 2; use sample reference `ACC-1051` and explain the result.

# %%
Account_Number = 'ACC-1051'
print("Account Number:", Account_Number)
text = input("Enter Input: ")
if re.findall(r"^FEE-WAIVER.*FEE-WAIVER$", text):
    print("Valid")
else:
    print("Invalid")
# Out:
# Account Number: ACC-1051
# Valid

# %% [markdown]
# 52. Redact emails from support text for banking case 2; use sample reference `ACC-1052` and explain the result.

# %%
Account_Number='ACC-1052'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.sub(r"[a-z]+[0-9]*@[a-z]+\.[a-z]+","customer",text)
# Out:
# Account Number: ACC-1052
# 'customer'

# %% [markdown]
# 53.Extract transfer ids without partial matches for banking case 2; use sample reference `ACC-1053` and explain the result.

# %%
Account_Number='ACC-1053'
print("Account Number:",Account_Number)
text=input("Enter Transfer_id:")
pattern=r"[A-Z]+-[0-9]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1053
# ['SBI-2025']

# %% [markdown]
# 54.Parse inventory key-value pairs for banking case 2; use sample reference `ACC-1054` and explain the result.

# %%
Account_Number='ACC-1054'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(",",text)
# Out:
# Account Number: ACC-1054
# ['Account=ACC-1035', 'Type=Savings', ' Balance=25000;', 'Status=Active']

# %% [markdown]
# 55. Use lookahead for strong fee waiver tokens for banking case 2; use sample reference `ACC-1055` and explain the result.

# %%
Account_Number='ACC-1055'
print("Account Number:",Account_Number)
text=input("Enter text:")
pattern1=r"WAIVER-\d+"
if(re.findall(pattern1,text)):
    print("Valid Token")
else:
    print("Invalid Token")
# Out:
# Account Number: ACC-1055
# Valid Token

# %% [markdown]
# 56.Use negative lookahead to reject test account references for banking case 2; use sample reference `ACC-1056` and explain the result.

# %%
Account_Number='ACC-1056'
print("Account Number:",Account_Number)
text=input("Enter Text:")
if(re.findall(r"TEST",text)):
    print("Your Bank Account is rejected")
else:
    print("Your Bank Account is Accepted")
# Out:
# Account Number: ACC-1056
# Your Bank Account is Accepted

# %% [markdown]
# 57.Extract account names between delimiters for banking case 2; use sample reference `ACC-1057` and explain the result.

# %%
Account_Number='ACC-1057'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.findall(r"[[a-z]+\s*[a-z]+]",text)
# Out:
# Account Number: ACC-1057
# ['[sai]', '[kartheek]']

# %% [markdown]
# 58.Replace dates with iso format for banking case 2; use sample reference `ACC-1058` and explain the result.

# %%
Account_Number="ACC-1058"
print("Account Number:",Account_Number)
text=input("Enter Date:")
c=re.split("-",text)
c.reverse()
d="-".join(c)
print(d)
# Out:
# Account Number: ACC-1058
# 2004-11-15

# %% [markdown]
# 59.Compile a reusable account pattern for banking case 2; use sample reference `ACC-1059` and explain the result.

# %%
Account_Number='ACC-1059'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-[0-9]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1059
# ['SBI-2027']

# %% [markdown]
# 60.Use case-insensitive matching for brand search for banking case 2; use sample reference `ACC-1060` and explain the result.

# %%
Account_Number='ACC-1060'
print("Account Number:",Account_Number)
text=input("Enter Text:").upper()
pattern=r"HDFC|SBI|APGB|UNION|CANARA|ICIC"
print(re.search(pattern,text))
# Out:
# Account Number: ACC-1060
# <re.Match object; span=(29, 33), match='HDFC'>

# %% [markdown]
# 61.Parse a receipt line into named groups for banking case 3; use sample reference `ACC-1061` and explain the result.

# %%
Account_Number='ACC-1061'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-\d+|\d{2}-\d{2}-\d{4}| ₹\d+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1061
# ['SBI-2027', '12-05-2114', ' ₹2569']

# %% [markdown]
# 62.Validate an account reference with optional category prefix for banking case 3; use sample reference `ACC-1062` and explain the result.

# %%
Account_Number='ACC-1062'
print("Account Number:",Account_Number)
text=input("Enter Input:")
pattern1=r"[A-Z]+-\d+"
pattern2=r"[A-Z]+-[A-Z]+-\d+"
if(re.findall(r"[A-Z]{3}-[A-Z]{3}-\d{4}",text)):
    print("Category Prefix is present")
elif(re.findall(r"[A-Z]{3}-\d{4}",text)):
    print("Category prefix is not present")
# Out:
# Account Number: ACC-1062
# Category prefix is not present

# %% [markdown]
# 63.Extract currency and amount for banking case 3; use sample reference `ACC-1063` and explain the result.

# %%
Account_Number='ACC-1063'
print("Account Number:",Account_Number)
money=input("Enter Money:")
print("currency:",re.findall(r"[₹|$|€|£|INR]",money))
print("Money:",re.findall(r"\d+",money))
# Out:
# Account Number: ACC-1063
# currency: ['$']
# Money: ['125478']

# %% [markdown]
# 64.Normalize account holder phone numbers for banking case 3; use sample reference `ACC-1064` and explain the result.

# %%
Account_Number="ACC-1064"
print("Account Number:",Account_Number)
Mobile_Number=input("Enter Mobile Number:")
re.sub("-","",Mobile_Number)
# Out:
# Account Number: ACC-1064
# '1236523256'

# %% [markdown]
# 65.Find repeated account words for banking case 3; use sample reference `ACC-1065` and explain the result.

# %%
Account_Number='ACC-1065'
print("Account Number:",Account_Number)
text=input("Enter Text:").lower()
b=re.findall(r"[a-z]+",text)
print(b)
c=len(b)
for i in range(len(b)):
    count=0
    for j in range(i+1,len(b)):
        if(b[i]==b[j]):
            count=count+1
            b[j]=""
    if(count > 0):
        print(b[i])
# Out:
# Account Number: ACC-1065
# ['abd', 'is', 'doing', 'assignment', 'edukron', 'assignment']
# assignment

# %% [markdown]
# 66.Validate fee waiver start and end anchors for banking case 3; use sample reference `ACC-1066` and explain the result.

# %%
Account_Number = 'ACC-1066'
print("Account Number:", Account_Number)
text = input("Enter Input: ")
if re.findall(r"^FEE-WAIVER.*FEE-WAIVER$", text):
    print("Valid")
else:
    print("Invalid")
# Out:
# Account Number: ACC-1066
# Valid

# %% [markdown]
# 67.Redact emails from support text for banking case 3; use sample reference `ACC-1067` and explain the result.

# %%
Account_Number='ACC-1067'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.sub(r"[a-z]+[0-9]*@[a-z]+\.[a-z]+","customer",text)
# Out:
# Account Number: ACC-1067
# 'customer'

# %% [markdown]
# 68.Extract transfer ids without partial matches for banking case 3; use sample reference `ACC-1068` and explain the result.

# %%
Account_Number='ACC-1068'
print("Account Number:",Account_Number)
text=input("Enter Transfer_id:")
pattern=r"[A-Z]+-[0-9]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1068
# ['SCI-1457']

# %% [markdown]
# 69.Parse inventory key-value pairs for banking case 3; use sample reference `ACC-1069` and explain the result.

# %%
Account_Number='ACC-1069'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(",",text)
# Out:
# Account Number: ACC-1069
# ['Account=ACC-1035', ' Balance=50000', ' Type=Savings']

# %% [markdown]
# 70.Use lookahead for strong fee waiver tokens for banking case 3; use sample reference `ACC-1070` and explain the result.

# %%
Account_Number='ACC-1070'
print("Account Number:",Account_Number)
text=input("Enter text:")
pattern1=r"WAIVER-\d+"
if(re.findall(pattern1,text)):
    print("Valid Token")
else:
    print("Invalid Token")
# Out:
# Account Number: ACC-1070
# Invalid Token

# %% [markdown]
# 71.Tokenize a messy receipt safely for banking case 1; use sample reference `ACC-1071` and explain the result.

# %%
Account_Number='ACC-1071'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(" ",text)
# Out:
# Account Number: ACC-1071
# ['Customer_Name:abg',
#  'Account_Number:ACC-1035',
#  'Transaction_ID:TRF-20260917',
#  'Amount:₹5,000',
#  'Date:17/09/2026',
#  'Transaction_Type:FundTransfer']

# %% [markdown]
# 72.Validate a multi-part warehouse location for banking case 1; use sample reference `ACC-1072` and explain the result.

# %%
Account_Number='ACC-1072'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-[A-Z]+-[A-Z]+-\d{6}"
if(re.findall(pattern,text)):
    print("Valid")
else:
    print("Invalid")
# Out:
# Account Number: ACC-1072
# Invalid

# %% [markdown]
# 73.Extract nested-looking account annotations within a defined limit for banking case 1; use sample reference `ACC-1073` and explain the result.

# %%
Account_Number='ACC-1073'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[[A-Z]+-\d+]"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1073
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5664\2531797273.py:5: FutureWarning: Possible nested set at position 1
#   re.findall(pattern,text)
# ['[ACC-1035]']

# %% [markdown]
# 74.Find duplicate adjacent account reference tokens with backreferences for banking case 1; use sample reference `ACC-1074` and explain the result.

# %%
import re
Account_Number = 'ACC-1074'
print("Account Number:", Account_Number)
text = input("Enter Text: ")
pattern = r'\b(ACC-\d{4})\s+\1\b'
if re.findall(pattern, text):
    print("Duplicate Adjacent Record")
else:
    print("No Duplicate Adjacent Record")
# Out:
# Account Number: ACC-1074
# Duplicate Adjacent Record

# %% [markdown]
# 75.Redact card-like numbers while preserving last four digits for banking case 1; use sample reference `ACC-1075` and explain the result.

# %%
Account_Number='ACC-1075'
print("Account Number:",Account_Number)
card_number=input("Enter Card Number:")
re.sub('1234-5678-1234-7890','****-****-****-7890',card_number)
# Out:
# Account Number: ACC-1075
# '****-****-****-7890'

# %% [markdown]
# 76.Parse audit log entries with named groups for banking case 1; use sample reference `ACC-1076` and explain the result.

# %%
Account_Number='ACC-1076'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern1=r"\d{4}-\d{2}-\d{2}"
pattern2=r"\d{2}:\d{2}:\d{2}"
pattern3=r"[a-z]+\d+"
pattern4=r"[A-Z]+"
pattern5=r"[A-Z]+-\d+"
print("Date:",re.findall(pattern1,text))
print("Time:",re.findall(pattern2,text))
print("user:",re.findall(pattern3,text))
print("action:",re.findall(pattern4,text))
print("account:",re.findall(pattern5,text))
# Out:
# Account Number: ACC-1076
# Date: ['2026-09-17']
# Time: ['14:30:25']
# user: ['admin01']
# action: ['LOGIN', 'ACC']
# account: ['ACC-1035']

# %% [markdown]
# 77.Build a verbose-mode pattern for account holder ids for banking case 1; use sample reference `ACC-1077` and explain the result.

# %%
Account_Number='ACC-1077'
print("Account Number:",Account_Number)
text=input("Enter Holder Id:")
pattern=r"[A-Z]+-[A-Z]+-[0-9]+-[A-Z]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1077
# ['HOLDER-ABC-1234-IN']

# %% [markdown]
# 78.Avoid catastrophic backtracking in a interest offer pattern for banking case 1; use sample reference `ACC-1078` and explain the result.

# %%
Account_Number='ACC-1078'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"\d+\.\d*%"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1078
# ['7.5%']

# %% [markdown]
# 79.Validate amount formats across supported currencies for banking case 1; use sample reference `ACC-1079` and explain the result.

# %%
Account_Number='ACC-1079'
print("Account Number:",Account_Number)
text=input("Enter Money:")
pattern=r"[$\d+|₹\d+ |€\d+]"
if(re.findall(pattern,text)):
    print("Valid Amount")
else:
    print("Invalid Amount")
# Out:
# Account Number: ACC-1079
# Valid Amount

# %% [markdown]
# 80.Create a regex-based data quality report for banking case 1; use sample reference `ACC-1080` and explain the result.

# %%
import re
Account_Number='ACC-1080'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
email=input("Enter Email:")
Mobile_Number=input("Enter Mobile Number:")
pattern1=r"[A-Z]+-[0-9]+"
pattern2=r"[a-z]+[0-9]*@[a-z]+\.[a-z]+"
pattern3=r"\d{10}"
if(re.findall(pattern1,Account_Number)):
    print("Account Number is correct")
else:
    print("Account Number is Incorrect")
if(re.findall(pattern2,email)):
    print("Email is Correct")
else:
    print("Email is Incorrect")
if(re.findall(pattern3,Mobile_Number)):
    print("Mobile Number is Correct")
else:
    print("Mobile Number is Incorrect")
# Out:
# Account Number: ACC-1080
# Account Number is correct
# Email is Correct
# Mobile Number is Correct

# %% [markdown]
# 81.Tokenize a messy receipt safely for banking case 2; use sample reference `ACC-1081` and explain the result.

# %%
Account_Number='ACC-1081'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(" ",text)
# Out:
# Account Number: ACC-1081
# ['Customer_Name:abc',
#  'Account_Number:ACC-1035',
#  'Transaction_ID:TRF-20260917',
#  'Amount:₹5,000',
#  'Date:17/09/2026',
#  'Transaction_Type:FundTransfer']

# %% [markdown]
# 82.Validate a multi-part warehouse location for banking case 2; use sample reference `ACC-1082` and explain the result.

# %%
Account_Number='ACC-1082'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-[A-Z]+-[A-Z]+-\d{6}"
if(re.findall(pattern,text)):
    print("Valid")
else:
    print("Invalid")
# Out:
# Account Number: ACC-1082
# Valid

# %% [markdown]
# 83. Extract nested-looking account annotations within a defined limit for banking case 2; use sample reference `ACC-1083` and explain the result.

# %%
Account_Number='ACC-1083'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[[A-Z]+-\d+]"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1083
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11276\3344133402.py:5: FutureWarning: Possible nested set at position 1
#   re.findall(pattern,text)
# ['[ACC-1035]']

# %% [markdown]
# 84.Find duplicate adjacent account reference tokens with backreferences for banking case 2; use sample reference `ACC-1084` and explain the result.

# %%
import re
Account_Number = 'ACC-1084'
print("Account Number:", Account_Number)
text = input("Enter Text: ")
pattern = r'\b(ACC-\d{4})\s+\1\b'
if re.findall(pattern, text):
    print("Duplicate Adjacent Record")
else:
    print("No Duplicate Adjacent Record")
# Out:
# Account Number: ACC-1084
# No Duplicate Adjacent Record

# %% [markdown]
# 85.Redact card-like numbers while preserving last four digits for banking case 2; use sample reference `ACC-1085` and explain the result.

# %%
Account_Number='ACC-1085'
print("Account Number:",Account_Number)
card_number=input("Enter Card Number:")
re.sub('1234-5678-1234-7890','****-****-****-7890',card_number)
# Out:
# Account Number: ACC-1085
# '****-****-****-7890'

# %% [markdown]
# 86.Parse audit log entries with named groups for banking case 2; use sample reference `ACC-1086` and explain the result.

# %%
Account_Number='ACC-1086'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern1=r"\d{4}-\d{2}-\d{2}"
pattern2=r"\d{2}:\d{2}:\d{2}"
pattern3=r"[a-z]+\d+"
pattern4=r"[A-Z]+"
pattern5=r"[A-Z]+-\d+"
print("Date:",re.findall(pattern1,text))
print("Time:",re.findall(pattern2,text))
print("user:",re.findall(pattern3,text))
print("action:",re.findall(pattern4,text))
print("account:",re.findall(pattern5,text))
# Out:
# Account Number: ACC-1086
# Date: ['2026-09-17']
# Time: ['14:30:25']
# user: ['admin01']
# action: ['LOGIN', 'ACC']
# account: ['ACC-1035']

# %% [markdown]
# 87. Build a verbose-mode pattern for account holder ids for banking case 2; use sample reference `ACC-1087` and explain the result.

# %%
Account_Number='ACC-1087'
print("Account Number:",Account_Number)
text=input("Enter Holder Id:")
pattern=r"[A-Z]+-[A-Z]+-[0-9]+-[A-Z]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1087
# ['HOLDER-ABC-1234-IN']

# %% [markdown]
# 88.Avoid catastrophic backtracking in a interest offer pattern for banking case 2; use sample reference `ACC-1088` and explain the result.

# %%
Account_Number='ACC-1088'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"\d+\.\d*%"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1088
# ['7.5%']

# %% [markdown]
# 89.Validate amount formats across supported currencies for banking case 2; use sample reference `ACC-1089` and explain the result.

# %%
Account_Number='ACC-1089'
print("Account Number:",Account_Number)
text=input("Enter Money:")
pattern=r"[$\d+|₹\d+ |€\d+]"
if(re.findall(pattern,text)):
    print("Valid Amount")
else:
    print("Invalid Amount")
# Out:
# Account Number: ACC-1089
# Valid Amount

# %% [markdown]
# 90.Create a regex-based data quality report for banking case 2; use sample reference `ACC-1090` and explain the result.

# %%
import re
Account_Number='ACC-1090'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
email=input("Enter Email:")
Mobile_Number=input("Enter Mobile Number:")
pattern1=r"[A-Z]+-[0-9]+"
pattern2=r"[a-z]+[0-9]*@[a-z]+\.[a-z]+"
pattern3=r"\d{10}"
if(re.findall(pattern1,Account_Number)):
    print("Account Number is correct")
else:
    print("Account Number is Incorrect")
if(re.findall(pattern2,email)):
    print("Email is Correct")
else:
    print("Email is Incorrect")
if(re.findall(pattern3,Mobile_Number)):
    print("Mobile Number is Correct")
else:
    print("Mobile Number is Incorrect")
# Out:
# Account Number: ACC-1090
# Account Number is correct
# Email is Correct
# Mobile Number is Correct

# %% [markdown]
# 91.Tokenize a messy receipt safely for banking case 3; use sample reference `ACC-1091` and explain the result.

# %%
Account_Number='ACC-1091'
print("Account Number:",Account_Number)
text=input("Enter Text:")
re.split(" ",text)
# Out:
# Account Number: ACC-1091
# ['Customer_Name:abcd',
#  'Account_Number:ACC-1035',
#  'Transaction_ID:TRF-20260917',
#  'Amount:₹5,000',
#  'Date:17/09/2026',
#  'Transaction_Type:FundTransfer']

# %% [markdown]
# 92.Validate a multi-part warehouse location for banking case 3; use sample reference `ACC-1092` and explain the result.

# %%
Account_Number='ACC-1092'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[A-Z]+-[A-Z]+-[A-Z]+-\d{6}"
if(re.findall(pattern,text)):
    print("Valid")
else:
    print("Invalid")
# Out:
# Account Number: ACC-1092
# Valid

# %% [markdown]
# 93.Extract nested-looking account annotations within a defined limit for banking case 3; use sample reference `ACC-1093` and explain the result.

# %%
Account_Number='ACC-1093'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"[[A-Z]+-\d+]"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1093
# ['[ACC-1035]']

# %% [markdown]
# 94.Find duplicate adjacent account reference tokens with backreferences for banking case 3; use sample reference `ACC-1094` and explain the result.

# %%
import re
Account_Number = 'ACC-1094'
print("Account Number:", Account_Number)
text = input("Enter Text: ")
pattern = r'\b(ACC-\d{4})\s+\1\b'
if re.findall(pattern, text):
    print("Duplicate Adjacent Record")
else:
    print("No Duplicate Adjacent Record")
# Out:
# Account Number: ACC-1094
# No Duplicate Adjacent Record

# %% [markdown]
# 95.Redact card-like numbers while preserving last four digits for banking case 3; use sample reference `ACC-1095` and explain the result.

# %%
Account_Number='ACC-1095'
print("Account Number:",Account_Number)
card_number=input("Enter Card Number:")
re.sub('1234-5678-1234-7890','****-****-****-7890',card_number)
# Out:
# Account Number: ACC-1095
# '****-****-****-7890'

# %% [markdown]
# 96.Parse audit log entries with named groups for banking case 3; use sample reference `ACC-1096` and explain the result.

# %%
Account_Number='ACC-1096'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern1=r"\d{4}-\d{2}-\d{2}"
pattern2=r"\d{2}:\d{2}:\d{2}"
pattern3=r"[a-z]+\d+"
pattern4=r"[A-Z]+"
pattern5=r"[A-Z]+-\d+"
print("Date:",re.findall(pattern1,text))
print("Time:",re.findall(pattern2,text))
print("user:",re.findall(pattern3,text))
print("action:",re.findall(pattern4,text))
print("account:",re.findall(pattern5,text))
# Out:
# Account Number: ACC-1096
# Date: ['2026-09-17']
# Time: ['14:30:25']
# user: ['admin01']
# action: ['LOGIN', 'ACC']
# account: ['ACC-1035']

# %% [markdown]
# 97.Build a verbose-mode pattern for account holder ids for banking case 3; use sample reference `ACC-1097` and explain the result.

# %%
Account_Number='ACC-1097'
print("Account Number:",Account_Number)
text=input("Enter Holder Id:")
pattern=r"[A-Z]+-[A-Z]+-[0-9]+-[A-Z]+"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1097
# ['HOLDER-ABC-1234-IN']

# %% [markdown]
# 98.Avoid catastrophic backtracking in a interest offer pattern for banking case 3; use sample reference `ACC-1098` and explain the result.

# %%
Account_Number='ACC-1098'
print("Account Number:",Account_Number)
text=input("Enter Text:")
pattern=r"\d+\.\d*%"
re.findall(pattern,text)
# Out:
# Account Number: ACC-1098
# ['7.5%']

# %% [markdown]
# 99.Validate amount formats across supported currencies for banking case 3; use sample reference `ACC-1099` and explain the result.

# %%
Account_Number='ACC-1099'
print("Account Number:",Account_Number)
text=input("Enter Money:")
pattern=r"[$\d+|₹\d+ |€\d+]"
if(re.findall(pattern,text)):
    print("Valid Amount")
else:
    print("Invalid Amount")
# Out:
# Account Number: ACC-1099
# Valid Amount

# %% [markdown]
# 100.Create a regex-based data quality report for banking case 3; use sample reference `ACC-1100` and explain the result.

# %%
import re
Account_Number='ACC-1100'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
email=input("Enter Email:")
Mobile_Number=input("Enter Mobile Number:")
pattern1=r"[A-Z]+-[0-9]+"
pattern2=r"[a-z]+[0-9]*@[a-z]+\.[a-z]+"
pattern3=r"\d{10}"
if(re.findall(pattern1,Account_Number)):
    print("Account Number is correct")
else:
    print("Account Number is Incorrect")
if(re.findall(pattern2,email)):
    print("Email is Correct")
else:
    print("Email is Incorrect")
if(re.findall(pattern3,Mobile_Number)):
    print("Mobile Number is Correct")
else:
    print("Mobile Number is Incorrect")
# Out:
# Account Number: ACC-1100
# Account Number is correct
# Email is Correct
# Mobile Number is Correct
