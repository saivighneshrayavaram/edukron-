# %% [markdown]
# 1.Create a account class for banking case 1; use sample reference `ACC-1001` and explain the result.

# %%
Account_Number='ACC-1001'
print("Account_Number:",Account_Number)
account_holder_name=input("Enter Name")
balance=int(input("Enter Balance:"))
account_type=input("Enter Account Type:")
Mobile_Number=int(input("Enter Mobile Number:"))
class Banking:
    def __init__(self,account_holder_name,account_number,balance,account_type,Mobile_Number):
        self.account_holder_name=account_holder_name
        self.account_number=account_number
        self.balance=balance
        self.account_type=account_type
        self.Mobile_Number=Mobile_Number
    def show_details(self):
        print("Name:",self.account_holder_name)
        print("Account_Number:",self.account_number)
        print("Balance:",self.balance)
        print("Account Type:",self.account_type)
        print("Mobile Number:",self.Mobile_Number)
b1=Banking(account_holder_name,Account_Number,balance,account_type,Mobile_Number)
b1.show_details()
# Out:
# Account_Number: ACC-1001
# Name: Rayavaram Sai Vighnesh
# Account_Number: ACC-1001
# Balance: 50200
# Account Type: Savings
# Mobile Number: 7993921717

# %% [markdown]
# 2. Add an initializer to accountholder for banking case 1; use sample reference `ACC-1002` and explain the result.

# %%
Account_Number='ACC-1002'
print("Account Number:",Account_Number)
account_holder_name=input("Enter Name")
balance=int(input("Enter Balance:"))
account_type=input("Enter Account Type:")
Mobile_Number=int(input("Enter Mobile Number:"))
class Banking:
    def __init__(self,account_holder_name,account_number,balance,account_type,Mobile_Number):
        self.account_holder_name=account_holder_name
        self.account_number=account_number
        self.balance=balance
        self.account_type=account_type
        self.Mobile_Number=Mobile_Number
    def show_details(self):
        print("Name:",self.account_holder_name)
        print("Account_Number:",self.account_number)
        print("Balance:",self.balance)
        print("Account Type:",self.account_type)
        print("Mobile Number:",self.Mobile_Number)
b1=Banking(account_holder_name,Account_Number,balance,account_type,Mobile_Number)
b1.show_details()
# Out:
# Account Number: ACC-1002
# Name: Rayavaram Sai Vighnesh
# Account_Number: ACC-1002
# Balance: 52000
# Account Type: Savings
# Mobile Number: 7993921717

# %% [markdown]
# 3.Represent an transfer object for banking case 1; use sample reference `ACC-1003` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1003'
print("Account_Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
    def show_details(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
        print("Transfer Amount:",self.Transfer_Amount)
        try:
            if(Transfer_Amount > sender_Balance):
                raise Exception("Transaction Status: Failed")
        except Exception as e:
            print(e)
        else:
            print("Transaction Status: Success")
b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount)
b1.show_details()
# Out:
# Account_Number: ACC-1003
# Transfer_id: TR-1023
# Sender_Account_Number: 456987
# Receiver_Account_Number: 321456
# Sender Balance: 56000
# Transfer Date: 2026-09-06
# Transfer Amount: 21000
# Transaction Status: Success

# %% [markdown]
# 4. Add a method that calculates line total for banking case 1; use sample reference `ACC-1004` and explain the result.

# %%
Account_Number='ACC-1004'
print("Account Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self.Transaction_Fee=Transaction_Fee
    def show_details(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
    def add_transaction_fee(self):
        transaction_Fee=self.Transfer_Amount*self.Transaction_Fee/100
        self.Transfer_Amount = self.Transfer_Amount+transaction_Fee
        print("Transfer_Amount:",self.Transfer_Amount)

b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.show_details()
b1.add_transaction_fee()
# Out:
# Account Number: ACC-1004
# Transfer_id: TR-1001
# Sender_Account_Number: 456123
# Receiver_Account_Number: 456789
# Sender Balance: 52000
# Transfer Date: 2026-09-06
# Transfer_Amount: 12546.0

# %% [markdown]
# 5. Use a class attribute for branch name for banking case 1; use sample reference `ACC-1005` and explain the result.

# %%
Account_Number='ACC-1005'
print("Account Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self.Transaction_Fee=Transaction_Fee
    def show_details(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
    def add_transaction_fee(self):
        transaction_Fee=self.Transfer_Amount*self.Transaction_Fee/100
        self.Transfer_Amount = self.Transfer_Amount+transaction_Fee
        print("Transfer_Amount:",self.Transfer_Amount)

b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.show_details()
b1.add_transaction_fee()
# Out:
# Account Number: ACC-1005
# Transfer_id: TR-1001
# Sender_Account_Number: 456123
# Receiver_Account_Number: 456789
# Sender Balance: 52000
# Transfer Date: 2026-09-06
# Transfer_Amount: 12625.0

# %% [markdown]
# 6.Write a readable __str__ method for banking case 1; use sample reference `ACC-1006` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1006'
print("Account Number:",Account_Number)
print("Account Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self.Transaction_Fee=Transaction_Fee
    def add_transaction_fee(self):
        transaction_Fee=self.Transfer_Amount*self.Transaction_Fee/100
        self.Transfer_Amount = self.Transfer_Amount+transaction_Fee
    def __str__(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
        print("Transfer_Amount:",self.Transfer_Amount)
        try:
            if(Transfer_Amount > self.sender_balance):
                raise Exception("Transaction Status:Failure")
        except Exception as e:
            print(e)
        else:
            print("Transaction Status:Success")
b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.add_transaction_fee()
b1.__str__()
# Out:
# Account Number: ACC-1006
# Account Number: ACC-1006
# Transfer_id: TR-12350
# Sender_Account_Number: 456321
# Receiver_Account_Number: 789456
# Sender Balance: 52000
# Transfer Date: 2026-09-06
# Transfer_Amount: 14140.0
# Transaction Status:Success

# %% [markdown]
# 7.Compare two account references with __eq__ for banking case 1; use sample reference `ACC-1007` and explain the result.

# %%
Account_Number='ACC-1007'
print("Account Number:",Account_Number)
Account_number=input("Enter Account Number:")
Account_Number1=input("Enter Account Number:")
class Banking:
    def __init__(self,Account_number):
        self.Account_number=Account_number
    def acc(self):
        print("Account Number:",self.Account_number)
b1=Banking(Account_number)
b1.acc()
b2=Banking(Account_Number1)
b2.acc()
print(b1.Account_number.__eq__(b2.Account_number))
# Out:
# Account Number: ACC-1007
# Account Number: acc-1001
# Account Number: acc-1001
# True

# %% [markdown]
# 8.Protect a amount with a property for banking case 1; use sample reference `ACC-1008` and explain the result.

# %%
Account_Number='ACC-1008'
print("Account Number:",Account_Number)
from datetime import date
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self._sender_account_number=sender_account_number
        self._receiver_account_number=receiver_account_number
        self._sender_balance=sender_balance
        self._Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self._Transaction_Fee=Transaction_Fee
    def add_transaction_fee(self):
        transaction_Fee=self._Transfer_Amount*self._Transaction_Fee/100
        self._Transfer_Amount = self._Transfer_Amount+transaction_Fee
    def __str__(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self._sender_account_number)
        print("Receiver_Account_Number:",self._receiver_account_number)
        print("Sender Balance:",self._sender_balance)
        print("Transfer Date:",self.Transfer_Date)
        print("Transfer_Amount:",self._Transfer_Amount)
        try:
            if(Transfer_Amount > self.sender_balance):
                raise Exception("Transaction Status:Failure")
        except Exception as e:
            print(e)
        else:
            print("Transaction Status:Success")
b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.add_transaction_fee()
b1.__str__()
# Out:
# Account Number: ACC-1008
# Transfer_id: TR-1001
# Sender_Account_Number: 123456
# Receiver_Account_Number: 789654
# Sender Balance: 250000
# Transfer Date: 2026-09-06
# Transfer_Amount: 176750.0
# 'Banking' object has no attribute 'sender_balance'

# %% [markdown]
# 9.Create portfolio and add_item for banking case 1; use sample reference `ACC-1009` and explain the result.

# %%
Account_Number='ACC-1009'
print("Account Number:",Account_Number)
class Portfolio:
    def __init__(self,Account_holder_name,Account_Number,IFSC_code,Mobile_Number,Place,balance):
        self.Account_holder_Name=Account_holder_name
        self.Account_Number=Account_Number
        self.IFSC_code=IFSC_code
        self.Mobile_Number=Mobile_Number
        self.place=Place
        self.balance=balance
    def add_item(self):
        print("Customer Name:",self.Account_holder_Name)
        print("Account Number:",self.Account_Number)
        print("IFSC Code:",self.IFSC_code)
        print("Mobile Number:",self.Mobile_Number)
        print("Place:",self.place)
        print("Balance:",self.balance)
account_holder_name=input("Enter Account Holder Name:")
Account_number=input("Enter Account Number:")
IFSC_code=input("Enter IFSC Code:")
Mobile_Number=int(input("Enter Mobile Number:"))
place=input("Enter Place:")
balance=int(input("Enter Balanace:"))
p1=Portfolio(account_holder_name,Account_number,IFSC_code,Mobile_Number,place,balance)
p1.add_item()
# Out:
# Account Number: ACC-1009
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 456987123012
# IFSC Code: SBI214563987
# Mobile Number: 7993921717
# Place: Vempalli
# Balance: 78200

# %% [markdown]
# 10.Model a branchaddress for banking case 1; use sample reference `ACC-1010` and explain the result.

# %%
Account_Number='ACC-1010'
print("Account Number:",Account_Number)
class BranchAddress:
    def __init__(self,Building_Number,Street_Name,City,State,PINCODE):
        self.Building_Number=Building_Number
        self.Street_Name=Street_Name
        self.City=City
        self.State=State
        self.pincode=PINCODE
    def Address(self):
        print("DOOR NUMBER:",self.Building_Number)
        print("Street:",self.Street_Name)
        print("City:",self.City)
        print("State:",self.State)
        print("Pincode:",self.pincode)
Building_Number=input("Enter Door Number:")
Street_Name=input("Enter Street Name:")
City=input("Enter City:")
State=input("Enter State:")
Pincode=int(input("Enter Pincode:"))
b1=BranchAddress(Building_Number,Street_Name,City,State,Pincode)
b1.Address()
# Out:
# Account Number: ACC-1010
# DOOR NUMBER: 12/526-F3
# Street: Pulivendula Road
# City: Vempalli
# State: Andhra Pradesh
# Pincode: 516329

# %% [markdown]
# 11.Use a static method to validate account reference for banking case 1; use sample reference `ACC-1011` and explain the result.

# %%
Account_mumber='ACC-1011'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
class Banking:
    def __init__(self,Account_Number):
        self.Account_Number=Account_Number
    @staticmethod
    def Validate():
        try:
            if(not Account_Number.isnumeric()):
                raise Exception("Invalid Account Number")
        except Exception as e:
            print(e)
        else:
            print("Valid Account Number")
b1=Banking(Account_Number)
Banking.Validate()
# Out:
# Account Number: 1425367890
# Valid Account Number

# %% [markdown]
# 12.Use a class method as an alternate constructor for banking case 1; use sample reference `ACC-1012` and explain the result.

# %%
Account_Number='ACC-1012'
print("Account Number:",Account_Number)
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_details(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Account Type:",self.Account_Type)
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
b1=Banking("Rayavaram",1234569870,56000,"Savings")
b2=Banking("Rayavaram Sai",1236547890,57800,"Current")
b1.show_details()
b2.show_details()
# Out:
# Account Number: ACC-1012
# Customer Name: Rayavaram
# Account Number: 1234569870
# Balance: 56000
# Account Type: Savings
# Customer Name: Rayavaram Sai
# Account Number: 1236547890
# Balance: 57800
# Account Type: Current

# %% [markdown]
# 13.Track object count for banking case 1; use sample reference `ACC-1013` and explain the result.

# %%
Account_Number = 'ACC-1013'
print("Account Number:", Account_Number)

class Banking:
    count = 0
    def __init__(self, Account_Name, Account_Number, Balance, Account_Type):
        self.Account_Name = Account_Name
        self.Account_Number = Account_Number
        self.Balance = Balance
        self.Account_Type = Account_Type
        Banking.count = Banking.count + 1
    def track(self):
        print("Total Objects:", Banking.count)
b1 = Banking("Rayavaram Sai Vighnesh", "ACC-1013", 54000, "Savings")
b2 = Banking("Rayavaram Sai", "ACC-1013", 87255, "Current")
b1.track()
b2.track()
# Out:
# Account Number: ACC-1013
# Total Objects: 2
# Total Objects: 2

# %% [markdown]
# 14.Model a loyaltyaccount for banking case 1; use sample reference `ACC-1014` and explain the result.

# %%
Account_Number='ACC-1014'
print("Account_Number:",Account_Number)
Account_Holder_Name=input("Enter Customer Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
transfer_Money=int(input("Enter Transfer Money:"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,transfer_Money):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.transfer_Money=transfer_Money
    def loyality(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        if(self.transfer_Money < 50000):
            Loyality_points=100
            print("Rewards points:",Loyality_points)
        elif(self.transfer_Money >=50000 and self.transfer_Money <100000):
            Loyality_points=250
            print("Loyality Points:",Loyality_points)
        else:
            Loyality_points=350
            print("Loyality Points:",Loyality_points)
b1=Banking(Account_Holder_Name,Account_Number,Balance,transfer_Money)
b1.loyality()
# Out:
# Account_Number: ACC-1014
# Name: Rayavaram Sai Vighnesh
# Account Number: 4563217890
# Balance: 25000
# Rewards points: 100

# %% [markdown]
# 15.Create a supplier class for banking case 1; use sample reference `ACC-1015` and explain the result.

# %%
Account_Number='ACC-1015'
print("Account Number:",Account_Number)
class Supplier:
    def __init__(self,supplier_Id,Supplier_name,product,Mobile_Number,Payment_Amount):
        self.supplier_Id=supplier_Id
        self.supplier_name=Supplier_name
        self.product=product
        self.Mobile_Number=Mobile_Number
        self.Payment_Amount=Payment_Amount
    def details(self):
        print("Supperlier_Id:",self.supplier_Id)
        print("Supplier Name:",self.supplier_name)
        print("Product:",self.product)
        print("Mobile Number:",self.Mobile_Number)
        print("Payment Amount:",self.Payment_Amount)
Supplier_id=input("Enter Supplier Id:")
Supplier_name=input("Enter Supplier Name:")
product=input("Enter Product Name:")
Mobile_Number=int(input("Enter Mobile Number:"))
Payment_Amount=int(input("Enter Payment Amount:"))
s1=Supplier(Supplier_id,Supplier_name,product,Mobile_Number,Payment_Amount)
s1.details()
# Out:
# Account Number: ACC-1015
# Supperlier_Id: AR-0012
# Supplier Name: Sai
# Product: HP
# Mobile Number: 7993921717
# Payment Amount: 89200

# %% [markdown]
# 16. Create a account class for banking case 2; use sample reference `ACC-1016` and explain the result.

# %%
Account_Number='ACC-1016'
print("Account Number:",Account_Number)
account_holder_name=input("Enter Name")
balance=int(input("Enter Balance:"))
account_type=input("Enter Account Type:")
Mobile_Number=int(input("Enter Mobile Number:"))
class Banking:
    def __init__(self,account_holder_name,account_number,balance,account_type,Mobile_Number):
        self.account_holder_name=account_holder_name
        self.account_number=account_number
        self.balance=balance
        self.account_type=account_type
        self.Mobile_Number=Mobile_Number
    def show_details(self):
        print("Name:",self.account_holder_name)
        print("Account_Number:",self.account_number)
        print("Balance:",self.balance)
        print("Account Type:",self.account_type)
        print("Mobile Number:",self.Mobile_Number)
b1=Banking(account_holder_name,Account_Number,balance,account_type,Mobile_Number)
b1.show_details()
# Out:
# Account Number: ACC-1016
# Name: Rayavaram Sai Vighnesh
# Account_Number: ACC-1016
# Balance: 50000
# Account Type: Savings
# Mobile Number: 7993921717

# %% [markdown]
# 17.Add an initializer to accountholder for banking case 2; use sample reference `ACC-1017` and explain the result.

# %%
Account_Number='ACC-1017'
print("Account Number:",Account_Number)
account_holder_name=input("Enter Name")
balance=int(input("Enter Balance:"))
account_type=input("Enter Account Type:")
Mobile_Number=int(input("Enter Mobile Number:"))
class Banking:
    def __init__(self,account_holder_name,account_number,balance,account_type,Mobile_Number):
        self.account_holder_name=account_holder_name
        self.account_number=account_number
        self.balance=balance
        self.account_type=account_type
        self.Mobile_Number=Mobile_Number
    def show_details(self):
        print("Name:",self.account_holder_name)
        print("Account_Number:",self.account_number)
        print("Balance:",self.balance)
        print("Account Type:",self.account_type)
        print("Mobile Number:",self.Mobile_Number)
b1=Banking(account_holder_name,Account_Number,balance,account_type,Mobile_Number)
b1.show_details()
# Out:
# Account Number: ACC-1017
# Name: Rayavaram Sai Vighnesh
# Account_Number: ACC-1017
# Balance: 85000
# Account Type: Savings
# Mobile Number: 7993921717

# %% [markdown]
# 18.Represent an transfer object for banking case 2; use sample reference `ACC-1018` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1018'
print("Account_Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
    def show_details(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
        print("Transfer Amount:",self.Transfer_Amount)
        try:
            if(Transfer_Amount > sender_Balance):
                raise Exception("Transaction Status: Failed")
        except Exception as e:
            print(e)
        else:
            print("Transaction Status: Success")
b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount)
b1.show_details()
# Out:
# Account_Number: ACC-1018
# Transfer_id: TR-1001
# Sender_Account_Number: 456321012312
# Receiver_Account_Number: 987456321012
# Sender Balance: 98000
# Transfer Date: 2026-09-07
# Transfer Amount: 25600
# Transaction Status: Success

# %% [markdown]
# 19.Add a method that calculates line total for banking case 2; use sample reference `ACC-1019` and explain the result.

# %%
Account_Number='ACC-1019'
print("Account Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self.Transaction_Fee=Transaction_Fee
    def show_details(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
    def add_transaction_fee(self):
        transaction_Fee=self.Transfer_Amount*self.Transaction_Fee/100
        self.Transfer_Amount = self.Transfer_Amount+transaction_Fee
        print("Transfer_Amount:",self.Transfer_Amount)

b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.show_details()
b1.add_transaction_fee()
# Out:
# Account Number: ACC-1019
# Transfer_id: TR-001
# Sender_Account_Number: 582369147023
# Receiver_Account_Number: 985632147032
# Sender Balance: 98750
# Transfer Date: 2026-09-07
# Transfer_Amount: 21715.0

# %% [markdown]
# 20.Use a class attribute for branch name for banking case 2; use sample reference `ACC-1020` and explain the result

# %%
from datetime import date
Account_Number='ACC-1020'
print("Account_Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self.Transaction_Fee=Transaction_Fee
    def show_details(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
    def add_transaction_fee(self):
        transaction_Fee=self.Transfer_Amount*self.Transaction_Fee/100
        self.Transfer_Amount = self.Transfer_Amount+transaction_Fee
        print("Transfer_Amount:",self.Transfer_Amount)

b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.show_details()
b1.add_transaction_fee()
# Out:
# Account_Number: ACC-1020
# Transfer_id: TR=1003
# Sender_Account_Number: 987456321023
# Receiver_Account_Number: 654123987012
# Sender Balance: 98000
# Transfer Date: 2026-09-07
# Transfer_Amount: 21781.66

# %% [markdown]
# 21.Write a readable __str__ method for banking case 2; use sample reference `ACC-1021` and explain the result.

# %%
Account_Number='ACC-1021'
print("Account Number:",Account_Number)
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self.sender_account_number=sender_account_number
        self.receiver_account_number=receiver_account_number
        self.sender_balance=sender_balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self.Transaction_Fee=Transaction_Fee
    def add_transaction_fee(self):
        transaction_Fee=self.Transfer_Amount*self.Transaction_Fee/100
        self.Transfer_Amount = self.Transfer_Amount+transaction_Fee
    def __str__(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self.sender_account_number)
        print("Receiver_Account_Number:",self.receiver_account_number)
        print("Sender Balance:",self.sender_balance)
        print("Transfer Date:",self.Transfer_Date)
        print("Transfer_Amount:",self.Transfer_Amount)
        try:
            if(Transfer_Amount > self.sender_balance):
                raise Exception("Transaction Status:Failure")
        except Exception as e:
            print(e)
        else:
            print("Transaction Status:Success")
b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.add_transaction_fee()
b1.__str__()
# Out:
# Account Number: ACC-1021
# Transfer_id: TR-3225
# Sender_Account_Number: 789654123023
# Receiver_Account_Number: 98745631202
# Sender Balance: 98700
# Transfer Date: 2026-09-07
# Transfer_Amount: 21715.0
# Transaction Status:Success

# %% [markdown]
# 22. Compare two account references with __eq__ for banking case 2; use sample reference `ACC-1022` and explain the result.

# %%
Account_Number='ACC-1022'
print("Account Number:",Account_Number)
Account_number=input("Enter Account Number:")
Account_Number1=input("Enter Account Number:")
class Banking:
    def __init__(self,Account_number):
        self.Account_number=Account_number
    def acc(self):
        print("Account Number:",self.Account_number)
b1=Banking(Account_number)
b1.acc()
b2=Banking(Account_Number1)
b2.acc()
print(b1.Account_number.__eq__(b2.Account_number))
# Out:
# Account Number: ACC-1022
# Account Number: 213546879012
# Account Number: 213546879012
# True

# %% [markdown]
# 23.Protect a amount with a property for banking case 2; use sample reference `ACC-1023` and explain the result.

# %%
Account_Number='ACC-1023'
print("Account Number:",Account_Number)
from datetime import date
Transfer_ID=input("Enter Transfer_id")
Sender_Account_Number=int(input("Enter Sender Account Number:"))
Receiver_Account_Number=int(input("Enter Receiver Account Number:"))
sender_Balance=int(input("Enter Balance:"))
Transfer_Date=date.today()
Transaction_Fee=int(input("Enter the percentage fee for Transaction Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
class Banking:
    def __init__(self,Transfer_id,sender_account_number,receiver_account_number,sender_balance,Transfer_Date,Transfer_Amount,Transaction_Fee):
        self.Transfer_id=Transfer_id
        self._sender_account_number=sender_account_number
        self._receiver_account_number=receiver_account_number
        self._sender_balance=sender_balance
        self._Transfer_Amount=Transfer_Amount
        self.Transfer_Date=Transfer_Date
        self._Transaction_Fee=Transaction_Fee
    def add_transaction_fee(self):
        transaction_Fee=self._Transfer_Amount*self._Transaction_Fee/100
        self._Transfer_Amount = self._Transfer_Amount+transaction_Fee
    def __str__(self):
        print("Transfer_id:",self.Transfer_id)
        print("Sender_Account_Number:",self._sender_account_number)
        print("Receiver_Account_Number:",self._receiver_account_number)
        print("Sender Balance:",self._sender_balance)
        print("Transfer Date:",self.Transfer_Date)
        print("Transfer_Amount:",self._Transfer_Amount)
        try:
            if(Transfer_Amount > self.sender_balance):
                raise Exception("Transaction Status:Failure")
        except Exception as e:
            print(e)
        else:
            print("Transaction Status:Success")
b1=Banking(Transfer_ID,Sender_Account_Number,Receiver_Account_Number,sender_Balance,Transfer_Date,Transfer_Amount,Transaction_Fee)
b1.add_transaction_fee()
b1.__str__()
# Out:
# Account Number: ACC-1023
# Transfer_id: TR-1001
# Sender_Account_Number: 123456789012
# Receiver_Account_Number: 321654879210
# Sender Balance: 65000
# Transfer Date: 2026-09-07
# Transfer_Amount: 25856.0
# 'Banking' object has no attribute 'sender_balance'

# %% [markdown]
# 24.Create portfolio and add_item for banking case 2; use sample reference `ACC-1024` and explain the result.

# %%
Account_Number='ACC-1024'
print("Account Number:",Account_Number)
class Portfolio:
    def __init__(self,Account_holder_name,Account_Number,IFSC_code,Mobile_Number,Place,balance):
        self.Account_holder_Name=Account_holder_name
        self.Account_Number=Account_Number
        self.IFSC_code=IFSC_code
        self.Mobile_Number=Mobile_Number
        self.place=Place
        self.balance=balance
    def add_item(self):
        print("Customer Name:",self.Account_holder_Name)
        print("Account Number:",self.Account_Number)
        print("IFSC Code:",self.IFSC_code)
        print("Mobile Number:",self.Mobile_Number)
        print("Place:",self.place)
        print("Balance:",self.balance)
account_holder_name=input("Enter Account Holder Name:")
Account_number=input("Enter Account Number:")
IFSC_code=input("Enter IFSC Code:")
Mobile_Number=int(input("Enter Mobile Number:"))
place=input("Enter Place:")
balance=int(input("Enter Balanace:"))
p1=Portfolio(account_holder_name,Account_number,IFSC_code,Mobile_Number,place,balance)
p1.add_item()
# Out:
# Account Number: ACC-1024
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 123456799012
# IFSC Code: SBI2255889630
# Mobile Number: 7993921717
# Place: Vempalli
# Balance: 50000

# %% [markdown]
# 25.Model a branchaddress for banking case 2; use sample reference `ACC-1025` and explain the result.

# %%
Account_Number='ACC-1025'
print("Account Number:",Account_Number)
class BranchAddress:
    def __init__(self,Building_Number,Street_Name,City,State,PINCODE):
        self.Building_Number=Building_Number
        self.Street_Name=Street_Name
        self.City=City
        self.State=State
        self.pincode=PINCODE
    def Address(self):
        print("DOOR NUMBER:",self.Building_Number)
        print("Street:",self.Street_Name)
        print("City:",self.City)
        print("State:",self.State)
        print("Pincode:",self.pincode)
Building_Number=input("Enter Door Number:")
Street_Name=input("Enter Street Name:")
City=input("Enter City:")
State=input("Enter State:")
Pincode=int(input("Enter Pincode:"))
b1=BranchAddress(Building_Number,Street_Name,City,State,Pincode)
b1.Address()
# Out:
# Account Number: ACC-1025
# DOOR NUMBER: 12/56-F3
# Street: Pulivendula road
# City: Vempalli
# State: Andhra Pradesh
# Pincode: 516329

# %% [markdown]
# 26.Use a static method to validate account reference for banking case 2; use sample reference `ACC-1026` and explain the result.

# %%
Account_Number='ACC-1026'
print("Account Number:",Account_Number)
Account_Number=input("Enter Account Number:")
class Banking:
    def __init__(self,Account_Number):
        self.Account_Number=Account_Number
    @staticmethod
    def Validate():
        try:
            if(not Account_Number.isnumeric()):
                raise Exception("Invalid Account Number")
        except Exception as e:
            print(e)
        else:
            print("Valid Account Number")
b1=Banking(Account_Number)
Banking.Validate()
# Out:
# Account Number: ACC-1026
# Valid Account Number

# %% [markdown]
# 27. Use a class method as an alternate constructor for banking case 2; use sample reference `ACC-1027` and explain the result.

# %%
Account_Number='ACC-1027'
print("Account Number:",Account_Number)
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_details(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Account Type:",self.Account_Type)
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
b1=Banking("Rayavaram",1234569870,56000,"Savings")
b2=Banking("Rayavaram Sai",1236547890,57800,"Current")
b1.show_details()
b2.show_details()
# Out:
# Account Number: ACC-1027
# Customer Name: Rayavaram
# Account Number: 1234569870
# Balance: 56000
# Account Type: Savings
# Customer Name: Rayavaram Sai
# Account Number: 1236547890
# Balance: 57800
# Account Type: Current

# %% [markdown]
# 28.Track object count for banking case 2; use sample reference `ACC-1028` and explain the result.

# %%
Account_Number = 'ACC-1028'
print("Account Number:", Account_Number)
class Banking:
    count = 0
    def __init__(self, Account_Name, Account_Number, Balance, Account_Type):
        self.Account_Name = Account_Name
        self.Account_Number = Account_Number
        self.Balance = Balance
        self.Account_Type = Account_Type
        Banking.count = Banking.count + 1
    def track(self):
        print("Total Objects:", Banking.count)
b1 = Banking("Rayavaram Sai Vighnesh", "ACC-1028", 54000, "Savings")
b2 = Banking("Rayavaram Sai", "ACC-1028", 87255, "Current")
b1.track()
b2.track()
# Out:
# Account Number: ACC-1028
# Total Objects: 2
# Total Objects: 2

# %% [markdown]
# 29. Model a loyaltyaccount for banking case 2; use sample reference `ACC-1029` and explain the result.

# %%
Account_Number='ACC-1029'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Customer Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
transfer_Money=int(input("Enter Transfer Money:"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,transfer_Money):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.transfer_Money=transfer_Money
    def loyality(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        if(self.transfer_Money < 50000):
            Loyality_points=100
            print("Rewards points:",Loyality_points)
        elif(self.transfer_Money >=50000 and self.transfer_Money <100000):
            Loyality_points=250
            print("Loyality Points:",Loyality_points)
        else:
            Loyality_points=350
            print("Loyality Points:",Loyality_points)
b1=Banking(Account_Holder_Name,Account_Number,Balance,transfer_Money)
b1.loyality()
# Out:
# Account Number: ACC-1029
# Name: Rayavaram Sai Vighnesh
# Account Number: 213546879012
# Balance: 56000
# Rewards points: 100

# %% [markdown]
# 30.Create a supplier class for banking case 2; use sample reference `ACC-1030` and explain the result.

# %%
Account_Number='ACC-1030'
print("Account Number:",Account_Number)
class Supplier:
    def __init__(self,supplier_Id,Supplier_name,product,Mobile_Number,Payment_Amount):
        self.supplier_Id=supplier_Id
        self.supplier_name=Supplier_name
        self.product=product
        self.Mobile_Number=Mobile_Number
        self.Payment_Amount=Payment_Amount
    def details(self):
        print("Supperlier_Id:",self.supplier_Id)
        print("Supplier Name:",self.supplier_name)
        print("Product:",self.product)
        print("Mobile Number:",self.Mobile_Number)
        print("Payment Amount:",self.Payment_Amount)
Supplier_id=input("Enter Supplier Id:")
Supplier_name=input("Enter Supplier Name:")
product=input("Enter Product Name:")
Mobile_Number=int(input("Enter Mobile Number:"))
Payment_Amount=int(input("Enter Payment Amount:"))
s1=Supplier(Supplier_id,Supplier_name,product,Mobile_Number,Payment_Amount)
s1.details()
# Out:
# Account Number: ACC-1030
# Supperlier_Id: SR-1025
# Supplier Name: Sai
# Product: Air Conditioner
# Mobile Number: 7993921751
# Payment Amount: 56900

# %% [markdown]
# 31. Inherit perishableaccount from account for banking case 1; use sample reference `ACC-1031` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1031'
print("Account Number:",Account_Number)
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balane=Balance
        self.Account_Type=Account_Type
        self.Deposit=Deposit
        self.Withdrawl=Withdrawl
class Account1(Account):
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl,Expiry_Date):
        super().__init__(Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl)
        self.Expiry_Date=Expiry_Date
    def show_account(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balane)
        print("Account Type:",self.Account_Type)
        print("Expiry Date:",self.Expiry_Date)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Amount:"))
Account_Type=input("Enter Account Type:")
Deposit=int(input("Enter Deposit Amount:"))
withdrawl=int(input("Enter Withdrawl Amount:"))
Expiry_Date=date.today()

a1=Account1(Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,withdrawl,Expiry_Date)
a1.show_account()
# Out:
# Account Number: ACC-1031
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 546213879021
# Balance: 54000
# Account Type: Savings
# Expiry Date: 2026-09-07

# %% [markdown]
# 32.Override a discount method for banking case 1; use sample reference `ACC-1032` and explain the result.

# %%
Account_Number='ACC-1032'
print("Account Number:",Account_Number)
class Account:
    def __init__(self,discount):
        self.discount=discount
    def discount1(self,percentage):
        print("Discount Percent:",percentage)
class Loyality(Account):
    def __init__(self,discount):
        super().__init__(discount)
    def discount1(self,Percentage):
        print("Discount Percentage:",Percentage)
percentage=int(input("Enter Percentage:"))
l1=Loyality(4)
l1.discount1(percentage)
# Out:
# Account Number: ACC-1032
# Discount Percentage: 10

# %% [markdown]
# 33.Use polymorphic payment processors for banking case 1; use sample reference `ACC-1033` and explain the result.

# %%
Account_Number='ACC-1033'
print("Account Number:",Account_Number)
class Payment:
    def process_payment(self):
        print("Process Transaction")
class UPI(Payment):
    def process_payment(self):
        print("I am doing Payment transaction through UPI")
class Creditcard(Payment):
    def process_payment(self):
        print("I am doing Payment transaction through creditcard")
class Debitcard(Payment):
    def process_payment(self):
        print("I am doing payment transaction through Debit card")
class NetBanking(Payment):
    def process_payment(self):
        print("I am doing payment Transaction through NetBanking")
n1=NetBanking()
n1.process_payment()
d1=Debitcard()
d1.process_payment()
c1=Creditcard()
c1.process_payment()
u1=UPI()
u1.process_payment()
# Out:
# Account Number: ACC-1033
# I am doing payment Transaction through NetBanking
# I am doing payment transaction through Debit card
# I am doing Payment transaction through creditcard
# I am doing Payment transaction through UPI

# %% [markdown]
# 34.Compose transfer from transferline objects for banking case 1; use sample reference `ACC-1034` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1034'
print("Account Number:",Account_Number)
class Transferline1:
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1):
        self.sender_account_number=Sender_Account_Number
        self.receiver_account_number=Receiver_Account_Number
        self.Amount1=Amount1
    def show_transfer1(self):
        print("Sender:",self.sender_account_number)
        print("Receiver:",self.receiver_account_number)
        print("Amount:",self.Amount1)
class Transferline2:
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount2):
        self.sender_account_number=Sender_Account_Number
        self.receiver_account_number=Receiver_Account_Number
        self.Amount2=Amount2
    def show_transfer2(self):
        print("Sender:",self.sender_account_number)
        print("Receiver:",self.receiver_account_number)
        print("Amount:",self.Amount2)
class Transfer(Transferline1,Transferline2):
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1,Amount2):
        Transferline1.__init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1)
        Transferline2.__init__(self,Sender_Account_Number,Receiver_Account_Number,Amount2)
    def show_transfer(self):
        amount=self.Amount1+self.Amount2
        print("Date:",date.today())
        print("Status:Scuccess")
        print("Amount:",amount)
t1=Transferline1(123654789650,546987125306,5000)
t1.show_transfer1()
t2=Transferline2(546218723980,164785963015,5000)
t2.show_transfer2()
t=Transfer(546218723980,164785963015,5000,5000)
t.show_transfer()
# Out:
# Account Number: ACC-1034
# Sender: 123654789650
# Receiver: 546987125306
# Amount: 5000
# Sender: 546218723980
# Receiver: 164785963015
# Amount: 5000
# Date: 2026-09-09
# Status:Scuccess
# Amount: 10000

# %% [markdown]
# 35.Define an abstract paymentmethod for banking case 1; use sample reference `ACC-1035` and explain the result.

# %%
Account_Number='ACC-1035'
print("Account_Number:",Account_Number)
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def paymentmethod(self):
        pass

class Payment1(Payment):
    def paymentmethod(self):
        print("I am doing payment transaction through UPI Payment")

class Payment2(Payment):
    def paymentmethod(self):
        print("I am doing payment transaction through Credit card Transaction")

class Payment3(Payment):
    def paymentmethod(self):
        print("I am doing Payment Transaction through Debit card Transaction")

class Payment4(Payment):
    def paymentmethod(self):
        print("I am doing payment Transaction through Net Banking")

p1=Payment1()
p1.paymentmethod()
p2=Payment2()
p2.paymentmethod()
p3=Payment3()
p3.paymentmethod()
p4=Payment4()
p4.paymentmethod()
# Out:
# Account_Number: ACC-1035
# I am doing payment transaction through UPI Payment
# I am doing payment transaction through Credit card Transaction
# I am doing Payment Transaction through Debit card Transaction
# I am doing payment Transaction through Net Banking

# %% [markdown]
# 36.Use a dataclass for inventoryrecord for banking case 1; use sample reference `ACC-1036` and explain the result.

# %%
Account_Number='ACC-1036'
print("Account Number:",Account_Number)
class Data:
    def __init__(self,Item_id,Item_Name,Quantity,Branch,Status):
        self.Item_ID=Item_id
        self.Item_Name=Item_Name
        self.Quantity=Quantity
        self.Branch=Branch
        self.Status=Status
    def show_Store(self):
        print("Item_ID:",self.Item_ID)
        print("Item_Name:",self.Item_Name)
        print("Quantity:",self.Quantity)
        print("Branch:",self.Branch)
        print("Status:",self.Status)
Item_ID=input("Enter Input ID:")
Item_Name=input("Enter Item Name:")
Quantity=int(input("Enter Quantity:"))
Branch=input("Enter Branch Name:")
Status=input("Enter Status:")
d1=Data(Item_ID,Item_Name,Quantity,Branch,Status)
d1.show_Store()
# Out:
# Account Number: ACC-1036
# Item_ID: ID-236
# Item_Name: ATM
# Quantity: 3
# Branch: Vempally
# Status: Working

# %% [markdown]
# 37.Implement a custom iterator for portfolio for banking case 1; use sample reference `ACC-1037` and explain the result.

# %%
Account_Number='ACC-1037'
print("Account Number:",Account_Number)
class Portfolio:
    def __init__(self,Account_Holder_name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_details(self):
        print("Account_Type:",self.Account_Type)
        print("Account Holder Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
p1=Portfolio("Rayavarm Sai Vighnesh",541236987012,54000,"Savings")
p1.show_details()
p2=Portfolio("Rayavaram Koushik",564879321025,546000,"Current")
p2.show_details()
p3=Portfolio("Rayavaram Kushal",874521369023,87000,"Fixed")
p3.show_details()
# Out:
# Account Number: ACC-1037
# Account_Type: Savings
# Account Holder Name: Rayavarm Sai Vighnesh
# Account Number: 541236987012
# Balance: 54000
# Account_Type: Current
# Account Holder Name: Rayavaram Koushik
# Account Number: 564879321025
# Balance: 546000
# Account_Type: Fixed
# Account Holder Name: Rayavaram Kushal
# Account Number: 874521369023
# Balance: 87000

# %% [markdown]
# 38. Use multiple inheritance carefully for timestampeditem for banking case 1; use sample reference `ACC-1038` and explain the result.

# %%
Account_Number='ACC-1038'
print("Account Number:",Account_Number)
from datetime import date
from datetime import datetime
Account_Number=int(input("Enter Amount Number:"))
Transasction_Type=input("Enter Transaction Type:")
Transaction_Amount=int(input("Enter Transaction Amount:"))
date1=date.today()
now=datetime.now()
time1=now.strftime("%H:%M:%S")
class Transaction:
    def __init__(self,Account_Number,Transaction_Type,Transaction_Amount):
        self.Account_Number=Account_Number
        self.Transaction_Type=Transaction_Type
        self.Transaction_Amount=Transaction_Amount
class Timestampeditem:
    def __init__(self,date,time):
        self.date=date
        self.time=time
class BankTransaction(Transaction,Timestampeditem):
    def __init__(self,Account_Number,Transaction_Type,Transaction_Amount,date,time):
        Transaction.__init__(self,Account_Number,Transaction_Type,Transaction_Amount)
        Timestampeditem.__init__(self,date,time)
    def show_Account(self):
        print("Account Number:",Account_Number)
        print("Transaction Type:",Transasction_Type)
        print("Transaction Amount:",Transaction_Amount)
        print("date:",self.date)
        print("Time:",self.time)
b1=BankTransaction(Account_Number,Transasction_Type,Transaction_Amount,date1,time1)
b1.show_Account()
# Out:
# Account Number: ACC-1038
# Account Number: 546213897021
# Transaction Type: UPI
# Transaction Amount: 65000
# date: 2026-09-08
# Time: 15:59:25

# %% [markdown]
# 39. Create a account factory for banking case 1; use sample reference `ACC-1039` and explain the result.

# %%
Account_Number='ACC-1039'
print("Account Number:",Account_Number)
Account_Number=int(input("Enter Account Number:"))
Account_Holder_Name=input("Enyter Account Holder Name:")
Balance=int(input("Enter Amount:"))
Account_Type=input("Enter Account Type:")
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_Account(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Customer Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Account Type:",self.Account_Type)
a1=Account(Account_Holder_Name,Account_Number,Balance,Account_Type)
a1.show_Account()
# Out:
# Account Number: ACC-1039
# Customer Name: Rayavaram Sai
# Customer Account Number: 546987258963
# Balance: 58000
# Account Type: Savings

# %% [markdown]
# 40.Apply a strategy for interest offers for banking case 1; use sample reference `ACC-1040` and explain the result.

# %%
Account_Number='ACC-1040'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Name:")
Account_Number=int(input("Enter Account Number:"))
age=int(input("Enter Age:"))
Account_Type=input("Enter Account Type:")
transfer_balance=int(input("Enter Transfer Balance:"))
balance=int(input("Enter Balance:"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,age,Account_Type,balance,transfer_balance):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Age=age
        self.Account_Type=Account_Type
        self.balance=balance
        self.transfer_balance=transfer_balance
    def show_intrest(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Age:",self.Age)
        print("Account Number:",self.Account_Number)
        print("Account Type:",self.Account_Type)
        print("Balance:",self.balance)
        print("Transfer Balance:",transfer_balance)
        if(self.Age >10 and self.Age <60):
            print("Interst:4%")
        elif(self.Age >= 60):
            print("Interst:7%")
        elif(self.Account_Type=='Fixed'):
            print("Interst:8%")
        elif((self.Age >0 and self.Age< 60) and (transfer_balance > 100000)):
            print("Interst:9%")
        elif((self.Age >0 and self.Age< 60) and (self.Account_Type=='Fixed')):
            print("Interst:6%")
b1=Banking(Account_Holder_Name,Account_Number,age,Account_Type,balance,transfer_balance)
b1.show_intrest()
# Out:
# Account Number: ACC-1040
# Customer Name: Rayavaram Sai Vighnesh
# Age: 56
# Account Number: 546213879023
# Account Type: Savigs
# Balance: 98000
# Transfer Balance: 32000
# Interst:4%

# %% [markdown]
# 41.Encapsulate balance reservation for banking case 1; use sample reference `ACC-1041` and explain the result.

# %%
Account_Number='ACC-1041'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
reserve_Balance=int(input("Enter Reserve Balance:"))
payament_Status=input("Enter Payment Status:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,reserve_Balance,payment_Status):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self._reserve_Balance=reserve_Balance
        self.payment_Status=payment_Status
    def show_balance(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Reserve Balance:",self._reserve_Balance)
        if(self.payment_Status =='Yes'):
            if(self._reserve_Balance <= self.Balance):
                self.Balance=self.Balance-self._reserve_Balance
                print("Available Balance:",self.Balance)
            else:
                print("Insufficient Balance")
        else:
            print("Payment Status Failed")
b1=Banking(Account_Holder_Name,Account_Number,Balance,reserve_Balance,payament_Status)
b1.show_balance()
# Out:
# Account Number: ACC-1041
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 21354687936
# Balance: 65000
# Reserve Balance: 60000
# Available Balance: 5000

# %% [markdown]
# 42.Model aggregation between branch and employees for banking case 1; use sample reference `ACC-1042` and explain the result.

# %%
Account_Number='ACC-1042'
print("Account Number:",Account_Number)
Employee_Name=input("Enter Employee Name:")
Employee_Id=input("Enter Employee ID:")
Employee_Branch=input("Enter Branch Name:")
Employee_new_Branch=input("Enter New Branch:")
Salary=int(input("Enter Salary:"))
new_salary=int(input("Enter New Salary:"))
Role=input("Enter Role:")
class Branch1:
    def __init__(self,Employee_Name,Employee_Id,Employee_Branch,salary,Role):
        self.Employee_Name=Employee_Name
        self.Employee_Id=Employee_Id
        self.Employee_Branch=Employee_Branch
        self.Salary=salary
        self.Role=Role
class Branch2:
    def __init__(self,Employee_new_Branch,new_salary,Role):
        self.Employee_new_Branch=Employee_new_Branch
        self.new_salary=new_salary
        self.Role=Role
class Branch:
    def __init__(self,Employee_Name,Employee_Id,Employee_Branch,salary,Role,Employee_new_Branch,new_salary):
        Branch1.__init__(self,Employee_Name,Employee_Id,Employee_Branch,salary,Role)
        Branch2.__init__(self,Employee_new_Branch,new_salary,Role)
    def show_branch(self):
        print("Employee Name:",self.Employee_Name)
        print("Employee_Id:",self.Employee_Id)
        print("Employee Old Branch:",self.Employee_Branch)
        print("Employee Branch:",self.Employee_new_Branch)
        print("Salary:",self.new_salary)
        print("Role:",self.Role)
B1=Branch(Employee_Name,Employee_Id,Employee_Branch,Salary,Role,Employee_new_Branch,new_salary)
B1.show_branch()
# Out:
# Account Number: ACC-1042
# Employee Name: Rayavaram Sai Vighnesh
# Employee_Id: emp-1001
# Employee Old Branch: Vempalli
# Employee Branch: Pulivendula
# Salary: 42000
# Role: Manager

# %% [markdown]
# 43.Serialize an transfer to a dictionary for banking case 1; use sample reference `ACC-1043` and explain the result.

# %%
Account_Number='ACC-1043'
print("Account Number:",Account_Number)
Transaction_ID=input("Enter Transaction Id")
sender_Id=input("Enter Sender ID:")
Receiver_Id=input("Enter Receiver ID:")
Amount=int(input("Enter Amount:"))
Status=input("Enter Status:")
dict1={
    "Transaction_Id":"",
    "Sender Id":"",
    "Receiver_ID":"",
    "Amount":0,
    "Status":""

}
class Transfer:
    def __init__(self,Transaction_ID,sender_Id,Receiver_Id,Amount,Status):
        self.Transaction_ID=Transaction_ID
        self.sender_id=sender_Id
        self.Receiver_Id=Receiver_Id
        self.Amount=Amount
        self.Status=Status
    def shoe_transfer(self):
        dict1["Transaction_Id"]=self.Transaction_ID
        dict1["Sender Id"]=self.sender_id
        dict1["Receiver_ID"]=self.Receiver_Id
        dict1["Amount"]=self.Amount
        dict1["Status"]=self.Status
        print(dict1)
t1=Transfer(Transaction_ID,sender_Id,Receiver_Id,Amount,Status)
t1.shoe_transfer()
# Out:
# Account Number: ACC-1043
# {'Transaction_Id': 'TR-1001', 'Sender Id': 'SE-01', 'Receiver_ID': 'RE-01', 'Amount': 25000, 'Status': 'Success'}

# %% [markdown]
# 44.Implement a repository abstraction for banking case 1; use sample reference `ACC-1044` and explain the result.

# %%
# Account class
class Account:
    def __init__(self, account_number, account_holder, balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance

    def show_details(self):
        print("Account Number:", self.account_number)
        print("Account Holder:", self.account_holder)
        print("Balance:", self.balance)


# Repository abstraction
class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def add_account(self, account):
        self.accounts[account.account_number] = account

    def find_account(self, account_number):
        return self.accounts.get(account_number)

    def update_account(self, account):
        self.accounts[account.account_number] = account

    def delete_account(self, account_number):
        if account_number in self.accounts:
            del self.accounts[account_number]

    def get_all_accounts(self):
        return self.accounts.values()


# Create account
account1 = Account("ACC-1044", "Sai Vignesh", 50000)

# Create repository
repository = AccountRepository()

# Add account to repository
repository.add_account(account1)

# Find account
account = repository.find_account("ACC-1044")

# Display result
if account:
    print("Account Found")
    account.show_details()
else:
    print("Account Not Found")
# Out:
# Account Found
# Account Number: ACC-1044
# Account Holder: Sai Vignesh
# Balance: 50000

# %% [markdown]
# 45. Apply dependency injection to checkout for banking case 1; use sample reference `ACC-1045` and explain the result.

# %%
Account_Number='ACC-1045'
print("Account Number:",Account_Number)
Payment_Process=input("Select the payment process:")
class Checkout:
    def __init__(self,Payement_Processor):
        self.Payment_Processor=Payement_Processor
    def show_Checkout(self):
        print("Select the payment Process:",self.Payment_Processor)
        print("Payment process successfully completed")
c1=Checkout(Payment_Process)
c1.show_Checkout()
# Out:
# Account Number: ACC-1045
# Select the payment Process: Creditcard
# Payment process successfully completed

# %% [markdown]
# 46.Inherit perishableaccount from account for banking case 2; use sample reference `ACC-1046` and explain the result.

# %%
Account_Number='ACC-1046'
print("Account Number:",Account_Number)
from datetime import date
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balane=Balance
        self.Account_Type=Account_Type
        self.Deposit=Deposit
        self.Withdrawl=Withdrawl
class Account1(Account):
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl,Expiry_Date):
        super().__init__(Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl)
        self.Expiry_Date=Expiry_Date
    def show_account(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balane)
        print("Account Type:",self.Account_Type)
        print("Expiry Date:",self.Expiry_Date)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Amount:"))
Account_Type=input("Enter Account Type:")
Deposit=int(input("Enter Deposit Amount:"))
withdrawl=int(input("Enter Withdrawl Amount:"))
Expiry_Date=date.today()

a1=Account1(Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,withdrawl,Expiry_Date)
a1.show_account()
# Out:
# Account Number: ACC-1046
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 546213879032
# Balance: 59000
# Account Type: Savings
# Expiry Date: 2026-09-09

# %% [markdown]
# 47. Override a discount method for banking case 2; use sample reference `ACC-1047` and explain the result.

# %%
Account_Number='ACC-1047'
print("Account Number:",Account_Number)
class Account:
    def __init__(self,discount):
        self.discount=discount
    def discount1(self,percentage):
        print("Discount Percent:",percentage)
class Loyality(Account):
    def __init__(self,discount):
        super().__init__(discount)
    def discount1(self,Percentage):
        print("Discount Percentage:",Percentage)
percentage=int(input("Enter Percentage:"))
l1=Loyality(4)
l1.discount1(percentage)
# Out:
# Account Number: ACC-1047
# Discount Percentage: 15

# %% [markdown]
# 48.Use polymorphic payment processors for banking case 2; use sample reference `ACC-1048` and explain the result.

# %%
Account_Number='ACC-1048'
print("Account Number:",Account_Number)
class Payment:
    def process_payment(self):
        print("Process Transaction")
class UPI(Payment):
    def process_payment(self):
        print("I am doing Payment transaction through UPI")
class Creditcard(Payment):
    def process_payment(self):
        print("I am doing Payment transaction through creditcard")
class Debitcard(Payment):
    def process_payment(self):
        print("I am doing payment transaction through Debit card")
class NetBanking(Payment):
    def process_payment(self):
        print("I am doing payment Transaction through NetBanking")
n1=NetBanking()
n1.process_payment()
d1=Debitcard()
d1.process_payment()
c1=Creditcard()
c1.process_payment()
u1=UPI()
u1.process_payment()
# Out:
# Account Number: ACC-1048
# I am doing payment Transaction through NetBanking
# I am doing payment transaction through Debit card
# I am doing Payment transaction through creditcard
# I am doing Payment transaction through UPI

# %% [markdown]
# 49.Compose transfer from transferline objects for banking case 2; use sample reference `ACC-1049` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1049'
print("Account Number:",Account_Number)
class Transferline1:
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1):
        self.sender_account_number=Sender_Account_Number
        self.receiver_account_number=Receiver_Account_Number
        self.Amount1=Amount1
    def show_transfer1(self):
        print("Sender:",self.sender_account_number)
        print("Receiver:",self.receiver_account_number)
        print("Amount:",self.Amount1)
class Transferline2:
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount2):
        self.sender_account_number=Sender_Account_Number
        self.receiver_account_number=Receiver_Account_Number
        self.Amount2=Amount2
    def show_transfer2(self):
        print("Sender:",self.sender_account_number)
        print("Receiver:",self.receiver_account_number)
        print("Amount:",self.Amount2)
class Transfer(Transferline1,Transferline2):
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1,Amount2):
        Transferline1.__init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1)
        Transferline2.__init__(self,Sender_Account_Number,Receiver_Account_Number,Amount2)
    def show_transfer(self):
        amount=self.Amount1+self.Amount2
        print("Date:",date.today())
        print("Status:Scuccess")
        print("Amount:",amount)
t1=Transferline1(123654789650,546987125306,5000)
t1.show_transfer1()
t2=Transferline2(546218723980,164785963015,5000)
t2.show_transfer2()
t=Transfer(546218723980,164785963015,5000,5000)
t.show_transfer()
# Out:
# Account Number: ACC-1049
# Sender: 123654789650
# Receiver: 546987125306
# Amount: 5000
# Sender: 546218723980
# Receiver: 164785963015
# Amount: 5000
# Date: 2026-09-09
# Status:Scuccess
# Amount: 10000

# %% [markdown]
# 50.Define an abstract paymentmethod for banking case 2; use sample reference `ACC-1050` and explain the result.

# %%
Account_Number='ACC-1050'
print("Account Number:",Account_Number)
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def paymentmethod(self):
        pass

class Payment1(Payment):
    def paymentmethod(self):
        print("I am doing payment transaction through UPI Payment")

class Payment2(Payment):
    def paymentmethod(self):
        print("I am doing payment transaction through Credit card Transaction")

class Payment3(Payment):
    def paymentmethod(self):
        print("I am doing Payment Transaction through Debit card Transaction")

class Payment4(Payment):
    def paymentmethod(self):
        print("I am doing payment Transaction through Net Banking")

p1=Payment1()
p1.paymentmethod()
p2=Payment2()
p2.paymentmethod()
p3=Payment3()
p3.paymentmethod()
p4=Payment4()
p4.paymentmethod()
# Out:
# Account Number: ACC-1050
# I am doing payment transaction through UPI Payment
# I am doing payment transaction through Credit card Transaction
# I am doing Payment Transaction through Debit card Transaction
# I am doing payment Transaction through Net Banking

# %% [markdown]
# 51.Use a dataclass for inventoryrecord for banking case 2; use sample reference `ACC-1051` and explain the result.

# %%
Account_Number='ACC-1051'
print("Account Number:",Account_Number)
class Data:
    def __init__(self,Item_id,Item_Name,Quantity,Branch,Status):
        self.Item_ID=Item_id
        self.Item_Name=Item_Name
        self.Quantity=Quantity
        self.Branch=Branch
        self.Status=Status
    def show_Store(self):
        print("Item_ID:",self.Item_ID)
        print("Item_Name:",self.Item_Name)
        print("Quantity:",self.Quantity)
        print("Branch:",self.Branch)
        print("Status:",self.Status)
Item_ID=input("Enter Input ID:")
Item_Name=input("Enter Item Name:")
Quantity=int(input("Enter Quantity:"))
Branch=input("Enter Branch Name:")
Status=input("Enter Status:")
d1=Data(Item_ID,Item_Name,Quantity,Branch,Status)
d1.show_Store()
# Out:
# Account Number: ACC-1051
# Item_ID: IT-56
# Item_Name: MAC BOOK
# Quantity: 3
# Branch: Vempalli
# Status: working

# %% [markdown]
# 52.Implement a custom iterator for portfolio for banking case 2; use sample reference `ACC-1052` and explain the result.

# %%
Account_Number='ACC-1052'
print("Account Number:",Account_Number)
class Portfolio:
    def __init__(self,Account_Holder_name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_details(self):
        print("Account_Type:",self.Account_Type)
        print("Account Holder Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
p1=Portfolio("Rayavarm Sai Vighnesh",541236987012,54000,"Savings")
p1.show_details()
p2=Portfolio("Rayavaram Koushik",564879321025,546000,"Current")
p2.show_details()
p3=Portfolio("Rayavaram Kushal",874521369023,87000,"Fixed")
p3.show_details()
# Out:
# Account Number: ACC-1052
# Account_Type: Savings
# Account Holder Name: Rayavarm Sai Vighnesh
# Account Number: 541236987012
# Balance: 54000
# Account_Type: Current
# Account Holder Name: Rayavaram Koushik
# Account Number: 564879321025
# Balance: 546000
# Account_Type: Fixed
# Account Holder Name: Rayavaram Kushal
# Account Number: 874521369023
# Balance: 87000

# %% [markdown]
# 53. Use multiple inheritance carefully for timestampeditem for banking case 2; use sample reference `ACC-1053` and explain the result.

# %%
Account_Number='ACC-1053'
print("Account Number:",Account_Number)
from datetime import date
from datetime import datetime
Account_Number=int(input("Enter Amount Number:"))
Transasction_Type=input("Enter Transaction Type:")
Transaction_Amount=int(input("Enter Transaction Amount:"))
date1=date.today()
now=datetime.now()
time1=now.strftime("%H:%M:%S")
class Transaction:
    def __init__(self,Account_Number,Transaction_Type,Transaction_Amount):
        self.Account_Number=Account_Number
        self.Transaction_Type=Transaction_Type
        self.Transaction_Amount=Transaction_Amount
class Timestampeditem:
    def __init__(self,date,time):
        self.date=date
        self.time=time
class BankTransaction(Transaction,Timestampeditem):
    def __init__(self,Account_Number,Transaction_Type,Transaction_Amount,date,time):
        Transaction.__init__(self,Account_Number,Transaction_Type,Transaction_Amount)
        Timestampeditem.__init__(self,date,time)
    def show_Account(self):
        print("Account Number:",Account_Number)
        print("Transaction Type:",Transasction_Type)
        print("Transaction Amount:",Transaction_Amount)
        print("date:",self.date)
        print("Time:",self.time)
b1=BankTransaction(Account_Number,Transasction_Type,Transaction_Amount,date1,time1)
b1.show_Account()
# Out:
# Account Number: ACC-1053
# Account Number: 542198746325
# Transaction Type: UPI
# Transaction Amount: 25000
# date: 2026-09-09
# Time: 12:25:35

# %% [markdown]
# 54.Create a account factory for banking case 2; use sample reference `ACC-1054` and explain the result.

# %%
Account_Number='ACC-1054'
print("Account Number:",Account_Number)
Account_Number=int(input("Enter Account Number:"))
Account_Holder_Name=input("Enyter Account Holder Name:")
Balance=int(input("Enter Amount:"))
Account_Type=input("Enter Account Type:")
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_Account(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Customer Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Account Type:",self.Account_Type)
a1=Account(Account_Holder_Name,Account_Number,Balance,Account_Type)
a1.show_Account()
# Out:
# Account Number: ACC-1054
# Customer Name: Rayavaram Sai Vighnesh
# Customer Account Number: 213654789632
# Balance: 69000
# Account Type: Savings

# %% [markdown]
# 55.Apply a strategy for interest offers for banking case 2; use sample reference `ACC-1055` and explain the result.

# %%
Account_Number='ACC-1055'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Name:")
Account_Number=int(input("Enter Account Number:"))
age=int(input("Enter Age:"))
Account_Type=input("Enter Account Type:")
transfer_balance=int(input("Enter Transfer Balance:"))
balance=int(input("Enter Balance:"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,age,Account_Type,balance,transfer_balance):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Age=age
        self.Account_Type=Account_Type
        self.balance=balance
        self.transfer_balance=transfer_balance
    def show_intrest(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Age:",self.Age)
        print("Account Number:",self.Account_Number)
        print("Account Type:",self.Account_Type)
        print("Balance:",self.balance)
        print("Transfer Balance:",transfer_balance)
        if(self.Age >10 and self.Age <60):
            print("Interst:4%")
        elif(self.Age >= 60):
            print("Interst:7%")
        elif(self.Account_Type=='Fixed'):
            print("Interst:8%")
        elif((self.Age >0 and self.Age< 60) and (transfer_balance > 100000)):
            print("Interst:9%")
        elif((self.Age >0 and self.Age< 60) and (self.Account_Type=='Fixed')):
            print("Interst:6%")
b1=Banking(Account_Holder_Name,Account_Number,age,Account_Type,balance,transfer_balance)
b1.show_intrest()
# Out:
# Account Number: ACC-1055
# Customer Name: Rayavaram Sai Vighnesh
# Age: 45
# Account Number: 213654897063
# Account Type: Savings
# Balance: 982300
# Transfer Balance: 25000
# Interst:4%

# %% [markdown]
# 56. Encapsulate balance reservation for banking case 2; use sample reference `ACC-1056` and explain the result.

# %%
Account_Number='ACC-1056'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
reserve_Balance=int(input("Enter Reserve Balance:"))
payament_Status=input("Enter Payment Status:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,reserve_Balance,payment_Status):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self._reserve_Balance=reserve_Balance
        self.payment_Status=payment_Status
    def show_balance(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Reserve Balance:",self._reserve_Balance)
        if(self.payment_Status =='Yes'):
            if(self._reserve_Balance <= self.Balance):
                self.Balance=self.Balance-self._reserve_Balance
                print("Available Balance:",self.Balance)
            else:
                print("Insufficient Balance")
        else:
            print("Payment Status Failed")
b1=Banking(Account_Holder_Name,Account_Number,Balance,reserve_Balance,payament_Status)
b1.show_balance()
# Out:
# Account Number: ACC-1056
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 546213987263
# Balance: 65300
# Reserve Balance: 50000
# Payment Status Failed

# %% [markdown]
# 57. Model aggregation between branch and employees for banking case 2; use sample reference `ACC-1057` and explain the result.

# %%
Account_Number='ACC-1057'
print("Account Number:",Account_Number)
Employee_Name=input("Enter Employee Name:")
Employee_Id=input("Enter Employee ID:")
Employee_Branch=input("Enter Branch Name:")
Employee_new_Branch=input("Enter New Branch:")
Salary=int(input("Enter Salary:"))
new_salary=int(input("Enter New Salary:"))
Role=input("Enter Role:")
class Branch1:
    def __init__(self,Employee_Name,Employee_Id,Employee_Branch,salary,Role):
        self.Employee_Name=Employee_Name
        self.Employee_Id=Employee_Id
        self.Employee_Branch=Employee_Branch
        self.Salary=salary
        self.Role=Role
class Branch2:
    def __init__(self,Employee_new_Branch,new_salary,Role):
        self.Employee_new_Branch=Employee_new_Branch
        self.new_salary=new_salary
        self.Role=Role
class Branch:
    def __init__(self,Employee_Name,Employee_Id,Employee_Branch,salary,Role,Employee_new_Branch,new_salary):
        Branch1.__init__(self,Employee_Name,Employee_Id,Employee_Branch,salary,Role)
        Branch2.__init__(self,Employee_new_Branch,new_salary,Role)
    def show_branch(self):
        print("Employee Name:",self.Employee_Name)
        print("Employee_Id:",self.Employee_Id)
        print("Employee Old Branch:",self.Employee_Branch)
        print("Employee Branch:",self.Employee_new_Branch)
        print("Salary:",self.new_salary)
        print("Role:",self.Role)
B1=Branch(Employee_Name,Employee_Id,Employee_Branch,Salary,Role,Employee_new_Branch,new_salary)
B1.show_branch()
# Out:
# Account Number: ACC-1057
# Employee Name: Rayavaram Sai Vighnesh
# Employee_Id: EMP-1002
# Employee Old Branch: Vempalli
# Employee Branch: Pulivendula
# Salary: 45000
# Role: Manager

# %% [markdown]
# 58.Serialize an transfer to a dictionary for banking case 2; use sample reference `ACC-1058` and explain the result.

# %%
Account_Number='ACC-1058'
print("Account Number:",Account_Number)
Transaction_ID=input("Enter Transaction Id")
sender_Id=input("Enter Sender ID:")
Receiver_Id=input("Enter Receiver ID:")
Amount=int(input("Enter Amount:"))
Status=input("Enter Status:")
dict1={
    "Transaction_Id":"",
    "Sender Id":"",
    "Receiver_ID":"",
    "Amount":0,
    "Status":""

}
class Transfer:
    def __init__(self,Transaction_ID,sender_Id,Receiver_Id,Amount,Status):
        self.Transaction_ID=Transaction_ID
        self.sender_id=sender_Id
        self.Receiver_Id=Receiver_Id
        self.Amount=Amount
        self.Status=Status
    def shoe_transfer(self):
        dict1["Transaction_Id"]=self.Transaction_ID
        dict1["Sender Id"]=self.sender_id
        dict1["Receiver_ID"]=self.Receiver_Id
        dict1["Amount"]=self.Amount
        dict1["Status"]=self.Status
        print(dict1)
t1=Transfer(Transaction_ID,sender_Id,Receiver_Id,Amount,Status)
t1.shoe_transfer()
# Out:
# Account Number: ACC-1058
# {'Transaction_Id': 'TR-542', 'Sender Id': '54123695', 'Receiver_ID': '45621396', 'Amount': 26300, 'Status': 'Success'}

# %% [markdown]
# 59.Implement a repository abstraction for banking case 2; use sample reference `ACC-1059` and explain the result.

# %%
# Account class
class Account:
    def __init__(self, account_number, account_holder, balance):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance

    def show_details(self):
        print("Account Number:", self.account_number)
        print("Account Holder:", self.account_holder)
        print("Balance:", self.balance)


# Repository abstraction
class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def add_account(self, account):
        self.accounts[account.account_number] = account

    def find_account(self, account_number):
        return self.accounts.get(account_number)

    def update_account(self, account):
        self.accounts[account.account_number] = account

    def delete_account(self, account_number):
        if account_number in self.accounts:
            del self.accounts[account_number]

    def get_all_accounts(self):
        return self.accounts.values()


# Create account
account1 = Account("ACC-1059", "Sai Vignesh", 50000)

# Create repository
repository = AccountRepository()

# Add account to repository
repository.add_account(account1)

# Find account
account = repository.find_account("ACC-1059")

# Display result
if account:
    print("Account Found")
    account.show_details()
else:
    print("Account Not Found")
# Out:
# Account Found
# Account Number: ACC-1059
# Account Holder: Sai Vignesh
# Balance: 50000

# %% [markdown]
# 60.Apply dependency injection to checkout for banking case 2; use sample reference `ACC-1060` and explain the result.

# %%
Account_Number='ACC-1060'
print("Account Number:",Account_Number)
Payment_Process=input("Select the payment process:")
class Checkout:
    def __init__(self,Payement_Processor):
        self.Payment_Processor=Payement_Processor
    def show_Checkout(self):
        print("Select the payment Process:",self.Payment_Processor)
        print("Payment process successfully completed")
c1=Checkout(Payment_Process)
c1.show_Checkout()
# Out:
# Account Number: ACC-1060
# Select the payment Process: Credit Card
# Payment process successfully completed

# %% [markdown]
# 61.Inherit perishableaccount from account for banking case 3; use sample reference `ACC-1061` and explain the result.

# %%
Account_Number='ACC-1061'
print("Account Number:",Account_Number)
from datetime import date
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balane=Balance
        self.Account_Type=Account_Type
        self.Deposit=Deposit
        self.Withdrawl=Withdrawl
class Account1(Account):
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl,Expiry_Date):
        super().__init__(Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,Withdrawl)
        self.Expiry_Date=Expiry_Date
    def show_account(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balane)
        print("Account Type:",self.Account_Type)
        print("Expiry Date:",self.Expiry_Date)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Amount:"))
Account_Type=input("Enter Account Type:")
Deposit=int(input("Enter Deposit Amount:"))
withdrawl=int(input("Enter Withdrawl Amount:"))
Expiry_Date=date.today()

a1=Account1(Account_Holder_Name,Account_Number,Balance,Account_Type,Deposit,withdrawl,Expiry_Date)
a1.show_account()
# Out:
# Account Number: ACC-1061
# Customer Name: Rayavaram Sai Vighnesh
# Account Number: 213546897026
# Balance: 54233
# Account Type: Savings
# Expiry Date: 2026-09-09

# %% [markdown]
# 62.Override a discount method for banking case 3; use sample reference `ACC-1062` and explain the result.

# %%
Account_Number='ACC-1062'
print("Account Number:",Account_Number)
class Account:
    def __init__(self,discount):
        self.discount=discount
    def discount1(self,percentage):
        print("Discount Percent:",percentage)
class Loyality(Account):
    def __init__(self,discount):
        super().__init__(discount)
    def discount1(self,Percentage):
        print("Discount Percentage:",Percentage)
percentage=int(input("Enter Percentage:"))
l1=Loyality(4)
l1.discount1(percentage)
# Out:
# Account Number: ACC-1062
# Discount Percentage: 16

# %% [markdown]
# 63.Use polymorphic payment processors for banking case 3; use sample reference `ACC-1063` and explain the result.

# %%
Account_Number='ACC-1063'
print("Account Number:",Account_Number)
class Payment:
    def process_payment(self):
        print("Process Transaction")
class UPI(Payment):
    def process_payment(self):
        print("I am doing Payment transaction through UPI")
class Creditcard(Payment):
    def process_payment(self):
        print("I am doing Payment transaction through creditcard")
class Debitcard(Payment):
    def process_payment(self):
        print("I am doing payment transaction through Debit card")
class NetBanking(Payment):
    def process_payment(self):
        print("I am doing payment Transaction through NetBanking")
n1=NetBanking()
n1.process_payment()
d1=Debitcard()
d1.process_payment()
c1=Creditcard()
c1.process_payment()
u1=UPI()
u1.process_payment()
# Out:
# Account Number: ACC-1063
# I am doing payment Transaction through NetBanking
# I am doing payment transaction through Debit card
# I am doing Payment transaction through creditcard
# I am doing Payment transaction through UPI

# %% [markdown]
# 64.Compose transfer from transferline objects for banking case 3; use sample reference `ACC-1064` and explain the result.

# %%
from datetime import date
Account_Number='ACC-1064'
print("Account Number:",Account_Number)
class Transferline1:
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1):
        self.sender_account_number=Sender_Account_Number
        self.receiver_account_number=Receiver_Account_Number
        self.Amount1=Amount1
    def show_transfer1(self):
        print("Sender:",self.sender_account_number)
        print("Receiver:",self.receiver_account_number)
        print("Amount:",self.Amount1)
class Transferline2:
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount2):
        self.sender_account_number=Sender_Account_Number
        self.receiver_account_number=Receiver_Account_Number
        self.Amount2=Amount2
    def show_transfer2(self):
        print("Sender:",self.sender_account_number)
        print("Receiver:",self.receiver_account_number)
        print("Amount:",self.Amount2)
class Transfer(Transferline1,Transferline2):
    def __init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1,Amount2):
        Transferline1.__init__(self,Sender_Account_Number,Receiver_Account_Number,Amount1)
        Transferline2.__init__(self,Sender_Account_Number,Receiver_Account_Number,Amount2)
    def show_transfer(self):
        amount=self.Amount1+self.Amount2
        print("Date:",date.today())
        print("Status:Scuccess")
        print("Amount:",amount)
t1=Transferline1(123654789650,546987125306,5000)
t1.show_transfer1()
t2=Transferline2(546218723980,164785963015,5000)
t2.show_transfer2()
t=Transfer(546218723980,164785963015,5000,5000)
t.show_transfer()
# Out:
# Account Number: ACC-1064
# Sender: 123654789650
# Receiver: 546987125306
# Amount: 5000
# Sender: 546218723980
# Receiver: 164785963015
# Amount: 5000
# Date: 2026-09-09
# Status:Scuccess
# Amount: 10000

# %% [markdown]
# 65.Define an abstract paymentmethod for banking case 3; use sample reference `ACC-1065` and explain the result.

# %%
Account_Number='ACC-1065'
print("Account Number:",Account_Number)
from abc import ABC,abstractmethod
class Payment(ABC):
    @abstractmethod
    def paymentmethod(self):
        pass

class Payment1(Payment):
    def paymentmethod(self):
        print("I am doing payment transaction through UPI Payment")

class Payment2(Payment):
    def paymentmethod(self):
        print("I am doing payment transaction through Credit card Transaction")

class Payment3(Payment):
    def paymentmethod(self):
        print("I am doing Payment Transaction through Debit card Transaction")

class Payment4(Payment):
    def paymentmethod(self):
        print("I am doing payment Transaction through Net Banking")

p1=Payment1()
p1.paymentmethod()
p2=Payment2()
p2.paymentmethod()
p3=Payment3()
p3.paymentmethod()
p4=Payment4()
p4.paymentmethod()
# Out:
# Account Number: ACC-1065
# I am doing payment transaction through UPI Payment
# I am doing payment transaction through Credit card Transaction
# I am doing Payment Transaction through Debit card Transaction
# I am doing payment Transaction through Net Banking

# %% [markdown]
# 66.Use a dataclass for inventoryrecord for banking case 3; use sample reference `ACC-1066` and explain the result.

# %%
Account_Number='ACC-1066'
print("Account Number:",Account_Number)
class Data:
    def __init__(self,Item_id,Item_Name,Quantity,Branch,Status):
        self.Item_ID=Item_id
        self.Item_Name=Item_Name
        self.Quantity=Quantity
        self.Branch=Branch
        self.Status=Status
    def show_Store(self):
        print("Item_ID:",self.Item_ID)
        print("Item_Name:",self.Item_Name)
        print("Quantity:",self.Quantity)
        print("Branch:",self.Branch)
        print("Status:",self.Status)
Item_ID=input("Enter Input ID:")
Item_Name=input("Enter Item Name:")
Quantity=int(input("Enter Quantity:"))
Branch=input("Enter Branch Name:")
Status=input("Enter Status:")
d1=Data(Item_ID,Item_Name,Quantity,Branch,Status)
d1.show_Store()
# Out:
# Account Number: ACC-1066
# Item_ID: IT-102
# Item_Name: Mac Book
# Quantity: 2
# Branch: Vempalli
# Status: Working

# %% [markdown]
# 67.Implement a custom iterator for portfolio for banking case 3; use sample reference `ACC-1067` and explain the result.

# %%
Account_Number='ACC-1067'
print("Account Number:",Account_Number)
class Portfolio:
    def __init__(self,Account_Holder_name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_details(self):
        print("Account_Type:",self.Account_Type)
        print("Account Holder Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
p1=Portfolio("Rayavarm Sai Vighnesh",541236987012,54000,"Savings")
p1.show_details()
p2=Portfolio("Rayavaram Koushik",564879321025,546000,"Current")
p2.show_details()
p3=Portfolio("Rayavaram Kushal",874521369023,87000,"Fixed")
p3.show_details()
# Out:
# Account Number: ACC-1067
# Account_Type: Savings
# Account Holder Name: Rayavarm Sai Vighnesh
# Account Number: 541236987012
# Balance: 54000
# Account_Type: Current
# Account Holder Name: Rayavaram Koushik
# Account Number: 564879321025
# Balance: 546000
# Account_Type: Fixed
# Account Holder Name: Rayavaram Kushal
# Account Number: 874521369023
# Balance: 87000

# %% [markdown]
# 68.Use multiple inheritance carefully for timestampeditem for banking case 3; use sample reference `ACC-1068` and explain the result.

# %%
Account_Number='ACC-1068'
print("Account Number:",Account_Number)
from datetime import date
from datetime import datetime
Account_Number=int(input("Enter Amount Number:"))
Transasction_Type=input("Enter Transaction Type:")
Transaction_Amount=int(input("Enter Transaction Amount:"))
date1=date.today()
now=datetime.now()
time1=now.strftime("%H:%M:%S")
class Transaction:
    def __init__(self,Account_Number,Transaction_Type,Transaction_Amount):
        self.Account_Number=Account_Number
        self.Transaction_Type=Transaction_Type
        self.Transaction_Amount=Transaction_Amount
class Timestampeditem:
    def __init__(self,date,time):
        self.date=date
        self.time=time
class BankTransaction(Transaction,Timestampeditem):
    def __init__(self,Account_Number,Transaction_Type,Transaction_Amount,date,time):
        Transaction.__init__(self,Account_Number,Transaction_Type,Transaction_Amount)
        Timestampeditem.__init__(self,date,time)
    def show_Account(self):
        print("Account Number:",Account_Number)
        print("Transaction Type:",Transasction_Type)
        print("Transaction Amount:",Transaction_Amount)
        print("date:",self.date)
        print("Time:",self.time)
b1=BankTransaction(Account_Number,Transasction_Type,Transaction_Amount,date1,time1)
b1.show_Account()
# Out:
# Account Number: ACC-1068
# Account Number: 546213987023
# Transaction Type: Savings
# Transaction Amount: 25600
# date: 2026-09-09
# Time: 13:12:17

# %% [markdown]
# 69.Create a account factory for banking case 3; use sample reference `ACC-1069` and explain the result.

# %%
Account_Number='ACC-1069'
print("Account Number:",Account_Number)
Account_Number=int(input("Enter Account Number:"))
Account_Holder_Name=input("Enyter Account Holder Name:")
Balance=int(input("Enter Amount:"))
Account_Type=input("Enter Account Type:")
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.Account_Type=Account_Type
    def show_Account(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Customer Account Number:",self.Account_Number)
        print("Balance:",self.Balance)
        print("Account Type:",self.Account_Type)
a1=Account(Account_Holder_Name,Account_Number,Balance,Account_Type)
a1.show_Account()
# Out:
# Account Number: ACC-1069
# Customer Name: Rayavaram Sai Vighnesh
# Customer Account Number: 54869321569820
# Balance: 65320
# Account Type: Savings

# %% [markdown]
# 70.Apply a strategy for interest offers for banking case 3; use sample reference `ACC-1070` and explain the result.

# %%
Account_Number='ACC-1070'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Name:")
Account_Number=int(input("Enter Account Number:"))
age=int(input("Enter Age:"))
Account_Type=input("Enter Account Type:")
transfer_balance=int(input("Enter Transfer Balance:"))
balance=int(input("Enter Balance:"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,age,Account_Type,balance,transfer_balance):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Age=age
        self.Account_Type=Account_Type
        self.balance=balance
        self.transfer_balance=transfer_balance
    def show_intrest(self):
        print("Customer Name:",self.Account_Holder_Name)
        print("Age:",self.Age)
        print("Account Number:",self.Account_Number)
        print("Account Type:",self.Account_Type)
        print("Balance:",self.balance)
        print("Transfer Balance:",transfer_balance)
        if(self.Age >10 and self.Age <60):
            print("Interst:4%")
        elif(self.Age >= 60):
            print("Interst:7%")
        elif(self.Account_Type=='Fixed'):
            print("Interst:8%")
        elif((self.Age >0 and self.Age< 60) and (transfer_balance > 100000)):
            print("Interst:9%")
        elif((self.Age >0 and self.Age< 60) and (self.Account_Type=='Fixed')):
            print("Interst:6%")
b1=Banking(Account_Holder_Name,Account_Number,age,Account_Type,balance,transfer_balance)
b1.show_intrest()
# Out:
# Account Number: ACC-1070
# Customer Name: Rayavaram Sai Vighnesh
# Age: 25
# Account Number: 2134568793021
# Account Type: Savings
# Balance: 98000
# Transfer Balance: 25000
# Interst:4%

# %% [markdown]
# 71.Design an extensible pricing engine for banking case 1; use sample reference `ACC-1071` and explain the result.

# %%
Account_Number='ACC-1071'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Customer Name:")
Account_Number=int(input("Enter Account Number:"))
Age=int(input("Enter Age:"))
Balance=int(input("Enter Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
Account_Type=input("Enter Account Type:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Age,Balance,Transfer_Amount,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Age=Age
        self.Balance=Balance
        self.Transfer_Amount=Transfer_Amount
        self.Account_Type=Account_Type
    def show_pricing_engine(self):
        print("Name:",self.Account_Holder_Name)
        print("Age:",self.Age)
        print("Account Number:",self.Account_Number)
        print("Account Type:",self.Account_Type)
        if(self.Transfer_Amount >100000 and self.Account_Type=='Savings'):
            Transfer_Fee=10
            GST_Tax=8
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >100000 and self.Account_Type=='Fixed'):
            Transfer_Fee=8
            GST_Tax=6
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >50000 and self.Account_Type=='Fixed'):
            Transfer_Fee=6
            GST_Tax=4
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >50000 and self.Account_Type=='Savings'):
            Transfer_Fee=5
            GST_Tax=3
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount < 50000 and self.Account_Type=='Fixed'):
            Transfer_Fee=3
            GST_Tax=2
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount < 50000 and self.Account_Type=='Savings'):
            Transfer_Fee=4
            GST_Tax=3
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
b1=Banking(Account_Holder_Name,Account_Number,Age,Balance,Transfer_Amount,Account_Type)
b1.show_pricing_engine()
# Out:
# Account Number: ACC-1071
# Name: Rayavaram Sai Vighnesh
# Age: 22
# Account Number: 213546899721
# Account Type: Savings
# Transaction Amount: 230518

# %% [markdown]
# 72.Implement an observer for low balance for banking case 1; use sample reference `ACC-1072` and explain the result.

# %%
Account_Number='ACC-1072'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Balance=int(input("Enter Account Balance:"))
Minimum_Balance=int(input("Enter Minimum Balance:"))
class Balance:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Minimum_Balance):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Minimum_Balance=Minimum_Balance
    def checkBalance(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Minimum Balance:",self.Minimum_Balance)
        print("Account Balance:",self.Account_Balance)
        if(self.Account_Balance < Minimum_Balance):
            print("Please Maintain the minimum Balance in your Bank")
b1=Balance(Account_Holder_Name,Account_Number,Account_Balance,Minimum_Balance)
b1.checkBalance()
# Out:
# Account Number: ACC-1072
# Name: Sai
# Account Number: 213546879062
# Minimum Balance: 1000
# Account Balance: 200
# Please Maintain the minimum Balance in your Bank

# %% [markdown]
# 73.Build a state machine for transfer status for banking case 1; use sample reference `ACC-1073` and explain the result.

# %%
Account_Number='ACC-1073'
print("Account Number:",Account_Balance)
Account_Holder_Name=input("Enter Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Balance=int(input("Enter Account Balance:"))
Transfer_Amount=int(input("Enter Amount:"))
Transfer_Status=input("Enter Transfer Status:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Transfer_Amount,Transfer_Status):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Status=Transfer_Status
    def show_transfer_status(self):
        print("Name:",self,Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Account Balance:",self.Account_Balance)
        print("Transfer Amount:",self.Transfer_Amount)
        if(self.Transfer_Status=="Pending"):
            print("Transaction Status:Transfer has been created but is not completed yet")
        elif(self.Transfer_Status=="Processing"):
            print("Transfer Status:Bank is currently processing the transfer")
        elif(self.Transfer_Status=="Successful"):
            print("Transfer Status:Money has been transferred successfully.")
        elif(self.Transfer_Status=="Failed"):
            print("Transfer Status:Transfer could not be completed.")
        elif(self.Transfer_Status=="Cancelled"):
            print("Transfer Status:Transfer was cancelled before completion.")
b1=Banking(Account_Holder_Name,Account_Number,Account_Balance,Transfer_Amount,Transfer_Status)
b1.show_transfer_status()
# Out:
# Account Number: 65000
# Name: <__main__.Banking object at 0x000001E782D734D0> Sai
# Account Number: 214536987065
# Account Balance: 68000
# Transfer Amount: 25600
# Transaction Status:Transfer has been created but is not completed yet

# %% [markdown]
# 74. Create an immutable money value object for banking case 1; use sample reference `ACC-1074` and explain the result.

# %%
Account_Number='ACC-1074'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
count=int(input("Enter count"))
more=int(input("Enter More"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,count,more):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.more=more
        self.count=count
    def money(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Money:",self.Balance)
        if(self.count <=self.more):
            self.count=self.count+1
            self.Balance=int(input("Enter Balance:"))
            b1.money()
        
b1=Banking(Account_Holder_Name,Account_Number,Balance,count,more)
b1.money()
# Out:
# Account Number: ACC-1074
# Name: abcg
# Account Number: 12365478902
# Money: 500
# Name: abcg
# Account Number: 12365478902
# Money: 2000
# Name: abcg
# Account Number: 12365478902
# Money: 5000

# %% [markdown]
# 75Implement a unit-of-work transaction for banking case 1; use sample reference `ACC-1075` and explain the result.

# %%
Account_Number='ACC-1075'
print("Account Number:",Account_Number)
Account1_Balance=int(input("Enter Account1 Balance:"))
Account2_Balance=int(input("Enter Account2 Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,Account1_Balance,Account2_Balance,transfer_Balance):
        self.Account1_Balance=Account1_Balance
        self.Account2_Balance=Account2_Balance
        self.transfer_Balance=transfer_Balance
    def show_transaction(self):
        if(self.transfer_Balance<=self.Account1_Balance):
            self.Account1_Balance=self.Account1_Balance-self.transfer_Balance
            self.Account2_Balance=self.Account2_Balance+self.transfer_Balance
            print("Account1 Balance:",self.Account1_Balance)
            print("Account2 Balance:",self.Account2_Balance)
        else:
            print("Account1 Balance:",self.Account1_Balance)
            print("Account2 Balance:",self.Account2_Balance)
b1=Banking(Account1_Balance,Account2_Balance,transfer_Balance)
b1.show_transaction()
# Out:
# Account Number: ACC-1075
# Account1 Balance: 10000
# Account2 Balance: 95000

# %% [markdown]
# 76.Separate domain and infrastructure layers for banking case 1; use sample reference `ACC-1076` and explain the result.

# %%
Account_Number='ACC-1076'
print("Account Number:",Account_Number)
Account_Balance=int(input("Enter Balance:"))
transfer_Balance=int(input("Enter Transfer Balance"))
class Banking:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_domain_infrastructure(self):
        if(self.transfer_Balance <=self.Account_Balance):
            print("Transfering Amount:",self.transfer_Balance)
            self.Account_Balance=self.Account_Balance-self.transfer_Balance
            print("Account Balance:",self.Account_Balance)
        else:
            print("Insufficient Balance")
b1=Banking(Account_Balance,transfer_Balance)
b1.show_domain_infrastructure()
# Out:
# Account Number: ACC-1076
# Transfering Amount: 5000
# Account Balance: 51320

# %% [markdown]
# 77.Design a plugin-ready payment architecture for banking case 1; use sample reference `ACC-1077` and explain the result.

# %%
Account_Number='ACC-1077'
print("Account Number:",Account_Number)
select_payment=input("Select the payment process:")
Account_Balance=int(input("Enter The Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,select_payment,Account_Balance,transfer_Balance):
        self.select_payment=select_payment
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_architecture(self):
        print("Select Payment:",self.select_payment)
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully Completed")
        else:
            print("Payment Failed due to Insufficient Balance")
b1=Banking(select_payment,Account_Balance,transfer_Balance)
b1.show_architecture()
# Out:
# Account Number: ACC-1077
# Select Payment: UPI
# Payment Successfully Completed

# %% [markdown]
# 78.Implement a descriptor for positive amounts for banking case 1; use sample reference `ACC-1078` and explain the result.

# %%
Account_Number='ACC-1078'
print("Account Number:",Account_Number)
Account_Balance=int(input("Enter The Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_descriptor(self):
        if(self.Account_Balance>0):
            if(transfer_Balance > 0):
                print("Transaction Successfully completed")
            else:
                print("Transaction Amount is invalid")
        else:
            print("Account Balance is invalid")
b1=Banking(Account_Balance,transfer_Balance)
b1.show_descriptor()
# Out:
# Account Number: ACC-1078
# Transaction Successfully completed

# %% [markdown]
# 79.Use cooperative inheritance with super for banking case 1; use sample reference `ACC-1079` and explain the result.

# %%
Account_Number='ACC-1079'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Type=input("Enter Account Type:")
Account_Balance=int(input("Enter Balance"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking1:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Type=Account_Type
class Banking2:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
class Banking(Banking1,Banking2):
    def __init__(self,Account_Holder_Name,Account_Number,Account_Type,Account_Balance,transfer_Balance):
        Banking1.__init__(self,Account_Holder_Name,Account_Number,Account_Type)
        Banking2.__init__(self,Account_Balance,transfer_Balance)
    def inherit(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Transaction Balance:",self.transfer_Balance)
        print("Account Balance:",self.Account_Balance)
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully completed")
        else:
            print("Payment Failed due to insufficient Balance")
b1=Banking(Account_Holder_Name,Account_Number,Account_Type,Account_Balance,transfer_Balance)
b1.inherit()
# Out:
# Account Number: ACC-1079
# Name: vcgh
# Account Number: 52369871023
# Transaction Balance: 6000
# Account Balance: 65000
# Payment Successfully completed

# %% [markdown]
# 80.Refactor a god object using solid for banking case 1; use sample reference `ACC-1080` and explain the result.

# %%
Account_Number='ACC-1080'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Type=input("Enter Account Type")
Account_Balance=int(input("Enter Account Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Account_Type=Account_Type
    def show_Account(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Account Balance:",self.Account_Balance)
        print("Account Type:",self.Account_Type)
class Transfer:
    def __init__(self,transfer_Balance):
        self.transfer_Balance=transfer_Balance
    def show_transaction(self):
        print("Transfer Balance:",self.transfer_Balance)
class Payment:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_payment(self):
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully completed")
        else:
            print("Payment Failed due to insufficient balance")
class Notificaton:
    def notify(self):
        print("Customer get the message about payment status")
class Intrest:
    def show_intrest(self):
        print("Intrest:4%")
a1=Account(Account_Holder_Name,Account_Number,Account_Balance,Account_Type)
a1.show_Account()
t1=Transfer(transfer_Balance)
t1.show_transaction()
p1=Payment(Account_Balance,transfer_Balance)
p1.show_payment()
n1=Notificaton()
n1.notify()
i1=Intrest()
i1.show_intrest()
# Out:
# Account Number: ACC-1080
# Name: avcb
# Account Number: 21354687903
# Account Balance: 52000
# Account Type: savings
# Transfer Balance: 25000
# Payment Successfully completed
# Customer get the message about payment status
# Intrest:4%

# %% [markdown]
# 81.Design an extensible pricing engine for banking case 2; use sample reference `ACC-1081` and explain the result.

# %%
Account_Number='ACC-1081'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Customer Name:")
Account_Number=int(input("Enter Account Number:"))
Age=int(input("Enter Age:"))
Balance=int(input("Enter Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
Account_Type=input("Enter Account Type:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Age,Balance,Transfer_Amount,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Age=Age
        self.Balance=Balance
        self.Transfer_Amount=Transfer_Amount
        self.Account_Type=Account_Type
    def show_pricing_engine(self):
        print("Name:",self.Account_Holder_Name)
        print("Age:",self.Age)
        print("Account Number:",self.Account_Number)
        print("Account Type:",self.Account_Type)
        if(self.Transfer_Amount >100000 and self.Account_Type=='Savings'):
            Transfer_Fee=10
            GST_Tax=8
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >100000 and self.Account_Type=='Fixed'):
            Transfer_Fee=8
            GST_Tax=6
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >50000 and self.Account_Type=='Fixed'):
            Transfer_Fee=6
            GST_Tax=4
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >50000 and self.Account_Type=='Savings'):
            Transfer_Fee=5
            GST_Tax=3
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount < 50000 and self.Account_Type=='Fixed'):
            Transfer_Fee=3
            GST_Tax=2
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount < 50000 and self.Account_Type=='Savings'):
            Transfer_Fee=4
            GST_Tax=3
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
b1=Banking(Account_Holder_Name,Account_Number,Age,Balance,Transfer_Amount,Account_Type)
b1.show_pricing_engine()
# Out:
# Account Number: ACC-1081
# Name: vrcr
# Age: 22
# Account Number: 213564789032
# Account Type: Savings
# Transaction Amount: 25007

# %% [markdown]
# 82.Implement an observer for low balance for banking case 2; use sample reference `ACC-1082` and explain the result.

# %%
Account_Number='ACC-1082'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Balance=int(input("Enter Account Balance:"))
Minimum_Balance=int(input("Enter Minimum Balance:"))
class Balance:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Minimum_Balance):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Minimum_Balance=Minimum_Balance
    def checkBalance(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Minimum Balance:",self.Minimum_Balance)
        print("Account Balance:",self.Account_Balance)
        if(self.Account_Balance < Minimum_Balance):
            print("Please Maintain the minimum Balance in your Bank")
b1=Balance(Account_Holder_Name,Account_Number,Account_Balance,Minimum_Balance)
b1.checkBalance()
# Out:
# Account Number: ACC-1082
# Name: arbcvr
# Account Number: 2154368793026
# Minimum Balance: 2000
# Account Balance: 56000

# %% [markdown]
# 83.Build a state machine for transfer status for banking case 2; use sample reference `ACC-1083` and explain the result.

# %%
Account_Number='ACC-1083'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Balance=int(input("Enter Account Balance:"))
Transfer_Amount=int(input("Enter Amount:"))
Transfer_Status=input("Enter Transfer Status:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Transfer_Amount,Transfer_Status):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Status=Transfer_Status
    def show_transfer_status(self):
        print("Name:",self,Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Account Balance:",self.Account_Balance)
        print("Transfer Amount:",self.Transfer_Amount)
        if(self.Transfer_Status=="Pending"):
            print("Transaction Status:Transfer has been created but is not completed yet")
        elif(self.Transfer_Status=="Processing"):
            print("Transfer Status:Bank is currently processing the transfer")
        elif(self.Transfer_Status=="Successful"):
            print("Transfer Status:Money has been transferred successfully.")
        elif(self.Transfer_Status=="Failed"):
            print("Transfer Status:Transfer could not be completed.")
        elif(self.Transfer_Status=="Cancelled"):
            print("Transfer Status:Transfer was cancelled before completion.")
b1=Banking(Account_Holder_Name,Account_Number,Account_Balance,Transfer_Amount,Transfer_Status)
b1.show_transfer_status()
# Out:
# Account Number: ACC-1083
# Name: <__main__.Banking object at 0x000001AFA0F21A90> vasavi_Travels
# Account Number: 541236987065
# Account Balance: 25600
# Transfer Amount: 12500
# Transfer Status:Bank is currently processing the transfer

# %% [markdown]
# 84.Create an immutable money value object for banking case 2; use sample reference `ACC-1084` and explain the result.

# %%
Account_Number='ACC-1084'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
count=int(input("Enter count"))
more=int(input("Enter More"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,count,more):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.more=more
        self.count=count
    def money(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Money:",self.Balance)
        if(self.count <=self.more):
            self.count=self.count+1
            self.Balance=int(input("Enter Balance:"))
            b1.money()
        
b1=Banking(Account_Holder_Name,Account_Number,Balance,count,more)
b1.money()
# Out:
# Account Number: ACC-1084
# Name: prl Tarvels
# Account Number: 54368923015
# Money: 48000
# Name: prl Tarvels
# Account Number: 54368923015
# Money: 25600

# %% [markdown]
# 85.Implement a unit-of-work transaction for banking case 2; use sample reference `ACC-1085` and explain the result.

# %%
Account_Number='ACC-1085'
print("Account Number:",Account_Number)
Account1_Balance=int(input("Enter Account1 Balance:"))
Account2_Balance=int(input("Enter Account2 Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,Account1_Balance,Account2_Balance,transfer_Balance):
        self.Account1_Balance=Account1_Balance
        self.Account2_Balance=Account2_Balance
        self.transfer_Balance=transfer_Balance
    def show_transaction(self):
        if(self.transfer_Balance<=self.Account1_Balance):
            self.Account1_Balance=self.Account1_Balance-self.transfer_Balance
            self.Account2_Balance=self.Account2_Balance+self.transfer_Balance
            print("Account1 Balance:",self.Account1_Balance)
            print("Account2 Balance:",self.Account2_Balance)
        else:
            print("Account1 Balance:",self.Account1_Balance)
            print("Account2 Balance:",self.Account2_Balance)
b1=Banking(Account1_Balance,Account2_Balance,transfer_Balance)
b1.show_transaction()
# Out:
# Account Number: ACC-1085
# Account1 Balance: 30900
# Account2 Balance: 74800

# %% [markdown]
# 86.Separate domain and infrastructure layers for banking case 2; use sample reference `ACC-1086` and explain the result.

# %%
Account_Number='ACC-1086'
print("Account Number:",Account_Number)
Account_Balance=int(input("Enter Balance:"))
transfer_Balance=int(input("Enter Transfer Balance"))
class Banking:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_domain_infrastructure(self):
        if(self.transfer_Balance <=self.Account_Balance):
            print("Transfering Amount:",self.transfer_Balance)
            self.Account_Balance=self.Account_Balance-self.transfer_Balance
            print("Account Balance:",self.Account_Balance)
        else:
            print("Insufficient Balance")
b1=Banking(Account_Balance,transfer_Balance)
b1.show_domain_infrastructure()
# Out:
# Account Number: ACC-1086
# Transfering Amount: 24500
# Account Balance: 30300

# %% [markdown]
# 87.Design a plugin-ready payment architecture for banking case 2; use sample reference `ACC-1087` and explain the result.

# %%
Account_Number='ACC-1087'
print("Account Number:",Account_Number)
select_payment=input("Select the payment process:")
Account_Balance=int(input("Enter The Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,select_payment,Account_Balance,transfer_Balance):
        self.select_payment=select_payment
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_architecture(self):
        print("Select Payment:",self.select_payment)
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully Completed")
        else:
            print("Payment Failed due to Insufficient Balance")
b1=Banking(select_payment,Account_Balance,transfer_Balance)
b1.show_architecture()
# Out:
# Account Number: ACC-1087
# Select Payment: UPI
# Payment Successfully Completed

# %% [markdown]
# 88.Implement a descriptor for positive amounts for banking case 2; use sample reference `ACC-1088` and explain the result.

# %%
Account_Number='ACC-1088'
print("Account Number:",Account_Number)
Account_Balance=int(input("Enter The Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_descriptor(self):
        if(self.Account_Balance>0):
            if(transfer_Balance > 0):
                print("Transaction Successfully completed")
            else:
                print("Transaction Amount is invalid")
        else:
            print("Account Balance is invalid")
b1=Banking(Account_Balance,transfer_Balance)
b1.show_descriptor()
# Out:
# Account Number: ACC-1088
# Transaction Successfully completed

# %% [markdown]
# 89. Use cooperative inheritance with super for banking case 2; use sample reference `ACC-1089` and explain the result.

# %%
Account_Number='ACC-1089'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Type=input("Enter Account Type:")
Account_Balance=int(input("Enter Balance"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking1:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Type=Account_Type
class Banking2:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
class Banking(Banking1,Banking2):
    def __init__(self,Account_Holder_Name,Account_Number,Account_Type,Account_Balance,transfer_Balance):
        Banking1.__init__(self,Account_Holder_Name,Account_Number,Account_Type)
        Banking2.__init__(self,Account_Balance,transfer_Balance)
    def inherit(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Transaction Balance:",self.transfer_Balance)
        print("Account Balance:",self.Account_Balance)
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully completed")
        else:
            print("Payment Failed due to insufficient Balance")
b1=Banking(Account_Holder_Name,Account_Number,Account_Type,Account_Balance,transfer_Balance)
b1.inherit()
# Out:
# Account Number: ACC-1089
# Name: nbgt
# Account Number: 452187963025
# Transaction Balance: 2
# Account Balance: 1
# Payment Failed due to insufficient Balance

# %% [markdown]
# 90.Refactor a god object using solid for banking case 2; use sample reference `ACC-1090` and explain the result.

# %%
Account_Number='ACC-1090'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Type=input("Enter Account Type")
Account_Balance=int(input("Enter Account Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Account_Type=Account_Type
    def show_Account(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Account Balance:",self.Account_Balance)
        print("Account Type:",self.Account_Type)
class Transfer:
    def __init__(self,transfer_Balance):
        self.transfer_Balance=transfer_Balance
    def show_transaction(self):
        print("Transfer Balance:",self.transfer_Balance)
class Payment:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_payment(self):
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully completed")
        else:
            print("Payment Failed due to insufficient balance")
class Notificaton:
    def notify(self):
        print("Customer get the message about payment status")
class Intrest:
    def show_intrest(self):
        print("Intrest:4%")
a1=Account(Account_Holder_Name,Account_Number,Account_Balance,Account_Type)
a1.show_Account()
t1=Transfer(transfer_Balance)
t1.show_transaction()
p1=Payment(Account_Balance,transfer_Balance)
p1.show_payment()
n1=Notificaton()
n1.notify()
i1=Intrest()
i1.show_intrest()
# Out:
# Account Number: ACC-1090
# Name: uhgt
# Account Number: 478596321056
# Account Balance: 58412
# Account Type: Savings
# Transfer Balance: 21456
# Payment Successfully completed
# Customer get the message about payment status
# Intrest:4%

# %% [markdown]
# 91. Design an extensible pricing engine for banking case 3; use sample reference `ACC-1091` and explain the result.

# %%
Account_Number='ACC-1091'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Customer Name:")
Account_Number=int(input("Enter Account Number:"))
Age=int(input("Enter Age:"))
Balance=int(input("Enter Balance:"))
Transfer_Amount=int(input("Enter Transfer Amount:"))
Account_Type=input("Enter Account Type:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Age,Balance,Transfer_Amount,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Age=Age
        self.Balance=Balance
        self.Transfer_Amount=Transfer_Amount
        self.Account_Type=Account_Type
    def show_pricing_engine(self):
        print("Name:",self.Account_Holder_Name)
        print("Age:",self.Age)
        print("Account Number:",self.Account_Number)
        print("Account Type:",self.Account_Type)
        if(self.Transfer_Amount >100000 and self.Account_Type=='Savings'):
            Transfer_Fee=10
            GST_Tax=8
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >100000 and self.Account_Type=='Fixed'):
            Transfer_Fee=8
            GST_Tax=6
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >50000 and self.Account_Type=='Fixed'):
            Transfer_Fee=6
            GST_Tax=4
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount >50000 and self.Account_Type=='Savings'):
            Transfer_Fee=5
            GST_Tax=3
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount < 50000 and self.Account_Type=='Fixed'):
            Transfer_Fee=3
            GST_Tax=2
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
        elif(self.Transfer_Amount < 50000 and self.Account_Type=='Savings'):
            Transfer_Fee=4
            GST_Tax=3
            self.Transfer_Amount=self.Transfer_Amount+Transfer_Fee+GST_Tax
            print("Transaction Amount:",self.Transfer_Amount)
b1=Banking(Account_Holder_Name,Account_Number,Age,Balance,Transfer_Amount,Account_Type)
b1.show_pricing_engine()
# Out:
# Account Number: ACC-1091
# Name: sdfer
# Age: 22
# Account Number: 417258963032
# Account Type: Savings
# Transaction Amount: 21485

# %% [markdown]
# 92.Implement an observer for low balance for banking case 3; use sample reference `ACC-1092` and explain the result.

# %%
Account_Number='ACC-1092'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Balance=int(input("Enter Account Balance:"))
Minimum_Balance=int(input("Enter Minimum Balance:"))
class Balance:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Minimum_Balance):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Minimum_Balance=Minimum_Balance
    def checkBalance(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Minimum Balance:",self.Minimum_Balance)
        print("Account Balance:",self.Account_Balance)
        if(self.Account_Balance < Minimum_Balance):
            print("Please Maintain the minimum Balance in your Bank")
b1=Balance(Account_Holder_Name,Account_Number,Account_Balance,Minimum_Balance)
b1.checkBalance()
# Out:
# Account Number: ACC-1092
# Name: lopk
# Account Number: 7485690132
# Minimum Balance: 1000
# Account Balance: 2560

# %% [markdown]
# 93.Build a state machine for transfer status for banking case 3; use sample reference `ACC-1093` and explain the result.

# %%
Account_Number='ACC-1093'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Balance=int(input("Enter Account Balance:"))
Transfer_Amount=int(input("Enter Amount:"))
Transfer_Status=input("Enter Transfer Status:")
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Transfer_Amount,Transfer_Status):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Transfer_Amount=Transfer_Amount
        self.Transfer_Status=Transfer_Status
    def show_transfer_status(self):
        print("Name:",self,Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Account Balance:",self.Account_Balance)
        print("Transfer Amount:",self.Transfer_Amount)
        if(self.Transfer_Status=="Pending"):
            print("Transaction Status:Transfer has been created but is not completed yet")
        elif(self.Transfer_Status=="Processing"):
            print("Transfer Status:Bank is currently processing the transfer")
        elif(self.Transfer_Status=="Successful"):
            print("Transfer Status:Money has been transferred successfully.")
        elif(self.Transfer_Status=="Failed"):
            print("Transfer Status:Transfer could not be completed.")
        elif(self.Transfer_Status=="Cancelled"):
            print("Transfer Status:Transfer was cancelled before completion.")
b1=Banking(Account_Holder_Name,Account_Number,Account_Balance,Transfer_Amount,Transfer_Status)
b1.show_transfer_status()
# Out:
# Account Number: ACC-1093
# Name: <__main__.Banking object at 0x000001AFA1011940> gftd
# Account Number: 741258963021
# Account Balance: 78000
# Transfer Amount: 14200
# Transfer Status:Transfer could not be completed.

# %% [markdown]
# 94.Create an immutable money value object for banking case 3; use sample reference `ACC-1094` and explain the result.

# %%
Account_Number='ACC-1094'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Name:")
Account_Number=int(input("Enter Account Number:"))
Balance=int(input("Enter Balance:"))
count=int(input("Enter count"))
more=int(input("Enter More"))
class Banking:
    def __init__(self,Account_Holder_Name,Account_Number,Balance,count,more):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Balance=Balance
        self.more=more
        self.count=count
    def money(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Money:",self.Balance)
        if(self.count <=self.more):
            self.count=self.count+1
            self.Balance=int(input("Enter Balance:"))
            b1.money()
        
b1=Banking(Account_Holder_Name,Account_Number,Balance,count,more)
b1.money()
# Out:
# Account Number: ACC-1094
# Name: dfgt
# Account Number: 741369852014
# Money: 96000
# Name: dfgt
# Account Number: 741369852014
# Money: 51000

# %% [markdown]
# 95.Implement a unit-of-work transaction for banking case 3; use sample reference `ACC-1095` and explain the result.

# %%
Account_Number='ACC-1095'
print("Account Number:",Account_Number)
Account1_Balance=int(input("Enter Account1 Balance:"))
Account2_Balance=int(input("Enter Account2 Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,Account1_Balance,Account2_Balance,transfer_Balance):
        self.Account1_Balance=Account1_Balance
        self.Account2_Balance=Account2_Balance
        self.transfer_Balance=transfer_Balance
    def show_transaction(self):
        if(self.transfer_Balance<=self.Account1_Balance):
            self.Account1_Balance=self.Account1_Balance-self.transfer_Balance
            self.Account2_Balance=self.Account2_Balance+self.transfer_Balance
            print("Account1 Balance:",self.Account1_Balance)
            print("Account2 Balance:",self.Account2_Balance)
        else:
            print("Account1 Balance:",self.Account1_Balance)
            print("Account2 Balance:",self.Account2_Balance)
b1=Banking(Account1_Balance,Account2_Balance,transfer_Balance)
b1.show_transaction()
# Out:
# Account Number: ACC-1095
# Account1 Balance: 30200
# Account2 Balance: 40380

# %% [markdown]
# 96.Separate domain and infrastructure layers for banking case 3; use sample reference `ACC-1096` and explain the result.

# %%
Account_Number='ACC-1096'
print("Account Number:",Account_Number)
Account_Balance=int(input("Enter Balance:"))
transfer_Balance=int(input("Enter Transfer Balance"))
class Banking:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_domain_infrastructure(self):
        if(self.transfer_Balance <=self.Account_Balance):
            print("Transfering Amount:",self.transfer_Balance)
            self.Account_Balance=self.Account_Balance-self.transfer_Balance
            print("Account Balance:",self.Account_Balance)
        else:
            print("Insufficient Balance")
b1=Banking(Account_Balance,transfer_Balance)
b1.show_domain_infrastructure()
# Out:
# Account Number: ACC-1096
# Transfering Amount: 24500
# Account Balance: 20500

# %% [markdown]
# 97.Design a plugin-ready payment architecture for banking case 3; use sample reference `ACC-1097` and explain the result.

# %%
Account_Number='ACC-1097'
print("Account Number:",Account_Number)
select_payment=input("Select the payment process:")
Account_Balance=int(input("Enter The Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,select_payment,Account_Balance,transfer_Balance):
        self.select_payment=select_payment
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_architecture(self):
        print("Select Payment:",self.select_payment)
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully Completed")
        else:
            print("Payment Failed due to Insufficient Balance")
b1=Banking(select_payment,Account_Balance,transfer_Balance)
b1.show_architecture()
# Out:
# Account Number: ACC-1097
# Select Payment: UPI
# Payment Successfully Completed

# %% [markdown]
# 98.Implement a descriptor for positive amounts for banking case 3; use sample reference `ACC-1098` and explain the result.

# %%
Account_Number='ACC-1098'
print("Account Number:",Account_Number)
Account_Balance=int(input("Enter The Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_descriptor(self):
        if(self.Account_Balance>0):
            if(transfer_Balance > 0):
                print("Transaction Successfully completed")
            else:
                print("Transaction Amount is invalid")
        else:
            print("Account Balance is invalid")
b1=Banking(Account_Balance,transfer_Balance)
b1.show_descriptor()
# Out:
# Account Number: ACC-1098
# Transaction Successfully completed

# %% [markdown]
# 99.Use cooperative inheritance with super for banking case 3; use sample reference `ACC-1099` and explain the result.

# %%
Account_Number='ACC-1099'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Type=input("Enter Account Type:")
Account_Balance=int(input("Enter Balance"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Banking1:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Type=Account_Type
class Banking2:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
class Banking(Banking1,Banking2):
    def __init__(self,Account_Holder_Name,Account_Number,Account_Type,Account_Balance,transfer_Balance):
        Banking1.__init__(self,Account_Holder_Name,Account_Number,Account_Type)
        Banking2.__init__(self,Account_Balance,transfer_Balance)
    def inherit(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Transaction Balance:",self.transfer_Balance)
        print("Account Balance:",self.Account_Balance)
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully completed")
        else:
            print("Payment Failed due to insufficient Balance")
b1=Banking(Account_Holder_Name,Account_Number,Account_Type,Account_Balance,transfer_Balance)
b1.inherit()
# Out:
# Account Number: ACC-1099
# Name: redt
# Account Number: 912345687023
# Transaction Balance: 45890
# Account Balance: 87000
# Payment Successfully completed

# %% [markdown]
# 100.Refactor a god object using solid for banking case 3; use sample reference `ACC-1100` and explain the result.

# %%
Account_Number='ACC-1100'
print("Account Number:",Account_Number)
Account_Holder_Name=input("Enter Account Holder Name:")
Account_Number=int(input("Enter Account Number:"))
Account_Type=input("Enter Account Type")
Account_Balance=int(input("Enter Account Balance:"))
transfer_Balance=int(input("Enter Transfer Balance:"))
class Account:
    def __init__(self,Account_Holder_Name,Account_Number,Account_Balance,Account_Type):
        self.Account_Holder_Name=Account_Holder_Name
        self.Account_Number=Account_Number
        self.Account_Balance=Account_Balance
        self.Account_Type=Account_Type
    def show_Account(self):
        print("Name:",self.Account_Holder_Name)
        print("Account Number:",self.Account_Number)
        print("Account Balance:",self.Account_Balance)
        print("Account Type:",self.Account_Type)
class Transfer:
    def __init__(self,transfer_Balance):
        self.transfer_Balance=transfer_Balance
    def show_transaction(self):
        print("Transfer Balance:",self.transfer_Balance)
class Payment:
    def __init__(self,Account_Balance,transfer_Balance):
        self.Account_Balance=Account_Balance
        self.transfer_Balance=transfer_Balance
    def show_payment(self):
        if(self.transfer_Balance <= self.Account_Balance):
            print("Payment Successfully completed")
        else:
            print("Payment Failed due to insufficient balance")
class Notificaton:
    def notify(self):
        print("Customer get the message about payment status")
class Intrest:
    def show_intrest(self):
        print("Intrest:4%")
a1=Account(Account_Holder_Name,Account_Number,Account_Balance,Account_Type)
a1.show_Account()
t1=Transfer(transfer_Balance)
t1.show_transaction()
p1=Payment(Account_Balance,transfer_Balance)
p1.show_payment()
n1=Notificaton()
n1.notify()
i1=Intrest()
i1.show_intrest()
# Out:
# Account Number: ACC-1100
# Name: hgyt
# Account Number: 945612387012
# Account Balance: 98500
# Account Type: Savings
# Transfer Balance: 45621
# Payment Successfully completed
# Customer get the message about payment status
# Intrest:4%
