# %%
Account_number='ACC-1001'
balance=int(input("Enter Balance:"))
deposit_amount=int(input("Enter Deposit Amount:"))
try:
    if(deposit_amount < 0):
        raise Exception("Deposit amount caannot be negative")
except Exception as e:
    print(e)
else:
    balance=balance + deposit_amount
    print("Account Number:",Account_number)
    print("Deposit Money:",deposit_amount)
    print("New Balanace:",balance)
# Out:
# Account Number: ACC-1001
# Deposit Money: 25000
# New Balanace: 60000

# %% [markdown]
# 2.Handle a missing account key for banking case 1; use sample reference `ACC-1002` and explain the result.

# %%
details={
    "name":["Kartheek", "Bhairaveswar Reddy"]
}
len1=len(details)
name=input("Enter Name:")
try:
     if(name not in details["name"]):
        raise Exception("Name not found")
except Exception as e:
    print(e)
else:
    print(name)
# Out:
# Name not found

# %% [markdown]
# 3.Prevent division by zero in average balance for banking case 1; use sample reference `ACC-1003` and explain the result.

# %%
Account_Number='ACC-1003'
print("Account_Number:",Account_Number)
Balance=int(input("Enter Balance:"))
b=0
if True:
    try:
        c=Balance/b
    except Exception as e:
        print("Number Cannot be divided by zero")
# Out:
# Account_Number: ACC-1003
# Number Cannot be divided by zero

# %% [markdown]
# 4.Open a transaction file safely for banking case 1; use sample reference `ACC-1004` and explain the result.

# %%
Account_number='ACC-1004'
print("Account Number:",Account_number)
try:
    data=file.open("sample.txt")
except:
    print("Transaction file is missing")
# Out:
# Account Number: ACC-1004
# Transaction file is missing

# %% [markdown]
# 5.Reject a negative withdrawal for banking case 1; use sample reference `ACC-1005` and explain the result.

# %%
Account_Number='Acc-1005'
print("Account_Number:",Account_Number)
with_drawl=int(input("Enter withdraw amount:"))
try:
    if(with_drawl < 0):
        raise Exception("Withdrwal amount cannot be negative")
except Exception as e:
    print(e)
else:
    print("With Drawl Amount:",with_drawl)
# Out:
# Account_Number: Acc-1005
# Withdrwal amount cannot be negative

# %% [markdown]
# 6.Catch invalid tenure input for banking case 1; use sample reference `ACC-1006` and explain the result.

# %%
Duration=int(input("Enter The Duration:"))
tenure=int(input("Enter the Tenure:"))
try:
    if(Duration > tenure):
        raise Exception("Invalid Tenure Input")
except Exception as e:
    print(e)
else:
    print("Duration:",Duration)
    print("Tenure:",tenure)
# Out:
# Invalid Tenure Input

# %% [markdown]
# 7.Use else after pin-format validation for banking case 1; use sample reference `ACC-1007` and explain the result.

# %%
Account_Number='ACC-1007'
print("Account_Number:",Account_Number)
pin=15698
user_pin=int(input("Enter Pin:"))
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
except Exception as e:
    print(e)
else:
    print("Pin is Valid")
# Out:
# Account_Number: ACC-1007
# Pin is Valid

# %% [markdown]
# 8.Use finally to close a session for banking case 1; use sample reference `ACC-1008` and explain the result.

# %%
Account_Number='ACC-1008'
print("Account_Number:",Account_Number)
pin=15698
user_input=int(input("Enter Pin:"))
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
except Exception as e:
    print(e)
finally:
    print("successfully Excuted the code")
# Out:
# Account_Number: ACC-1008
# successfully Excuted the code

# %% [markdown]
# 9.Catch multiple numeric conversion errors for banking case 1; use sample reference `ACC-1009` and explain the result.

# %%
Account_Number='ACC-1009'
print("ACCOUNT-Number:",Account_Number)
pin="12345"
user_pin=input("Enter pin:")
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
    if(len(user_pin) != len(pin)):
        raise Exception("Invalid pin length")
    if(not user_pin.isnumeric()):
       raise Exception("Pin sholud be numeric")
except Exception as e:
    print(e)
# Out:
# ACCOUNT-Number: ACC-1009
# Invalid Pin

# %% [markdown]
# 10.Raise a clear valueerror for banking case 1; use sample reference `ACC-1010` and explain the result.

# %%
Account_Number='ACC-1010'
print("Account_Number:",Account_Number)
name="Kartheek"
try:
    b=int(name)
except Exception as e:
    print(e)
else:
    print("Name")
finally:
    print("Success")
# Out:
# Account_Number: ACC-1010
# invalid literal for int() with base 10: 'Kartheek'
# Success

# %% [markdown]
# 11.Parse a deposit amount for banking case 2; use sample reference `ACC-1011` and explain the result.

# %%
Account_Number='ACC-1011'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
deposit_amount=int(input("Enter Deposit Amount:"))
try:
    if(deposit_amount < 0):
        raise Exception("Deposit amount caannot be negative")
except Exception as e:
    print(e)
else:
    balance=balance + deposit_amount
    print("Account Number:",Account_Number)
    print("Deposit Money:",deposit_amount)
    print("New Balanace:",balance)
# Out:
# Account_Number: ACC-1011
# Deposit amount caannot be negative

# %% [markdown]
# 12.Handle a missing account key for banking case 2; use sample reference `ACC-1012` and explain the result.

# %%
Account_Number='ACC-1012'
print("Account_Number:",Account_Number)
details={
    "name":["Jayanth", "Vijay"]
}
name=input("Enter Name:")
try:
     if(name not in details["name"]):
        raise Exception("Name not found")
except Exception as e:
    print(e)
else:
    print(name)
# Out:
# Account_Number: ACC-1012
# Name not found

# %% [markdown]
# 13.Prevent division by zero in average balance for banking case 2; use sample reference `ACC-1013` and explain the result.

# %%
Account_Number='ACC-1013'
print("Account_Number:",Account_Number)
Balance=int(input("Enter Balance:"))
b=0
if True:
    try:
        c=Balance/b
    except Exception as e:
        print("Number Cannot be divided by zero")
# Out:
# Account_Number: ACC-1013
# Number Cannot be divided by zero

# %% [markdown]
# 14.Open a transaction file safely for banking case 2; use sample reference `ACC-1014` and explain the result.

# %%
Account_number='ACC-1014'
print("Account Number:",Account_number)
try:
    data=file.open("Transaction.csv")
except:
    print("Transaction file is missing")
# Out:
# Account Number: ACC-1014
# Transaction file is missing

# %% [markdown]
# 15.Reject a negative withdrawal for banking case 2; use sample reference `ACC-1015` and explain the result.

# %%
Account_Number='ACC-1015'
print("Account_Number:",Account_Number)
with_drawl=int(input("Enter withdraw amount:"))
try:
    if(with_drawl < 0):
        raise Exception("Withdrwal amount cannot be negative")
except Exception as e:
    print(e)
else:
    print("With Drawl Amount:",with_drawl)
# Out:
# Account_Number: ACC-1015
# Withdrwal amount cannot be negative

# %% [markdown]
# 16.Catch invalid tenure input for banking case 2; use sample reference `ACC-1016` and explain the result.

# %%
Account_Number='ACC-1016'
print("Account_Number:",Account_Number)
Duration=int(input("Enter The Duration:"))
tenure=int(input("Enter the Tenure:"))
try:
    if(Duration > tenure):
        raise Exception("Invalid Tenure Input")
except Exception as e:
    print(e)
else:
    print("Duration:",Duration)
    print("Tenure:",tenure)
# Out:
# Account_Number: ACC-1016
# Invalid Tenure Input

# %% [markdown]
# 17.Use else after pin-format validation for banking case 2; use sample reference `ACC-1017` and explain the result.

# %%
Account_Number='ACC-1017'
print("Account_Number:",Account_Number)
pin=15698
user_pin=int(input("Enter Pin:"))
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
except Exception as e:
    print(e)
else:
    print("Pin is Valid")
# Out:
# Account_Number: ACC-1017
# Invalid Pin

# %% [markdown]
# 18. Use finally to close a session for banking case 2; use sample reference `ACC-1018` and explain the result.

# %%
Account_Number='ACC-1018'
print("Account_Number:",Account_Number)
pin=15698
user_input=int(input("Enter Pin:"))
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
except Exception as e:
    print(e)
else:
    print("Pin is valid")
finally:
    print("successfully Excuting the code")
# Out:
# Account_Number: ACC-1018
# Invalid Pin
# successfully Excuting the code

# %% [markdown]
# 19.Catch multiple numeric conversion errors for banking case 2; use sample reference `ACC-1019` and explain the result.

# %%
Account_Number='ACC-1019'
print("ACCOUNT-Number:",Account_Number)
pin="12345"
user_pin=input("Enter pin:")
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
    if(len(user_pin) != len(pin)):
        raise Exception("Invalid pin length")
    if(not user_pin.isnumeric()):
       raise Exception("Pin sholud be numeric")
except Exception as e:
    print(e)
# Out:
# ACCOUNT-Number: ACC-1019
# Invalid Pin

# %% [markdown]
# 20.Raise a clear valueerror for banking case 2; use sample reference `ACC-1020` and explain the result.

# %%
Account_Number='ACC-1020'
print("Account_Number:",Account_Number)
name="Vijay"
try:
    b=int(name)
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1020
# invalid literal for int() with base 10: 'Vijay'

# %% [markdown]
# 21.Parse a deposit amount for banking case 3; use sample reference `ACC-1021` and explain the result.

# %%
Account_Number='ACC-1021'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
deposit_amount=int(input("Enter Deposit Amount:"))
try:
    if(deposit_amount < 0):
        raise Exception("Deposit amount caannot be negative")
except Exception as e:
    print(e)
else:
    balance=balance + deposit_amount
    print("Account Number:",Account_Number)
    print("Deposit Money:",deposit_amount)
    print("New Balanace:",balance)
# Out:
# Account_Number: ACC-1021
# Deposit amount caannot be negative

# %% [markdown]
# 22.Handle a missing account key for banking case 3; use sample reference `ACC-1022` and explain the result.

# %%
Account_Number='ACC-1022'
print("Account_Number:",Account_Number)
details={
    "name":["Ravi Teja", "Teja"]
}
name=input("Enter Name:")
try:
     if(name not in details["name"]):
        raise Exception("Name not found")
except Exception as e:
    print(e)
else:
    print(name)
# Out:
# Account_Number: ACC-1022
# Ravi Teja

# %% [markdown]
# 23.Prevent division by zero in average balance for banking case 3; use sample reference `ACC-1023` and explain the result.

# %%
Account_Number='ACC-1023'
print("Account_Number:",Account_Number)
Balance=int(input("Enter Balance:"))
b=0
if True:
    try:
        c=Balance/b
    except Exception as e:
        print("Number Cannot be divided by zero")
# Out:
# Account_Number: ACC-1023
# Number Cannot be divided by zero

# %% [markdown]
# 24.Open a transaction file safely for banking case 3; use sample reference `ACC-1024` and explain the result.

# %%
Account_Number='ACC-1024'
print("Account_Number:",Account_Number)
try:
    data=file.open("Transaction.csv")
except:
    print("Transactions file is missing")
# Out:
# Account_Number: ACC-1024
# Transactions file is missing

# %% [markdown]
# 25.Reject a negative withdrawal for banking case 3; use sample reference `ACC-1025` and explain the result.

# %%
Account_Number='ACC-1025'
print("Account_Number:",Account_Number)
with_drawl=int(input("Enter withdraw amount:"))
try:
    if(with_drawl < 0):
        raise Exception("Withdrwal amount cannot be negative")
except Exception as e:
    print(e)
else:
    print("With Drawl Amount:",with_drawl)
# Out:
# Account_Number: ACC-1025
# Withdrwal amount cannot be negative

# %% [markdown]
# 26.Catch invalid tenure input for banking case 3; use sample reference `ACC-1026` and explain the result.

# %%
Account_Number='ACC-1026'
print("Account_Number:",Account_Number)
Duration=int(input("Enter The Duration:"))
tenure=int(input("Enter the Tenure:"))
try:
    if(Duration > tenure):
        raise Exception("Invalid Tenure Input")
except Exception as e:
    print(e)
else:
    print("Duration:",Duration)
    print("Tenure:",tenure)
# Out:
# Account_Number: ACC-1026
# Invalid Tenure Input

# %% [markdown]
# 27.Use else after pin-format validation for banking case 3; use sample reference `ACC-1027` and explain the result.

# %%
Account_Number='ACC-1027'
print("Account_Number:",Account_Number)
pin=79939
user_pin=int(input("Enter Pin:"))
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
except Exception as e:
    print(e)
else:
    print("Pin is Valid")
# Out:
# Account_Number: ACC-1027
# Pin is Valid

# %% [markdown]
# 28.Use finally to close a session for banking case 3; use sample reference `ACC-1028` and explain the result.

# %%
Account_Number='ACC-1028'
print("Account_Number:",Account_Number)
user_input=int(input("Enter Pin:"))
pin=54698
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
except Exception as e:
    print(e)
else:
    print("Pin is valid")
finally:
    print("successfully Executing the code")
# Out:
# Account_Number: ACC-1028
# Invalid Pin
# successfully Executing the code

# %% [markdown]
# 29.Catch multiple numeric conversion errors for banking case 3; use sample reference `ACC-1029` and explain the result.

# %%
Account_Number='ACC-1029'
print("Account_Number:",Account_Number)
pin="12345"
user_pin=input("Enter pin:")
try:
    if(user_pin != pin):
        raise Exception("Invalid Pin")
    if(len(user_pin) != len(pin)):
        raise Exception("Invalid pin length")
    if(not user_pin.isnumeric()):
       raise Exception("Pin sholud be numeric")
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1029
# Invalid Pin

# %% [markdown]
# 30.Raise a clear valueerror for banking case 3; use sample reference `ACC-1030` and explain the result.

# %%
Account_Number='ACC-1030'
print("Account_Number:",Account_Number)
name="Bhairaveswar Reddy"
try:
    b=int(name)
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1030
# invalid literal for int() with base 10: 'Bhairaveswar Reddy'

# %% [markdown]
# 31.Create insufficientfundserror for banking case 1; use sample reference `ACC-1031` and explain the result.

# %%
Account_Number='ACC-1031'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
with_drawl=int(input("Enter Withdraw Amount:"))
try:
    if(with_drawl > balance):
        raise Exception("Insufficient Funds Error")
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1031
# Insufficient Funds Error

# %% [markdown]
# 32.Chain invalidtransactionerror from valueerror for banking case 1; use sample reference `ACC-1032` and explain the result.

# %%
Account_Number='ACC-1032'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
transaction_type='UPI'
holder_Account_Number=input("Enter account number:")
holder_transaction_type=input("Enter Transaction Type:")
holder_transaction_amount=int(input("Enter Amount:"))
try:
    if(holder_Account_Number != Account_Number):
        raise Exception("Invalid Account Number")
    if(holder_transaction_type != transaction_type):
        raise Exception("Invalid Transaction Type")
    if(holder_transaction_amount > balance):
        raise Exception("Insufficient Balance")
except Exception as e:
    print(e)
else:
    print("Your Transaction is successful")
# Out:
# Account_Number: ACC-1032
# Insufficient Balance

# %% [markdown]
# 33.Process transfers while isolating bad rows for banking case 1; use sample reference `ACC-1033` and explain the result.

# %%
Account_Number='ACC-1033'
print("Account_Number:",Account_Number)
Total_Number_of_Transactions=int(input("Enter Total Number of Transactions:"))
Successfully_Completed_Transactions=int(input("Enter Successfully Transactions:"))
bad_Transactions=Total_Number_of_Transactions-Successfully_Completed_Transactions
try:
    if(bad_Transactions >0):
        raise Exception(f"{bad_Transactions} Transactions are failed")
except Exception as e:
    print(e)
else:
    print("All Transactions are completed Successfully")
# Out:
# Account_Number: ACC-1033
# 30 Transactions are failed

# %% [markdown]
# 34.Retry a transient payment gateway for banking case 1; use sample reference `ACC-1034` and explain the result.

# %%
Account_Number='ACC-1034'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
transfer_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_Amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    transfer_Amount=int(input("Enter Transfer money:"))
    try:
        if(transfer_Amount > balance):
                raise Exception("Insufficient Money")
    except Exception as e:
         print("Insufficient Money")
    else:
         print("Successfully Transferred money")
else:
     print("Successfully Transferred Money")
# Out:
# Account_Number: ACC-1034
# Successfully Transferred money

# %% [markdown]
# 35.Log failed standing instructions for banking case 1; use sample reference `ACC-1035` and explain the result.

# %%
Account_Number='ACC-1035'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
Monthly_EMI=int(input("Enter EMI amount:"))
try:
    if(Monthly_EMI > balance):
        raise Exception("Payment Failed due to Insufficient Balance")
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1035
# Payment Failed due to Insufficient Balance

# %% [markdown]
# 36.Return a structured failure result for banking case 1; use sample reference `ACC-1036` and explain the result.

# %%
Account_Number='ACC-1036'
print("Account_Number:",Account_Number)
amount=int(input("Enter Balance:"))
transfer_amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    print("Status:Fail")
    print(e)
else:
    print("Status:True")
    print("Payment Successful")
# Out:
# Account_Number: ACC-1036
# Status:Fail
# Insufficient Money

# %% [markdown]
# 37.Validate a nested beneficiary record for banking case 1; use sample reference `ACC-1037` and explain the result.

# %%
Account_Number='ACC-1037'
print("Account_Number:",Account_Number)
account_name="Kartheek"
IFSC_code="SBI5236985632"
Mobile_Number=8796541230
Reciever_Account_Number=input("Enter Account Number:")
Reciever_Name=input("Enter Name:")
Reciever_IFSC_Code=input("Enter IFSC Code:")
Reciever_Mobile_Number=int(input("Enter Mobile Number:"))
try:
    if(Reciever_Name != account_name):
        raise Exception("Name is incorrect")
    if(Account_Number != Reciever_Account_Number):
        raise Exception("Account Number is incorrect")
    if(IFSC_code != Reciever_IFSC_Code):
        raise Exception("IFSC Code is incorrect")
    if(Mobile_Number != Reciever_Mobile_Number):
        raise Exception("Mobile Number is incorrect")
except Exception as e:
    print(e)
else:
    print("Your details are correct")
# Out:
# Account_Number: ACC-1037
# IFSC Code is incorrect

# %% [markdown]
# 38.Use a context manager for an audit file for banking case 1; use sample reference `ACC-1038` and explain the result.

# %%
Account_Number='ACC-1038'
print("Account_Number:",Account_Number)
account_number=input("Enter Account Number:")
name=input("Enter Name:")
IFSC_Code=input("Enter IFSC Code:")
Mobile_Number=input("Enter Mobile Number:")
try:
    if(not name.isalpha()):
        raise Exception("Name is not valid")
    if(not account_number.isnumeric()):
        raise Exception("Account Number is not valid")
    if(not IFSC_Code.isalnum()):
        raise Exception("IFSC code is not valid")
    if(not Mobile_Number.isnumeric()):
        raise Exception("Mobile Number is not valid")
except Exception as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account_Number: ACC-1038
# All details are correct

# %% [markdown]
# 39.Separate validation and recovery for banking case 1; use sample reference `ACC-1039` and explain the result.

# %%
Account_Number='ACC-1039'
print("Account_Number:",Account_Number)
Balance=int(input("Enter Balance: "))
Name="Sai"
transfer_Amount=int(input("Enter Transfer Amount:"))
UPI_Id='7993923717@asd'
customer_UPI_ID=input("Enter UPI:")
count=0
count1=0
try:
    if(UPI_Id!=customer_UPI_ID):
        count=count+1
        raise Exception("UPI_Id is wrong")
    if(transfer_Amount > Balance):
        count1=count1+1
        raise Exception("Transfer Amount is less than the balance")
except Exception as e:
    print(e)
    if(count==1):
        UPI_Id=input("Enter Correct UPI_Id:")
        raise Exception("UPI_Id is incorrect")
    if(count1==1):
        transfer_Amount=int(input("Enter the money less than the balance"))
        raise Exception("Check your balance due to insufficient balance")
else:
    print("Successfully Transfer Money")
# Out:
# Account_Number: ACC-1039
# Successfully Transfer Money

# %% [markdown]
# 40.Collect all kyc validation errors for banking case 1; use sample reference `ACC-1040` and explain the result.

# %%
Account_Number = 'ACC-1040'
print("Account_Number:", Account_Number)
class Banking(Exception):
    pass
class Insufficientbalance(Banking):
    pass
class IncorrectName(Banking):
    pass
class IncorrectAccountNumber(Banking):
    pass
class InvalidTransaction(Banking):
    pass

balance = int(input("Enter Amount:"))
transaction_amount = int(input("Enter Transaction Amount:"))
Name = input("Enter Name:")
errors = []
try:
    if not Name.startswith("Ray"):
        errors.append("Customer Name is wrong")
    if transaction_amount > balance:
        errors.append("Insufficient Balance")
    if not Account_Number.startswith("ACC-"):
        errors.append("Incorrect Account Number")
    if transaction_amount <= 0:
        errors.append("Transaction amount should be greater than zero")
    if errors:
        raise Banking("Multiple errors found")
except Banking:
    for error in errors:
        print(error)
else:
    print("All details are correct")
# Out:
# Account_Number: ACC-1040
# Customer Name is wrong
# Insufficient Balance

# %% [markdown]
# 41. Create insufficientfundserror for banking case 2; use sample reference `ACC-1041` and explain the result.

# %%
Account_Number='ACC-1041'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
with_drawl=int(input("Enter Withdraw Amount:"))
try:
    if(with_drawl > balance):
        raise Exception("Insufficient Funds Error")
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1041
# Insufficient Funds Error

# %% [markdown]
# 42.Chain invalidtransactionerror from valueerror for banking case 2; use sample reference `ACC-1042` and explain the result.

# %%
Account_Number='ACC-1042'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
transaction_type='UPI'
holder_Account_Number=input("Enter account number:")
holder_transaction_type=input("Enter Transaction Type:")
holder_transaction_amount=int(input("Enter Amount:"))
try:
    if(holder_Account_Number != Account_Number):
        raise Exception("Invalid Account Number")
    if(holder_transaction_type != transaction_type):
        raise Exception("Invalid Transaction Type")
    if(holder_transaction_amount > balance):
        raise Exception("Insufficient Balance")
except Exception as e:
    print(e)
else:
    print("Your Transaction is successful")
# Out:
# Account_Number: ACC-1042
# Your Transaction is successful

# %% [markdown]
# 43.Process transfers while isolating bad rows for banking case 2; use sample reference `ACC-1043` and explain the result.

# %%
Account_Number='ACC-1043'
print("Account_Number:",Account_Number)
Total_Number_of_Transactions=int(input("Enter Total Number of Transactions:"))
Successfully_Completed_Transactions=int(input("Enter Successfully Transactions:"))
bad_Transactions=Total_Number_of_Transactions-Successfully_Completed_Transactions
try:
    if(bad_Transactions >0):
        raise Exception(f"{bad_Transactions} Transactions are failed")
except Exception as e:
    print(e)
else:
    print("All Transactions are completed Successfully")
# Out:
# Account_Number: ACC-1043
# 25 Transactions are failed

# %% [markdown]
# 44.Retry a transient payment gateway for banking case 2; use sample reference `ACC-1044` and explain the result.

# %%
Account_Number='ACC-1044'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
transfer_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_Amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    transfer_Amount=int(input("Enter Transfer money:"))
    try:
        if(transfer_Amount > balance):
                raise Exception("Insufficient Money")
    except Exception as e:
         print("Insufficient Money")
    else:
         print("Successfully Transferred money")
else:
     print("Successfully Transferred Money")
# Out:
# Account_Number: ACC-1044
# Successfully Transferred Money

# %% [markdown]
# 45.Log failed standing instructions for banking case 2; use sample reference `ACC-1045` and explain the result.

# %%
Account_Number='ACC-1045'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
Monthly_EMI=int(input("Enter EMI amount:"))
try:
    if(Monthly_EMI > balance):
        raise Exception("Payment Failed due to Insufficient Balance")
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1045
# Payment Failed due to Insufficient Balance

# %% [markdown]
# 46.Return a structured failure result for banking case 2; use sample reference `ACC-1046` and explain the result.

# %%
Account_Number='ACC-1046'
print("Account_Number:",Account_Number)
amount=int(input("Enter Balance:"))
transfer_amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    print("Status:Fail")
    print(e)
else:
    print("Status:True")
    print("Payment Successful")
# Out:
# Account_Number: ACC-1046
# Status:True
# Payment Successful

# %% [markdown]
# 47.Validate a nested beneficiary record for banking case 2; use sample reference `ACC-1047` and explain the result.

# %%
Account_Number='ACC-1047'
print("Account_Number:",Account_Number)
account_name="Kartheek"
IFSC_code="SBI5236985632"
Mobile_Number=8796541230
Reciever_Account_Number=input("Enter Account Number:")
Reciever_Name=input("Enter Name:")
Reciever_IFSC_Code=input("Enter IFSC Code:")
Reciever_Mobile_Number=int(input("Enter Mobile Number:"))
try:
    if(Reciever_Name != account_name):
        raise Exception("Name is incorrect")
    if(Account_Number != Reciever_Account_Number):
        raise Exception("Account Number is incorrect")
    if(IFSC_code != Reciever_IFSC_Code):
        raise Exception("IFSC Code is incorrect")
    if(Mobile_Number != Reciever_Mobile_Number):
        raise Exception("Mobile Number is incorrect")
except Exception as e:
    print(e)
else:
    print("Your details are correct")
# Out:
# Account_Number: ACC-1047
# Account Number is incorrect

# %% [markdown]
# 48. Use a context manager for an audit file for banking case 2; use sample reference `ACC-1048` and explain the result.

# %%
Account_Number='ACC-1048'
print("Account_Number:",Account_Number)
account_number=input("Enter Account Number:")
name=input("Enter Name:")
IFSC_Code=input("Enter IFSC Code:")
Mobile_Number=input("Enter Mobile Number:")
try:
    if(not name.isalpha()):
        raise Exception("Name is not valid")
    if(not account_number.isnumeric()):
        raise Exception("Account Number is not valid")
    if(not IFSC_Code.isalnum()):
        raise Exception("IFSC code is not valid")
    if(not Mobile_Number.isnumeric()):
        raise Exception("Mobile Number is not valid")
except Exception as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account_Number: ACC-1048
# All details are correct

# %% [markdown]
# 49.Separate validation and recovery for banking case 2; use sample reference `ACC-1049` and explain the result.

# %%
Account_Number='ACC-1049'
print("Account_Number:",Account_Number)
Balance=int(input("Enter Balance: "))
Name="Sai"
transfer_Amount=int(input("Enter Transfer Amount:"))
UPI_Id='7993923717@asd'
customer_UPI_ID=input("Enter UPI:")
try:
    if(UPI_Id != customer_UPI_ID):
        raise Exception("Enter Correct upi id")
except:
    UPI_Id=input("Enter correct UPI_ID:")
    try:
        if(UPI_Id != customer_UPI_ID):
            raise Exception("Enter Correct UPI Id")
    except Exception as e:
        print(e)
    else:
        print("Your UPI ID Is correct")
else:
    print("Your upi id is correct")
try:
    if(transfer_Amount > Balance):
        raise Exception("transfer amount is greater than the balance")
except Exception as e:
    transfer_Amount=int(input("Enter tranfer amount is less than the balamce:"))
    try:
        if(transfer_Amount > balance):
            raise Exception("transfer amount is greater than the balance")
    except Exception as e:
        print(e)
    else:
        print("Transaction successfully Completed")
else:
    print("Transaction Successfully completed")
# Out:
# Account_Number: ACC-1049
# Your upi id is correct
# Transaction Successfully completed

# %% [markdown]
# 50.Collect all kyc validation errors for banking case 2; use sample reference `ACC-1050` and explain the result.

# %%
Account_Number = 'ACC-1050'
print("Account_Number:", Account_Number)
class Banking(Exception):
    pass
class Insufficientbalance(Banking):
    pass
class IncorrectName(Banking):
    pass
class IncorrectAccountNumber(Banking):
    pass
class InvalidTransaction(Banking):
    pass
balance = int(input("Enter Amount:"))
transaction_amount = int(input("Enter Transaction Amount:"))
Name = input("Enter Name:")
errors = []
try:
    if not Name.startswith("Ray"):
        errors.append("Customer Name is wrong")
    if transaction_amount > balance:
        errors.append("Insufficient Balance")
    if not Account_Number.startswith("ACC-"):
        errors.append("Incorrect Account Number")
    if transaction_amount <= 0:
        errors.append("Transaction amount should be greater than zero")
    if errors:
        raise Banking("Multiple errors found")
except Banking:
    for error in errors:
        print(error)
else:
    print("All details are correct")
# Out:
# Account_Number: ACC-1050
# Customer Name is wrong
# Insufficient Balance

# %% [markdown]
# 51.Create insufficientfundserror for banking case 3; use sample reference `ACC-1051` and explain the result.

# %%
Account_Number='ACC-1051'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
with_drawl=int(input("Enter Withdraw Amount:"))
try:
    if(with_drawl > balance):
        raise Exception("Insufficient Funds Error")
except Exception as e:
    print(e)
# Out:
# Account Number: ACC-1051
# Insufficient Funds Error

# %% [markdown]
# 52.Chain invalidtransactionerror from valueerror for banking case 3; use sample reference `ACC-1052` and explain the result.

# %%
Account_Number='ACC-1052'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
transaction_type='UPI'
holder_Account_Number=input("Enter account number:")
holder_transaction_type=input("Enter Transaction Type:")
holder_transaction_amount=int(input("Enter Amount:"))
try:
    if(holder_Account_Number != Account_Number):
        raise Exception("Invalid Account Number")
    if(holder_transaction_type != transaction_type):
        raise Exception("Invalid Transaction Type")
    if(holder_transaction_amount > balance):
        raise Exception("Insufficient Balance")
except Exception as e:
    print(e)
else:
    print("Your Transaction is successful")
# Out:
# Account Number: ACC-1052
# Insufficient Balance

# %% [markdown]
# 53.Process transfers while isolating bad rows for banking case 3; use sample reference `ACC-1053` and explain the result.

# %%
Account_Number='ACC-1053'
print("Account Number:",Account_Number)
Total_Number_of_Transactions=int(input("Enter Total Number of Transactions:"))
Successfully_Completed_Transactions=int(input("Enter Successfully Transactions:"))
bad_Transactions=Total_Number_of_Transactions-Successfully_Completed_Transactions
try:
    if(bad_Transactions >0):
        raise Exception(f"{bad_Transactions} Transactions are failed")
except Exception as e:
    print(e)
else:
    print("All Transactions are completed Successfully")
# Out:
# Account Number: ACC-1053
# 104 Transactions are failed

# %% [markdown]
# 54.Retry a transient payment gateway for banking case 3; use sample reference `ACC-1054` and explain the result.

# %%
Account_Number='ACC-1054'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
transfer_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_Amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    transfer_Amount=int(input("Enter Transfer money:"))
    try:
        if(transfer_Amount > balance):
                raise Exception("Insufficient Money")
    except Exception as e:
         print("Insufficient Money")
    else:
         print("Successfully Transferred money")
else:
     print("Successfully Transferred Money")
# Out:
# Account Number: ACC-1054
# Successfully Transferred money

# %% [markdown]
# 55.Log failed standing instructions for banking case 3; use sample reference `ACC-1055` and explain the result.

# %%
Account_Number='ACC-1055'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
Monthly_EMI=int(input("Enter EMI amount:"))
try:
    if(Monthly_EMI > balance):
        raise Exception("Payment Failed due to Insufficient Balance")
except Exception as e:
    print(e)
# Out:
# Account Number: ACC-1055
# Payment Failed due to Insufficient Balance

# %% [markdown]
# 56.Return a structured failure result for banking case 3; use sample reference `ACC-1056` and explain the result.

# %%
Account_Number='ACC-1056'
print("Account_Number:",Account_Number)
amount=int(input("Enter Balance:"))
transfer_amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    print("Status:Fail")
    print(e)
else:
    print("Status:True")
    print("Payment Successful")
# Out:
# Account_Number: ACC-1056
# Status:Fail
# Insufficient Money

# %% [markdown]
# 57.Validate a nested beneficiary record for banking case 3; use sample reference `ACC-1057` and explain the result.

# %%
Account_Number='ACC-1057'
print("Account Number:",Account_Number)
account_name="Kartheek"
IFSC_code="SBI5236985632"
Mobile_Number=8796541230
Reciever_Account_Number=input("Enter Account Number:")
Reciever_Name=input("Enter Name:")
Reciever_IFSC_Code=input("Enter IFSC Code:")
Reciever_Mobile_Number=int(input("Enter Mobile Number:"))
try:
    if(Reciever_Name != account_name):
        raise Exception("Name is incorrect")
    if(Account_Number != Reciever_Account_Number):
        raise Exception("Account Number is incorrect")
    if(IFSC_code != Reciever_IFSC_Code):
        raise Exception("IFSC Code is incorrect")
    if(Mobile_Number != Reciever_Mobile_Number):
        raise Exception("Mobile Number is incorrect")
except Exception as e:
    print(e)
else:
    print("Your details are correct")
# Out:
# Account Number: ACC-1057
# Mobile Number is incorrect

# %% [markdown]
# 58.Use a context manager for an audit file for banking case 3; use sample reference `ACC-1058` and explain the result.

# %%
Account_Number='ACC-1058'
print("Account Number:",Account_Number)
account_number=input("Enter Account Number:")
name=input("Enter Name:")
IFSC_Code=input("Enter IFSC Code:")
Mobile_Number=input("Enter Mobile Number:")
try:
    if(not name.isalpha()):
        raise Exception("Name is not valid")
    if(not account_number.isnumeric()):
        raise Exception("Account Number is not valid")
    if(not IFSC_Code.isalnum()):
        raise Exception("IFSC code is not valid")
    if(not Mobile_Number.isnumeric()):
        raise Exception("Mobile Number is not valid")
except Exception as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account Number: ACC-1058
# Account Number is not valid

# %% [markdown]
# 59.Separate validation and recovery for banking case 3; use sample reference `ACC-1059` and explain the result.

# %%
Account_Number='ACC-1059'
print("Account Number:",Account_Number)
Balance=int(input("Enter Balance: "))
Name="Sai"
transfer_Amount=int(input("Enter Transfer Amount:"))
UPI_Id='7993923717@asd'
customer_UPI_ID=input("Enter UPI:")
try:
    if(UPI_Id != customer_UPI_ID):
        raise Exception("Enter Correct upi id")
except:
    UPI_Id=input("Enter correct UPI_ID:")
    try:
        if(UPI_Id != customer_UPI_ID):
            raise Exception("Enter Correct UPI Id")
    except Exception as e:
        print(e)
    else:
        print("Your UPI ID Is correct")
else:
    print("Your upi id is correct")
try:
    if(transfer_Amount > Balance):
        raise Exception("transfer amount is greater than the balance")
except Exception as e:
    transfer_Amount=int(input("Enter tranfer amount is less than the balamce:"))
    try:
        if(transfer_Amount > balance):
            raise Exception("transfer amount is greater than the balance")
    except Exception as e:
        print(e)
    else:
        print("Transaction successfully Completed")
else:
    print("Transaction Successfully completed")
# Out:
# Account Number: ACC-1059
# Your upi id is correct
# Transaction Successfully completed

# %% [markdown]
# 60.Collect all kyc validation errors for banking case 3; use sample reference `ACC-1060` and explain the result.

# %%
Account_Number='ACC-1060'
print("Account Number:",Account_Number)
class Banking(Exception):
    pass
class Insufficientbalance(Banking):
    pass
class IncorrectName(Banking):
    pass
class IncorrectAccountNumber(Banking):
    pass
class InvalidTransaction(Banking):
    pass
balance = int(input("Enter Amount:"))
transaction_amount = int(input("Enter Transaction Amount:"))
Name = input("Enter Name:")
errors = []
try:
    if not Name.startswith("Ray"):
        errors.append("Customer Name is wrong")
    if transaction_amount > balance:
        errors.append("Insufficient Balance")
    if not Account_Number.startswith("ACC-"):
        errors.append("Incorrect Account Number")
    if transaction_amount <= 0:
        errors.append("Transaction amount should be greater than zero")
    if errors:
        raise Banking("Multiple errors found")
except Banking:
    for error in errors:
        print(error)
else:
    print("All details are correct")
# Out:
# Account Number: ACC-1060
# Customer Name is wrong
# Insufficient Balance

# %% [markdown]
# 61. Create insufficientfundserror for banking case 4; use sample reference `ACC-1061` and explain the result.

# %%
Account_Number='ACC-1061'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
with_drawl=int(input("Enter Withdraw Amount:"))
try:
    if(with_drawl > balance):
        raise Exception("Insufficient Funds Error")
except Exception as e:
    print(e)
# Out:
# Account Number: ACC-1061
# Insufficient Funds Error

# %% [markdown]
# 62.Chain invalidtransactionerror from valueerror for banking case 4; use sample reference `ACC-1062` and explain the result.

# %%
Account_Number='ACC-1062'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
transaction_type='UPI'
holder_Account_Number=input("Enter account number:")
holder_transaction_type=input("Enter Transaction Type:")
holder_transaction_amount=int(input("Enter Amount:"))
try:
    if(holder_Account_Number != Account_Number):
        raise Exception("Invalid Account Number")
    if(holder_transaction_type != transaction_type):
        raise Exception("Invalid Transaction Type")
    if(holder_transaction_amount > balance):
        raise Exception("Insufficient Balance")
except Exception as e:
    print(e)
else:
    print("Your Transaction is successful")
# Out:
# Account_Number: ACC-1062
# Insufficient Balance

# %% [markdown]
# 63.Process transfers while isolating bad rows for banking case 4; use sample reference `ACC-1063` and explain the result.

# %%
Account_Number='ACC-1063'
print("Account Number:",Account_Number)
Total_Number_of_Transactions=int(input("Enter Total Number of Transactions:"))
Successfully_Completed_Transactions=int(input("Enter Successfully Transactions:"))
bad_Transactions=Total_Number_of_Transactions-Successfully_Completed_Transactions
try:
    if(bad_Transactions >0):
        raise Exception(f"{bad_Transactions} Transactions are failed")
except Exception as e:
    print(e)
else:
    print("All Transactions are completed Successfully")
# Out:
# Account Number: ACC-1063
# 2 Transactions are failed

# %% [markdown]
# 64.Retry a transient payment gateway for banking case 4; use sample reference `ACC-1064` and explain the result.

# %%
Account_Number='ACC-1064'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
transfer_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_Amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    transfer_Amount=int(input("Enter Transfer money:"))
    try:
        if(transfer_Amount > balance):
                raise Exception("Insufficient Money")
    except Exception as e:
         print("Insufficient Money")
    else:
         print("Successfully Transferred money")
else:
     print("Successfully Transferred Money")
# Out:
# Account Number: ACC-1064
# Successfully Transferred Money

# %% [markdown]
# 65.Log failed standing instructions for banking case 4; use sample reference `ACC-1065` and explain the result.

# %%
Account_Number='ACC-1065'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
Monthly_EMI=int(input("Enter EMI amount:"))
try:
    if(Monthly_EMI > balance):
        raise Exception("Payment Failed due to Insufficient Balance")
except Exception as e:
    print(e)
# Out:
# Account Number: ACC-1065
# Payment Failed due to Insufficient Balance

# %% [markdown]
# 66.Return a structured failure result for banking case 4; use sample reference `ACC-1066` and explain the result.

# %%
Account_Number='ACC-1066'
print("Account Number:",Account_Number)
amount=int(input("Enter Balance:"))
transfer_amount=int(input("Enter Transfer Amount:"))
try:
    if(transfer_amount > balance):
        raise Exception("Insufficient Money")
except Exception as e:
    print("Status:Fail")
    print(e)
else:
    print("Status:True")
    print("Payment Successful")
# Out:
# Account Number: ACC-1066
# Status:True
# Payment Successful

# %% [markdown]
# 67.Validate a nested beneficiary record for banking case 4; use sample reference `ACC-1067` and explain the result.

# %%
Account_Number='ACC-1067'
print("Account_Number:",Account_Number)
account_name="Kartheek"
IFSC_code="SBI5236985632"
Mobile_Number=8796541230
Reciever_Account_Number=input("Enter Account Number:")
Reciever_Name=input("Enter Name:")
Reciever_IFSC_Code=input("Enter IFSC Code:")
Reciever_Mobile_Number=int(input("Enter Mobile Number:"))
try:
    if(Reciever_Name != account_name):
        raise Exception("Name is incorrect")
    if(Account_Number != Reciever_Account_Number):
        raise Exception("Account Number is incorrect")
    if(IFSC_code != Reciever_IFSC_Code):
        raise Exception("IFSC Code is incorrect")
    if(Mobile_Number != Reciever_Mobile_Number):
        raise Exception("Mobile Number is incorrect")
except Exception as e:
    print(e)
else:
    print("Your details are correct")
# Out:
# Account_Number: ACC-1067
# Your details are correct

# %% [markdown]
# 68.Use a context manager for an audit file for banking case 4; use sample reference `ACC-1068` and explain the result.

# %%
Account_Number='ACC-1068'
print("Account Number:",Account_Number)
account_number=input("Enter Account Number:")
name=input("Enter Name:")
IFSC_Code=input("Enter IFSC Code:")
Mobile_Number=input("Enter Mobile Number:")
try:
    if(not name.isalpha()):
        raise Exception("Name is not valid")
    if(not account_number.isnumeric()):
        raise Exception("Account Number is not valid")
    if(not IFSC_Code.isalnum()):
        raise Exception("IFSC code is not valid")
    if(not Mobile_Number.isnumeric()):
        raise Exception("Mobile Number is not valid")
except Exception as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account Number: ACC-1068
# Account Number is not valid

# %% [markdown]
# 69. Separate validation and recovery for banking case 4; use sample reference `ACC-1069` and explain the result.

# %%
Account_Number='ACC-1069'
print("Account Number:",Account_Number)
Balance=int(input("Enter Balance: "))
Name="Sai"
transfer_Amount=int(input("Enter Transfer Amount:"))
UPI_Id='7993923717@asd'
customer_UPI_ID=input("Enter UPI:")
try:
    if(UPI_Id != customer_UPI_ID):
        raise Exception("Enter Correct upi id")
except:
    UPI_Id=input("Enter correct UPI_ID:")
    try:
        if(UPI_Id != customer_UPI_ID):
            raise Exception("Enter Correct UPI Id")
    except Exception as e:
        print(e)
    else:
        print("Your UPI ID Is correct")
else:
    print("Your upi id is correct")
try:
    if(transfer_Amount > Balance):
        raise Exception("transfer amount is greater than the balance")
except Exception as e:
    transfer_Amount=int(input("Enter tranfer amount is less than the balamce:"))
    try:
        if(transfer_Amount > balance):
            raise Exception("transfer amount is greater than the balance")
    except Exception as e:
        print(e)
    else:
        print("Transaction successfully Completed")
else:
    print("Transaction Successfully completed")
# Out:
# Account Number: ACC-1069
# Your upi id is correct
# Transaction Successfully completed

# %% [markdown]
# 70.Collect all kyc validation errors for banking case 4; use sample reference `ACC-1070` and explain the result.

# %%
Account_Number = 'ACC-1070'
print("Account_Number:", Account_Number)
class Banking(Exception):
    pass
class Insufficientbalance(Banking):
    pass
class IncorrectName(Banking):
    pass
class IncorrectAccountNumber(Banking):
    pass
class InvalidTransaction(Banking):
    pass
balance = int(input("Enter Amount:"))
transaction_amount = int(input("Enter Transaction Amount:"))
Name = input("Enter Name:")
errors = []
try:
    if not Name.startswith("Ray"):
        errors.append("Customer Name is wrong")
    if transaction_amount > balance:
        errors.append("Insufficient Balance")
    if not Account_Number.startswith("ACC-"):
        errors.append("Incorrect Account Number")
    if transaction_amount <= 0:
        errors.append("Transaction amount should be greater than zero")
    if errors:
        raise Banking("Multiple errors found")
except Banking:
    for error in errors:
        print(error)
else:
    print("All details are correct")
# Out:
# Account_Number: ACC-1070
# Customer Name is wrong

# %% [markdown]
# Difficult

# %% [markdown]
# 71. Design a banking exception hierarchy for banking case 1; use sample reference `ACC-1071` and explain the result.

# %%
Account_Number='ACC-1071'
print("Account_Number:",Account_Number)
class Banking(Exception):
    pass
class Insufficientbalance(Banking):
    pass
class IncorrectName(Banking):
    pass
class IncorrectAccountNumber(Banking):
    pass
class InvalidTransaction(Banking):
    pass

balance=int(input("Enter Amount:"))
transaction_amount=int(input("Enter Transaction Amount:"))
Name=input("Enter Name:")

try:
    if(not Name.startswith("Ray")):
        raise IncorrectName("Customer Name is wrong")
    if(transaction_amount > balance):
        raise Insufficientbalance("Insufficient Balanace")
    if(Account_Number.startswith("1")):
        raise IncorrectAccountNumber("Incorrect Account Number")
    if(transaction_amount <= 0):
        raise InvalidTransaction("Transaction amount should be greater Than zero")
except IncorrectName as e:
    print(e)
except Insufficientbalance as e:
    print(e)
except IncorrectAccountNumber as e:
    print(e)
except InvalidTransaction as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account_Number: ACC-1071
# Customer Name is wrong

# %% [markdown]
# 72.Make a transfer rollback-safe for banking case 1; use sample reference `ACC-1072` and explain the result.

# %%
Account_Number='ACC-1072'
print("Account_Number:",Account_Number)
Account1_balance=int(input("Enter Account1 Balance:"))
Account2_balance=int(input("Enter Account2 Balance:"))
transaction_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transaction_Amount > Account1_balance):
        raise Exception("Insufficientbalance in Account1_balance")
except Exception as e:
    print(e)
    print("Account1 Balance:",Account1_balance)
    print("Account2 Balance:",Account2_balance)
else:
    Account1_balance=Account1_balance-transaction_Amount
    Account2_balance=Account2_balance+transaction_Amount
    print("After Transaction:")
    print("Account1 Balance:",Account1_balance)
    print("Account2 Balance:",Account2_balance)
# Out:
# Account_Number: ACC-1072
# After Transaction:
# Account1 Balance: 44000
# Account2 Balance: 106000

# %% [markdown]
# 73.Preserve causes across service layers for banking case 1; use sample reference `ACC-1073` and explain the result.

# %%
Account_Number='Acc-1073'
print("Account_Number:",Account_Number)
balance=int(input("Ente Balance:"))
transaction_amount=int(input("Enter transaction Balance:"))
try:
    if(transaction_amount > balance):
        raise Exception("Transaction Failed: Due to the Insufficient Funds")
except Exception as e:
    print(e)
else:
    print("Transaction Successfully completed")
# Out:
# Account_Number: Acc-1073
# Transaction Failed: Due to the Insufficient Funds

# %% [markdown]
# 74.Implement bounded exponential retry for banking case 1; use sample reference `ACC-1074` and explain the result.

# %%
import time
Account_Number='ACC-1074'
print("Account_Number:",Account_Number)
balance=int(input("Enter Balance:"))
count=int(input("enter the number of attempts:"))
for i in range(1,count+1):
    transaction_amount=int(input("Enter Transaction Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Transaction Failed")
        if(transaction_amount <= balance):
            print("Transaction Successfully competed")
            break
    except Exception as e:
        time.sleep(i)
        print(e)
# Out:
# Account_Number: ACC-1074
# Transaction Successfully competed

# %% [markdown]
# 75.Create a transaction context manager for banking case 1; use sample reference `ACC-1075` and explain the result.

# %%
Account_Number='ACC-1075'
print("Account Number:",Account_Number)
account1_balance=int(input("Enter the account1 balance:"))
account2_balance=int(input("Enter the account2 balance:"))
transaction_amount=int(input("Enter Transfer Amount:"))
try:
    if(transaction_amount > account1_balance):
        raise Exception("Insufficient balance")
except Exception as e:
    print(e)
    print("Account1 Balance:",account1_balance)
    print("Account2 Balance:",account2_balance)
else:
    print("After Transaction Sucessfully")
    account1_balance=account1_balance - transaction_amount
    account2_balance=account2_balance + transaction_amount
    print("Account1_balance:",account1_balance)
    print("Account2_balance:",account2_balance)
# Out:
# Account Number: ACC-1075
# Insufficient balance
# Account1 Balance: 50000
# Account2 Balance: 100000

# %% [markdown]
# 76.Build a dead-letter queue for payment events for banking case 1; use sample reference `ACC-1076` and explain the result.

# %%
Account_Number='ACC-1076'
print("Account_Number:",Account_Number)
balance=int(input("Enter the balance:"))
count=int(input("Enter the number of attempts:"))
for i in range(1,count+1):
    transaction_amount=int(input("Enter Transfer Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Insufficient balance")
        if(transaction_amount <=balance):
            break
    except Exception as e:
        print(e)
# Out:
# Account_Number: ACC-1076
# Insufficient balance
# Insufficient balance

# %% [markdown]
# 77.Make batch settlement failure-isolated for banking case 1; use sample reference `ACC-1077` and explain the result.

# %%
Account_Number='ACC-1077'
print("Account_Number:",Account_Number)
count=int(input("Enter the number of attempts:"))
for i in range(1,count+1):
    balance=int(input("Enter The balance:"))
    transaction_amount=int(input("Enter Transfer Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Insufficient balance")
        if(transaction_amount <=balance):
            print("Transaction Successfully completed")
    except Exception as e:
        print(e)
# Out:
# Account_Number: ACC-1077
# Transaction Successfully completed
# Insufficient balance
# Transaction Successfully completed
# Transaction Successfully completed
# Insufficient balance

# %% [markdown]
# 78. Report exact paths in nested statements for banking case 1; use sample reference `ACC-1078` and explain the result.

# %%
Account_Number='ACC-1078'
print("Account_Number:",Account_Number)
name=input("Enter Name:")
upi_id=input("Enter UPI_ID")
len_Mobile_Number=int(input("Length of the mobile number:"))
balance=int(input("Enter The balance:"))
transfer_Amount=int(input("Enter The transfer Amount:"))

try:
    if(not name.startswith("Ray")):
        raise Exception("Name is incorrect")
    print("Name is correct")
    try:
        if(not Account_Number.startswith('ACC')):
            raise Exception("Account Number is invalid")
        print("Account is Correct")
        try:
            if(len_Mobile_Number != 10):
                raise Exception("Mobile number is incorrect")
            print("Mobile Number is correct")
            try:
                if(not upi_id.startswith("789")):
                    raise Exception("UPI Id is invalid")
                print("UPI Is correct")
                try:
                    if(transfer_Amount > balance):
                        raise Exception("Insufficient balance")
                    print("Transaction Successfully Completed")
                except Exception as e:
                    print(e)
            except Exception as e:
                print(e)
        except Exception as e:
            print(e)
    except Exception as e:
        print(e)
except Exception as e:
    print(e)
# Out:
# Account_Number: ACC-1078
# Name is correct
# Account is Correct
# Mobile Number is correct
# UPI Id is invalid

# %% [markdown]
# 79.Design idempotent recovery after timeout for banking case 1; use sample reference `ACC-1079` and explain the result.

# %%
Account_Number='ACC-1079'
print("Account Number:",Account_Number)
Account1_balance=int(input("Enter Account1 balance:"))
Account2_balance=int(input("Enter Account2 balance:"))
count=int(input("Number of attempts:"))
a=Account1_balance
count1=0
for i in range(1,count+1):
    transfer_Amount=int(input("Enter Transfer Amount:"))
    try:
        if(transfer_Amount > Account1_balance):
            count1=count1+1
            raise Exception("Payment Failed")
        if(transfer_Amount < Account1_balance):
            Account1_balance=Account1_balance-transfer_Amount
            Account2_balance=Account2_balance+transfer_Amount
            if(a > Account1_balance):
                print("Transaction Completed")
                print("Account1 Balance:",Account1_balance)
                print("Account2 Balance:",Account2_balance)
            break
    except Exception as e:
        print(e)
        if(count==count1):
            print("You Reached Maximum Number of attempts")
# Out:
# Account Number: ACC-1079
# Payment Failed
# Payment Failed
# Payment Failed
# Maximum Reached

# %% [markdown]
# 80.Build an exception-safe reconciliation pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.

# %%
Account_Number='ACC-1080'
print("Account_Number:",Account_Number)
Bank_amount=int(input("Enter A Banking amount:"))
payment_amount=int(input("Enter A Payment Amount"))
try:
    if(Bank_amount != payment_amount):
        raise Exception("Mismatched")
except Exception as e:
    print(e)
else:
    print("Matched")
# Out:
# Account_Number: ACC-1080
# Matched

# %% [markdown]
# 81. Design a banking exception hierarchy for banking case 2; use sample reference `ACC-1081` and explain the result.

# %%
Account_Number='ACC-1081'
print("Account Number:",Account_Number)
balance=int(input("Enter Amount:"))
transaction_amount=int(input("Enter Transaction Amount:"))
Name=input("Enter Name:")
try:
    if(not Name.startswith("Ray")):
        raise Exception("Customer Name is wrong")
    if(transaction_amount > balance):
        raise Exception("Insufficient Balanace")
    if(Account_Number.startswith("1")):
        raise Exception("Incorrect Account Number")
    if(transaction_amount <= 0):
        raise Exception("Transaction amount should be greater Than zero")
except Exception as e:
    print(e)
except Exception as e:
    print(e)
except Exception as e:
    print(e)
except Exception as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account Number: ACC-1081
# Insufficient Balanace

# %% [markdown]
# 82. Make a transfer rollback-safe for banking case 2; use sample reference `ACC-1082` and explain the result.

# %%
Account_Number='ACC-1082'
print("Account_Number:",Account_Number)
Account1_balance=int(input("Enter Account1 Balance:"))
Account2_balance=int(input("Enter Account2 Balance:"))
transaction_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transaction_Amount > Account1_balance):
        raise Exception("Insufficientbalance in Account1_balance")
except Exception as e:
    print(e)
    print("Account1 Balance:",Account1_balance)
    print("Account2 Balance:",Account2_balance)
else:
    Account1_balance=Account1_balance-transaction_Amount
    Account2_balance=Account2_balance+transaction_Amount
    print("After Transaction:")
    print("Account1 Balance:",Account1_balance)
    print("Account2 Balance:",Account2_balance)
# Out:
# Account_Number: ACC-1082
# After Transaction:
# Account1 Balance: 5000
# Account2 Balance: 108000

# %% [markdown]
# 83.Preserve causes across service layers for banking case 2; use sample reference `ACC-1083` and explain the result.

# %%
Account_Number='ACC-1083'
print("Account Number:",Account_Number)
balance=int(input("Ente Balance:"))
transaction_amount=int(input("Enter transaction Balance:"))
try:
    if(transaction_amount > balance):
        raise Exception("Transaction Failed: Due to the Insufficient Funds")
except Exception as e:
    print(e)
else:
    print("Transaction Successfully completed")
# Out:
# Account Number: ACC-1083
# Transaction Failed: Due to the Insufficient Funds

# %% [markdown]
# 84.Implement bounded exponential retry for banking case 2; use sample reference `ACC-1084` and explain the result.

# %%
import time
Account_Number='ACC-1084'
print("Account1 Number:",Account_Number)
balance=int(input("Enter Balance:"))
count=int(input("enter the number of attempts:"))
for i in range(1,count+1):
    transaction_amount=int(input("Enter Transaction Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Transaction Failed")
        if(transaction_amount <= balance):
            print("Transaction Successfully competed")
            break
    except Exception as e:
        time.sleep(i)
        print(e)
# Out:
# Account1 Number: ACC-1084
# Transaction Failed
# Transaction Failed
# Transaction Successfully competed

# %% [markdown]
# 85.Create a transaction context manager for banking case 2; use sample reference `ACC-1085` and explain the result.

# %%
Account_Number='ACC-1085'
print("Account Number:",Account_Number)
account1_balance=int(input("Enter the account1 balance:"))
account2_balance=int(input("Enter the account2 balance:"))
transaction_amount=int(input("Enter Transfer Amount:"))
try:
    if(transaction_amount > account1_balance):
        raise Exception("Insufficient balance")
except Exception as e:
    print(e)
    print("Account1 Balance:",account1_balance)
    print("Account2 Balance:",account2_balance)
else:
    print("After Transaction Sucessfully")
    account1_balance=account1_balance - transaction_amount
    account2_balance=account2_balance + transaction_amount
    print("Account1_balance:",account1_balance)
    print("Account2_balance:",account2_balance)
# Out:
# Account Number: ACC-1085
# After Transaction Sucessfully
# Account1_balance: 75000
# Account2_balance: 185000

# %% [markdown]
# 86.Build a dead-letter queue for payment events for banking case 2; use sample reference `ACC-1086` and explain the result.

# %%
Account_Number='ACC-1086'
print("Account_Number:",Account_Number)
balance=int(input("Enter the balance:"))
count=int(input("Enter the number of attempts:"))
for i in range(1,count+1):
    transaction_amount=int(input("Enter Transfer Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Insufficient balance")
        if(transaction_amount <=balance):
            break
    except Exception as e:
        print(e)
# Out:
# Account_Number: ACC-1086
# Insufficient balance
# Insufficient balance
# Insufficient balance

# %% [markdown]
# 87. Make batch settlement failure-isolated for banking case 2; use sample reference `ACC-1087` and explain the result.

# %%
Account_Number='ACC-1087'
print("Account Number:",Account_Number)
count=int(input("Enter the number of attempts:"))
for i in range(1,count+1):
    balance=int(input("Enter The balance:"))
    transaction_amount=int(input("Enter Transfer Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Insufficient balance")
        if(transaction_amount <=balance):
            print("Transaction Successfully completed")
    except Exception as e:
        print(e)
# Out:
# Account Number: ACC-1087
# Insufficient balance
# Transaction Successfully completed
# Insufficient balance

# %% [markdown]
# 88.Report exact paths in nested statements for banking case 2; use sample reference `ACC-1088` and explain the result.

# %%
Account_Number='ACC-1088'
print("Account Number:",Account_Number)
name=input("Enter Name:")
upi_id=input("Enter UPI_ID")
len_Mobile_Number=int(input("Length of the mobile number:"))
balance=int(input("Enter The balance:"))
transfer_Amount=int(input("Enter The transfer Amount:"))

try:
    if(not name.startswith("Ray")):
        raise Exception("Name is incorrect")
    print("Name is correct")
    try:
        if(not Account_Number.startswith('ACC')):
            raise Exception("Account Number is invalid")
        print("Account is Correct")
        try:
            if(len_Mobile_Number != 10):
                raise Exception("Mobile number is incorrect")
            print("Mobile Number is correct")
            try:
                if(not upi_id.startswith("789")):
                    raise Exception("UPI Id is invalid")
                print("UPI Is correct")
                try:
                    if(transfer_Amount > balance):
                        raise Exception("Insufficient balance")
                    print("Transaction Successfully Completed")
                except Exception as e:
                    print(e)
            except Exception as e:
                print(e)
        except Exception as e:
            print(e)
    except Exception as e:
        print(e)
except Exception as e:
    print(e)
# Out:
# Account Number: ACC-1088
# Name is correct
# Account is Correct
# Mobile Number is correct
# UPI Is correct
# Insufficient balance

# %% [markdown]
# 89. Design idempotent recovery after timeout for banking case 2; use sample reference `ACC-1089` and explain the result.

# %%
Account_Number='ACC-1089'
print("Account Number:",Account_Number)
Account1_balance=int(input("Enter Account1 balance:"))
Account2_balance=int(input("Enter Account2 balance:"))
count=int(input("Number of attempts:"))
a=Account1_balance
count1=0
for i in range(1,count+1):
    transfer_Amount=int(input("Enter Transfer Amount:"))
    try:
        if(transfer_Amount > Account1_balance):
            count1=count1+1
            raise Exception("Payment Failed")
        if(transfer_Amount < Account1_balance):
            Account1_balance=Account1_balance-transfer_Amount
            Account2_balance=Account2_balance+transfer_Amount
            if(a > Account1_balance):
                print("Transaction Completed")
                print("Account1 Balance:",Account1_balance)
                print("Account2 Balance:",Account2_balance)
            break
    except Exception as e:
        print(e)
        if(count==count1):
            print("You Reached Maximum Number of attempts")
# Out:
# Account Number: ACC-1089
# Payment Failed
# Payment Failed
# You Reached Maximum Number of attempts

# %% [markdown]
# 90.Build an exception-safe reconciliation pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.

# %%
Account_Number='ACC-1090'
print("Account Number:",Account_Number)
Bank_amount=int(input("Enter A Banking amount:"))
payment_amount=int(input("Enter A Payment Amount"))
try:
    if(Bank_amount != payment_amount):
        raise Exception("Mismatched")
except Exception as e:
    print(e)
else:
    print("Matched")
# Out:
# Account Number: ACC-1090
# Matched

# %% [markdown]
# 91. Design a banking exception hierarchy for banking case 3; use sample reference `ACC-1091` and explain the result.

# %%
Account_Number='ACC-1091'
print("Account Number:",Account_Number)
balance=int(input("Enter Amount:"))
transaction_amount=int(input("Enter Transaction Amount:"))
Name=input("Enter Name:")
try:
    if(not Name.startswith("Ray")):
        raise Exception("Customer Name is wrong")
    if(transaction_amount > balance):
        raise Exception("Insufficient Balanace")
    if(Account_Number.startswith("1")):
        raise Exception("Incorrect Account Number")
    if(transaction_amount <= 0):
        raise Exception("Transaction amount should be greater Than zero")
except Exception as e:
    print(e)
except Exception as e:
    print(e)
except Exception as e:
    print(e)
except Exception as e:
    print(e)
else:
    print("All details are correct")
# Out:
# Account Number: ACC-1091
# All details are correct

# %% [markdown]
# 92.Make a transfer rollback-safe for banking case 3; use sample reference `ACC-1092` and explain the result.

# %%
Account_Number='ACC-1092'
print("Account Number:",Account_Number)
Account1_balance=int(input("Enter Account1 Balance:"))
Account2_balance=int(input("Enter Account2 Balance:"))
transaction_Amount=int(input("Enter Transfer Amount:"))
try:
    if(transaction_Amount > Account1_balance):
        raise Exception("Insufficientbalance in Account1_balance")
except Exception as e:
    print(e)
    print("Account1 Balance:",Account1_balance)
    print("Account2 Balance:",Account2_balance)
else:
    Account1_balance=Account1_balance-transaction_Amount
    Account2_balance=Account2_balance+transaction_Amount
    print("After Transaction:")
    print("Account1 Balance:",Account1_balance)
    print("Account2 Balance:",Account2_balance)
# Out:
# Account Number: ACC-1092
# Insufficientbalance in Account1_balance
# Account1 Balance: 78000
# Account2 Balance: 98000

# %% [markdown]
# 93.Preserve causes across service layers for banking case 3; use sample reference `ACC-1093` and explain the result.

# %%
Account_Number='ACC-1093'
print("Account Number:",Account_Number)
balance=int(input("Ente Balance:"))
transaction_amount=int(input("Enter transaction Balance:"))
try:
    if(transaction_amount > balance):
        raise Exception("Transaction Failed: Due to the Insufficient Funds")
except Exception as e:
    print(e)
else:
    print("Transaction Successfully completed")
# Out:
# Account Number: ACC-1093
# Transaction Successfully completed

# %% [markdown]
# 94.Implement bounded exponential retry for banking case 3; use sample reference `ACC-1094` and explain the result.

# %%
import time
Account_Number='ACC-1094'
print("Account Number:",Account_Number)
balance=int(input("Enter Balance:"))
count=int(input("enter the number of attempts:"))
for i in range(1,count+1):
    transaction_amount=int(input("Enter Transaction Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Transaction Failed")
        if(transaction_amount <= balance):
            print("Transaction Successfully competed")
            break
    except Exception as e:
        time.sleep(i)
        print(e)
# Out:
# Account Number: ACC-1094
# Transaction Successfully competed

# %% [markdown]
# 95.Create a transaction context manager for banking case 3; use sample reference `ACC-1095` and explain the result.

# %%
Account_Number='ACC-1095'
print("Account Number:",Account_Number)
account1_balance=int(input("Enter the account1 balance:"))
account2_balance=int(input("Enter the account2 balance:"))
transaction_amount=int(input("Enter Transfer Amount:"))
try:
    if(transaction_amount > account1_balance):
        raise Exception("Insufficient balance")
except Exception as e:
    print(e)
    print("Account1 Balance:",account1_balance)
    print("Account2 Balance:",account2_balance)
else:
    print("After Transaction Sucessfully")
    account1_balance=account1_balance - transaction_amount
    account2_balance=account2_balance + transaction_amount
    print("Account1_balance:",account1_balance)
    print("Account2_balance:",account2_balance)
# Out:
# Account Number: ACC-1095
# After Transaction Sucessfully
# Account1_balance: 18000
# Account2_balance: 43000

# %% [markdown]
# 96.Build a dead-letter queue for payment events for banking case 3; use sample reference `ACC-1096` and explain the result.

# %%
Account_Number='ACC-1096'
print("Account_Number:",Account_Number)
balance=int(input("Enter the balance:"))
count=int(input("Enter the number of attempts:"))
for i in range(1,count+1):
    transaction_amount=int(input("Enter Transfer Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Insufficient balance")
        if(transaction_amount <=balance):
            break
    except Exception as e:
        print(e)
# Out:
# Account_Number: ACC-1096

# %% [markdown]
# 97.Make batch settlement failure-isolated for banking case 3; use sample reference `ACC-1097` and explain the result.

# %%
Account_Number='ACC-1097'
print("Account_Number:",Account_Number)
count=int(input("Enter the number of attempts:"))
for i in range(1,count+1):
    balance=int(input("Enter The balance:"))
    transaction_amount=int(input("Enter Transfer Amount:"))
    try:
        if(transaction_amount > balance):
            raise Exception("Insufficient balance")
        if(transaction_amount <=balance):
            print("Transaction Successfully completed")
    except Exception as e:
        print(e)
# Out:
# Account_Number: ACC-1097
# Transaction Successfully completed
# Transaction Successfully completed
# Insufficient balance

# %% [markdown]
# 98.Report exact paths in nested statements for banking case 3; use sample reference `ACC-1098` and explain the result.

# %%
Account_Number='ACC-1098'
print("Account Number:",Account_Number)
name=input("Enter Name:")
upi_id=input("Enter UPI_ID")
len_Mobile_Number=int(input("Length of the mobile number:"))
balance=int(input("Enter The balance:"))
transfer_Amount=int(input("Enter The transfer Amount:"))

try:
    if(not name.startswith("Ray")):
        raise Exception("Name is incorrect")
    print("Name is correct")
    try:
        if(not Account_Number.startswith('ACC')):
            raise Exception("Account Number is invalid")
        print("Account is Correct")
        try:
            if(len_Mobile_Number != 10):
                raise Exception("Mobile number is incorrect")
            print("Mobile Number is correct")
            try:
                if(not upi_id.startswith("789")):
                    raise Exception("UPI Id is invalid")
                print("UPI Is correct")
                try:
                    if(transfer_Amount > balance):
                        raise Exception("Insufficient balance")
                    print("Transaction Successfully Completed")
                except Exception as e:
                    print(e)
            except Exception as e:
                print(e)
        except Exception as e:
            print(e)
    except Exception as e:
        print(e)
except Exception as e:
    print(e)
# Out:
# Account Number: ACC-1098
# Name is correct
# Account is Correct
# Mobile number is incorrect

# %% [markdown]
# 99.Design idempotent recovery after timeout for banking case 3; use sample reference `ACC-1099` and explain the result.

# %%
Account_Number='ACC-1099'
print("Account_Number:",Account_Number)
Account1_balance=int(input("Enter Account1 balance:"))
Account2_balance=int(input("Enter Account2 balance:"))
count=int(input("Number of attempts:"))
a=Account1_balance
count1=0
for i in range(1,count+1):
    transfer_Amount=int(input("Enter Transfer Amount:"))
    try:
        if(transfer_Amount > Account1_balance):
            count1=count1+1
            raise Exception("Payment Failed")
        if(transfer_Amount < Account1_balance):
            Account1_balance=Account1_balance-transfer_Amount
            Account2_balance=Account2_balance+transfer_Amount
            if(a > Account1_balance):
                print("Transaction Completed")
                print("Account1 Balance:",Account1_balance)
                print("Account2 Balance:",Account2_balance)
            break
    except Exception as e:
        print(e)
        if(count==count1):
            print("You Reached Maximum Number of attempts")
# Out:
# Account_Number: ACC-1099
# Transaction Completed
# Account1 Balance: 51000
# Account2 Balance: 79000

# %% [markdown]
# 100.Build an exception-safe reconciliation pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.

# %%
Account_Number='ACC-1100'
print("Account Number:",Account_Number)
Bank_amount=int(input("Enter A Banking amount:"))
payment_amount=int(input("Enter A Payment Amount"))
try:
    if(Bank_amount != payment_amount):
        raise Exception("Mismatched")
except Exception as e:
    print(e)
else:
    print("Matched")
# Out:
# Account Number: ACC-1100
# Mismatched
